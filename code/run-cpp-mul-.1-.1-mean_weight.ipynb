# %%
# %load main.py
import world
import utils
from world import cprint
import torch
import numpy as np
from tensorboardX import SummaryWriter
import time
import Procedure
from os.path import join
# ==============================
utils.set_seed(world.seed)
print(">>SEED:", world.seed)
# ==============================
import register
from register import dataset

Recmodel = register.MODELS[world.model_name](world.config, dataset)
Recmodel = Recmodel.to(world.device)
bpr = utils.BPRLoss(Recmodel, world.config)

weight_file = utils.getFileName()
print(f"load and save to {weight_file}")
if world.LOAD:
    try:
        Recmodel.load_state_dict(torch.load(weight_file,map_location=torch.device('cpu')))
        world.cprint(f"loaded model weights from {weight_file}")
    except FileNotFoundError:
        print(f"{weight_file} not exists, start from beginning")
Neg_k = 1

# init tensorboard
if world.tensorboard:
    w : SummaryWriter = SummaryWriter(
                                    join(world.BOARD_PATH, time.strftime("%m-%d-%Hh%Mm%Ss-") + "-" + world.comment)
                                    )
else:
    w = None
    world.cprint("not enable tensorflowboard")

try:
    for epoch in range(world.TRAIN_epochs):
        start = time.time()
        if epoch %10 == 0:
            cprint("[TEST]")
            Procedure.Test(dataset, Recmodel, epoch, w, world.config['multicore'])
        output_information = Procedure.BPR_train_original(dataset, Recmodel, bpr, epoch, neg_k=Neg_k,w=w)
        print(f'EPOCH[{epoch+1}/{world.TRAIN_epochs}] {output_information}')
        torch.save(Recmodel.state_dict(), weight_file)
finally:
    if world.tensorboard:
        w.close()
# Out:
# >>SEED: 2020
# loading [../data/gowalla]
# 810128 interactions for training
# 217242 interactions for testing
# gowalla Sparsity : 0.0008396216228570436
# gowalla is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'multicore': 1,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 24
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded heterogeneous graph ...
# don't split the matrix
# loading adjacency matrix
# successfully loaded homogeneous graph ...
# don't split the matrix
# loading degree weight
# successfully loaded heterogeneous degree weight ...
# lgn is already to go(dropout:0)
# load and save to /home/user1/Larry/FGCF/runs/code/checkpoints/lgn-gowalla-3-64.pth.tar
# [TEST]
# {'precision': array([0.00031315]), 'recall': array([0.00104633]), 'ndcg': array([0.00064937])}
# EPOCH[1/1000] loss0.622-|Sample:0.16|
# EPOCH[2/1000] loss0.334-|Sample:0.14|
# EPOCH[3/1000] loss0.215-|Sample:0.13|
# EPOCH[4/1000] loss0.165-|Sample:0.14|
# EPOCH[5/1000] loss0.137-|Sample:0.14|
# EPOCH[6/1000] loss0.119-|Sample:0.13|
# EPOCH[7/1000] loss0.106-|Sample:0.13|
# EPOCH[8/1000] loss0.097-|Sample:0.14|
# EPOCH[9/1000] loss0.090-|Sample:0.14|
# EPOCH[10/1000] loss0.084-|Sample:0.13|
# [TEST]
# {'precision': array([0.03767667]), 'recall': array([0.1215979]), 'ndcg': array([0.1037599])}
# EPOCH[11/1000] loss0.079-|Sample:0.16|
# EPOCH[12/1000] loss0.074-|Sample:0.14|
# EPOCH[13/1000] loss0.071-|Sample:0.13|
# EPOCH[14/1000] loss0.068-|Sample:0.14|
# EPOCH[15/1000] loss0.065-|Sample:0.14|
# EPOCH[16/1000] loss0.062-|Sample:0.14|
# EPOCH[17/1000] loss0.059-|Sample:0.14|
# EPOCH[18/1000] loss0.058-|Sample:0.16|
# EPOCH[19/1000] loss0.057-|Sample:0.13|
# EPOCH[20/1000] loss0.054-|Sample:0.14|
# [TEST]
# {'precision': array([0.04053185]), 'recall': array([0.13158645]), 'ndcg': array([0.11254191])}
# EPOCH[21/1000] loss0.053-|Sample:0.15|
# EPOCH[22/1000] loss0.051-|Sample:0.13|
# EPOCH[23/1000] loss0.050-|Sample:0.14|
# EPOCH[24/1000] loss0.049-|Sample:0.14|
# EPOCH[25/1000] loss0.048-|Sample:0.14|
# EPOCH[26/1000] loss0.046-|Sample:0.14|
# EPOCH[27/1000] loss0.045-|Sample:0.14|
# EPOCH[28/1000] loss0.045-|Sample:0.14|
# EPOCH[29/1000] loss0.043-|Sample:0.14|
# EPOCH[30/1000] loss0.043-|Sample:0.14|
# [TEST]
# {'precision': array([0.04285116]), 'recall': array([0.13927339]), 'ndcg': array([0.119531])}
# EPOCH[31/1000] loss0.042-|Sample:0.16|
# EPOCH[32/1000] loss0.042-|Sample:0.14|
# EPOCH[33/1000] loss0.040-|Sample:0.14|
# EPOCH[34/1000] loss0.040-|Sample:0.14|
# EPOCH[35/1000] loss0.039-|Sample:0.14|
# EPOCH[36/1000] loss0.038-|Sample:0.14|
# EPOCH[37/1000] loss0.037-|Sample:0.14|
# EPOCH[38/1000] loss0.037-|Sample:0.14|
# EPOCH[39/1000] loss0.036-|Sample:0.14|
# EPOCH[40/1000] loss0.036-|Sample:0.13|
# [TEST]
# {'precision': array([0.04447887]), 'recall': array([0.14521454]), 'ndcg': array([0.12459572])}
# EPOCH[41/1000] loss0.035-|Sample:0.13|
# EPOCH[42/1000] loss0.034-|Sample:0.14|
# EPOCH[43/1000] loss0.034-|Sample:0.14|
# EPOCH[44/1000] loss0.034-|Sample:0.13|
# EPOCH[45/1000] loss0.034-|Sample:0.14|
# EPOCH[46/1000] loss0.033-|Sample:0.14|
# EPOCH[47/1000] loss0.033-|Sample:0.14|
# EPOCH[48/1000] loss0.032-|Sample:0.14|
# EPOCH[49/1000] loss0.032-|Sample:0.16|
# EPOCH[50/1000] loss0.031-|Sample:0.14|
# [TEST]
# {'precision': array([0.04598433]), 'recall': array([0.14999583]), 'ndcg': array([0.12892457])}
# EPOCH[51/1000] loss0.031-|Sample:0.12|
# EPOCH[52/1000] loss0.030-|Sample:0.14|
# EPOCH[53/1000] loss0.030-|Sample:0.14|
# EPOCH[54/1000] loss0.030-|Sample:0.14|
# EPOCH[55/1000] loss0.029-|Sample:0.14|
# EPOCH[56/1000] loss0.029-|Sample:0.14|
# EPOCH[57/1000] loss0.029-|Sample:0.13|
# EPOCH[58/1000] loss0.029-|Sample:0.14|
# EPOCH[59/1000] loss0.028-|Sample:0.13|
# EPOCH[60/1000] loss0.028-|Sample:0.14|
# [TEST]
# {'precision': array([0.04733237]), 'recall': array([0.15453588]), 'ndcg': array([0.13258043])}
# EPOCH[61/1000] loss0.028-|Sample:0.14|
# EPOCH[62/1000] loss0.028-|Sample:0.14|
# EPOCH[63/1000] loss0.027-|Sample:0.14|
# EPOCH[64/1000] loss0.027-|Sample:0.14|
# EPOCH[65/1000] loss0.027-|Sample:0.13|
# EPOCH[66/1000] loss0.026-|Sample:0.14|
# EPOCH[67/1000] loss0.026-|Sample:0.14|
# EPOCH[68/1000] loss0.026-|Sample:0.13|
# EPOCH[69/1000] loss0.026-|Sample:0.14|
# EPOCH[70/1000] loss0.026-|Sample:0.14|
# [TEST]
# {'precision': array([0.04860004]), 'recall': array([0.15880377]), 'ndcg': array([0.13594847])}
# EPOCH[71/1000] loss0.025-|Sample:0.13|
# EPOCH[72/1000] loss0.025-|Sample:0.14|
# EPOCH[73/1000] loss0.025-|Sample:0.14|
# EPOCH[74/1000] loss0.024-|Sample:0.14|
# EPOCH[75/1000] loss0.025-|Sample:0.14|
# EPOCH[76/1000] loss0.024-|Sample:0.14|
# EPOCH[77/1000] loss0.024-|Sample:0.14|
# EPOCH[78/1000] loss0.024-|Sample:0.14|
# EPOCH[79/1000] loss0.023-|Sample:0.14|
# EPOCH[80/1000] loss0.024-|Sample:0.14|
# [TEST]
# {'precision': array([0.04939882]), 'recall': array([0.16142045]), 'ndcg': array([0.13815662])}
# EPOCH[81/1000] loss0.023-|Sample:0.14|
# EPOCH[82/1000] loss0.023-|Sample:0.13|
# EPOCH[83/1000] loss0.023-|Sample:0.14|
# EPOCH[84/1000] loss0.022-|Sample:0.13|
# EPOCH[85/1000] loss0.022-|Sample:0.13|
# EPOCH[86/1000] loss0.022-|Sample:0.13|
# EPOCH[87/1000] loss0.022-|Sample:0.14|
# EPOCH[88/1000] loss0.022-|Sample:0.14|
# EPOCH[89/1000] loss0.022-|Sample:0.13|
# EPOCH[90/1000] loss0.022-|Sample:0.14|
# [TEST]
# {'precision': array([0.05033324]), 'recall': array([0.16473367]), 'ndcg': array([0.14079434])}
# EPOCH[91/1000] loss0.021-|Sample:0.14|
# EPOCH[92/1000] loss0.022-|Sample:0.14|
# EPOCH[93/1000] loss0.021-|Sample:0.14|
# EPOCH[94/1000] loss0.021-|Sample:0.14|
# EPOCH[95/1000] loss0.021-|Sample:0.14|
# EPOCH[96/1000] loss0.021-|Sample:0.14|
# EPOCH[97/1000] loss0.021-|Sample:0.14|
# EPOCH[98/1000] loss0.021-|Sample:0.15|
# EPOCH[99/1000] loss0.021-|Sample:0.14|
# EPOCH[100/1000] loss0.020-|Sample:0.14|
# [TEST]
# {'precision': array([0.05097461]), 'recall': array([0.16659702]), 'ndcg': array([0.14265852])}
# EPOCH[101/1000] loss0.020-|Sample:0.12|
# EPOCH[102/1000] loss0.020-|Sample:0.14|
# EPOCH[103/1000] loss0.020-|Sample:0.14|
# EPOCH[104/1000] loss0.020-|Sample:0.13|
# EPOCH[105/1000] loss0.020-|Sample:0.14|
# EPOCH[106/1000] loss0.020-|Sample:0.13|
# EPOCH[107/1000] loss0.020-|Sample:0.13|
# EPOCH[108/1000] loss0.020-|Sample:0.14|
# EPOCH[109/1000] loss0.019-|Sample:0.14|
# EPOCH[110/1000] loss0.019-|Sample:0.13|
# [TEST]
# {'precision': array([0.05173153]), 'recall': array([0.16921269]), 'ndcg': array([0.14456273])}
# EPOCH[111/1000] loss0.019-|Sample:0.13|
# EPOCH[112/1000] loss0.019-|Sample:0.13|
# EPOCH[113/1000] loss0.019-|Sample:0.14|
# EPOCH[114/1000] loss0.019-|Sample:0.13|
# EPOCH[115/1000] loss0.019-|Sample:0.14|
# EPOCH[116/1000] loss0.019-|Sample:0.14|
# EPOCH[117/1000] loss0.019-|Sample:0.13|
# EPOCH[118/1000] loss0.018-|Sample:0.13|
# EPOCH[119/1000] loss0.019-|Sample:0.14|
# EPOCH[120/1000] loss0.018-|Sample:0.13|
# [TEST]
# {'precision': array([0.05204468]), 'recall': array([0.17020964]), 'ndcg': array([0.14577274])}
# EPOCH[121/1000] loss0.018-|Sample:0.12|
# EPOCH[122/1000] loss0.018-|Sample:0.13|
# EPOCH[123/1000] loss0.018-|Sample:0.13|
# EPOCH[124/1000] loss0.018-|Sample:0.14|
# EPOCH[125/1000] loss0.018-|Sample:0.13|
# EPOCH[126/1000] loss0.018-|Sample:0.13|
# EPOCH[127/1000] loss0.018-|Sample:0.13|
# EPOCH[128/1000] loss0.018-|Sample:0.13|
# EPOCH[129/1000] loss0.018-|Sample:0.13|
# EPOCH[130/1000] loss0.018-|Sample:0.14|
# [TEST]
# {'precision': array([0.05256045]), 'recall': array([0.17175341]), 'ndcg': array([0.14727046])}
# EPOCH[131/1000] loss0.018-|Sample:0.13|
# EPOCH[132/1000] loss0.017-|Sample:0.13|
# EPOCH[133/1000] loss0.017-|Sample:0.14|
# EPOCH[134/1000] loss0.017-|Sample:0.14|
# EPOCH[135/1000] loss0.017-|Sample:0.13|
# EPOCH[136/1000] loss0.017-|Sample:0.13|
# EPOCH[137/1000] loss0.017-|Sample:0.13|
# EPOCH[138/1000] loss0.017-|Sample:0.14|
# EPOCH[139/1000] loss0.017-|Sample:0.14|
# EPOCH[140/1000] loss0.017-|Sample:0.13|
# [TEST]
# {'precision': array([0.05285518]), 'recall': array([0.1725735]), 'ndcg': array([0.14811288])}
# EPOCH[141/1000] loss0.017-|Sample:0.14|
# EPOCH[142/1000] loss0.017-|Sample:0.14|
# EPOCH[143/1000] loss0.017-|Sample:0.14|
# EPOCH[144/1000] loss0.017-|Sample:0.13|
# EPOCH[145/1000] loss0.017-|Sample:0.13|
# EPOCH[146/1000] loss0.017-|Sample:0.13|
# EPOCH[147/1000] loss0.017-|Sample:0.13|
# EPOCH[148/1000] loss0.017-|Sample:0.14|
# EPOCH[149/1000] loss0.016-|Sample:0.14|
# EPOCH[150/1000] loss0.016-|Sample:0.13|
# [TEST]
# {'precision': array([0.05326881]), 'recall': array([0.1738904]), 'ndcg': array([0.14924614])}
# EPOCH[151/1000] loss0.016-|Sample:0.13|
# EPOCH[152/1000] loss0.016-|Sample:0.13|
# EPOCH[153/1000] loss0.017-|Sample:0.13|
# EPOCH[154/1000] loss0.016-|Sample:0.14|
# EPOCH[155/1000] loss0.016-|Sample:0.14|
# EPOCH[156/1000] loss0.016-|Sample:0.14|
# EPOCH[157/1000] loss0.016-|Sample:0.14|
# EPOCH[158/1000] loss0.016-|Sample:0.15|
# EPOCH[159/1000] loss0.016-|Sample:0.13|
# EPOCH[160/1000] loss0.016-|Sample:0.14|
# [TEST]
# {'precision': array([0.05353339]), 'recall': array([0.1745285]), 'ndcg': array([0.14973493])}
# EPOCH[161/1000] loss0.016-|Sample:0.13|
# EPOCH[162/1000] loss0.016-|Sample:0.13|
# EPOCH[163/1000] loss0.016-|Sample:0.14|
# EPOCH[164/1000] loss0.016-|Sample:0.15|
# EPOCH[165/1000] loss0.016-|Sample:0.14|
# EPOCH[166/1000] loss0.016-|Sample:0.14|
# EPOCH[167/1000] loss0.016-|Sample:0.14|
# EPOCH[168/1000] loss0.016-|Sample:0.14|
# EPOCH[169/1000] loss0.016-|Sample:0.13|
# EPOCH[170/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.05410275]), 'recall': array([0.17632415]), 'ndcg': array([0.15098366])}
# EPOCH[171/1000] loss0.015-|Sample:0.15|
# EPOCH[172/1000] loss0.015-|Sample:0.14|
# EPOCH[173/1000] loss0.015-|Sample:0.14|
# EPOCH[174/1000] loss0.015-|Sample:0.13|
# EPOCH[175/1000] loss0.015-|Sample:0.14|
# EPOCH[176/1000] loss0.015-|Sample:0.13|
# EPOCH[177/1000] loss0.015-|Sample:0.14|
# EPOCH[178/1000] loss0.015-|Sample:0.13|
# EPOCH[179/1000] loss0.015-|Sample:0.13|
# EPOCH[180/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.05433217]), 'recall': array([0.17711711]), 'ndcg': array([0.15184068])}
# EPOCH[181/1000] loss0.015-|Sample:0.14|
# EPOCH[182/1000] loss0.015-|Sample:0.13|
# EPOCH[183/1000] loss0.015-|Sample:0.13|
# EPOCH[184/1000] loss0.015-|Sample:0.13|
# EPOCH[185/1000] loss0.015-|Sample:0.13|
# EPOCH[186/1000] loss0.015-|Sample:0.14|
# EPOCH[187/1000] loss0.015-|Sample:0.13|
# EPOCH[188/1000] loss0.015-|Sample:0.13|
# EPOCH[189/1000] loss0.015-|Sample:0.13|
# EPOCH[190/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.0547257]), 'recall': array([0.17814211]), 'ndcg': array([0.15280177])}
# EPOCH[191/1000] loss0.015-|Sample:0.13|
# EPOCH[192/1000] loss0.015-|Sample:0.13|
# EPOCH[193/1000] loss0.015-|Sample:0.14|
# EPOCH[194/1000] loss0.015-|Sample:0.13|
# EPOCH[195/1000] loss0.015-|Sample:0.13|
# EPOCH[196/1000] loss0.015-|Sample:0.13|
# EPOCH[197/1000] loss0.015-|Sample:0.13|
# EPOCH[198/1000] loss0.015-|Sample:0.13|
# EPOCH[199/1000] loss0.015-|Sample:0.13|
# EPOCH[200/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.05473407]), 'recall': array([0.17825723]), 'ndcg': array([0.15310963])}
# EPOCH[201/1000] loss0.015-|Sample:0.15|
# EPOCH[202/1000] loss0.014-|Sample:0.14|
# EPOCH[203/1000] loss0.014-|Sample:0.13|
# EPOCH[204/1000] loss0.014-|Sample:0.14|
# EPOCH[205/1000] loss0.014-|Sample:0.13|
# EPOCH[206/1000] loss0.014-|Sample:0.14|
# EPOCH[207/1000] loss0.014-|Sample:0.13|
# EPOCH[208/1000] loss0.014-|Sample:0.14|
# EPOCH[209/1000] loss0.014-|Sample:0.14|
# EPOCH[210/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05495847]), 'recall': array([0.17869667]), 'ndcg': array([0.15343946])}
# EPOCH[211/1000] loss0.014-|Sample:0.13|
# EPOCH[212/1000] loss0.014-|Sample:0.13|
# EPOCH[213/1000] loss0.014-|Sample:0.14|
# EPOCH[214/1000] loss0.014-|Sample:0.13|
# EPOCH[215/1000] loss0.014-|Sample:0.14|
# EPOCH[216/1000] loss0.014-|Sample:0.13|
# EPOCH[217/1000] loss0.014-|Sample:0.14|
# EPOCH[218/1000] loss0.014-|Sample:0.13|
# EPOCH[219/1000] loss0.014-|Sample:0.15|
# EPOCH[220/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05518621]), 'recall': array([0.17970522]), 'ndcg': array([0.15405455])}
# EPOCH[221/1000] loss0.014-|Sample:0.14|
# EPOCH[222/1000] loss0.014-|Sample:0.14|
# EPOCH[223/1000] loss0.014-|Sample:0.14|
# EPOCH[224/1000] loss0.014-|Sample:0.14|
# EPOCH[225/1000] loss0.014-|Sample:0.13|
# EPOCH[226/1000] loss0.014-|Sample:0.13|
# EPOCH[227/1000] loss0.014-|Sample:0.14|
# EPOCH[228/1000] loss0.014-|Sample:0.14|
# EPOCH[229/1000] loss0.014-|Sample:0.13|
# EPOCH[230/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05536205]), 'recall': array([0.17986729]), 'ndcg': array([0.15463865])}
# EPOCH[231/1000] loss0.014-|Sample:0.13|
# EPOCH[232/1000] loss0.014-|Sample:0.13|
# EPOCH[233/1000] loss0.014-|Sample:0.13|
# EPOCH[234/1000] loss0.014-|Sample:0.13|
# EPOCH[235/1000] loss0.014-|Sample:0.14|
# EPOCH[236/1000] loss0.014-|Sample:0.14|
# EPOCH[237/1000] loss0.014-|Sample:0.13|
# EPOCH[238/1000] loss0.014-|Sample:0.13|
# EPOCH[239/1000] loss0.013-|Sample:0.13|
# EPOCH[240/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05560821]), 'recall': array([0.18053234]), 'ndcg': array([0.15518931])}
# EPOCH[241/1000] loss0.014-|Sample:0.13|
# EPOCH[242/1000] loss0.014-|Sample:0.13|
# EPOCH[243/1000] loss0.014-|Sample:0.13|
# EPOCH[244/1000] loss0.013-|Sample:0.13|
# EPOCH[245/1000] loss0.013-|Sample:0.13|
# EPOCH[246/1000] loss0.013-|Sample:0.14|
# EPOCH[247/1000] loss0.014-|Sample:0.14|
# EPOCH[248/1000] loss0.014-|Sample:0.13|
# EPOCH[249/1000] loss0.013-|Sample:0.13|
# EPOCH[250/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05560989]), 'recall': array([0.18025964]), 'ndcg': array([0.15526868])}
# EPOCH[251/1000] loss0.014-|Sample:0.12|
# EPOCH[252/1000] loss0.014-|Sample:0.13|
# EPOCH[253/1000] loss0.013-|Sample:0.13|
# EPOCH[254/1000] loss0.013-|Sample:0.13|
# EPOCH[255/1000] loss0.013-|Sample:0.14|
# EPOCH[256/1000] loss0.013-|Sample:0.13|
# EPOCH[257/1000] loss0.013-|Sample:0.13|
# EPOCH[258/1000] loss0.013-|Sample:0.13|
# EPOCH[259/1000] loss0.013-|Sample:0.13|
# EPOCH[260/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05580247]), 'recall': array([0.18109873]), 'ndcg': array([0.15562917])}
# EPOCH[261/1000] loss0.013-|Sample:0.14|
# EPOCH[262/1000] loss0.013-|Sample:0.13|
# EPOCH[263/1000] loss0.013-|Sample:0.14|
# EPOCH[264/1000] loss0.013-|Sample:0.14|
# EPOCH[265/1000] loss0.013-|Sample:0.14|
# EPOCH[266/1000] loss0.013-|Sample:0.14|
# EPOCH[267/1000] loss0.013-|Sample:0.14|
# EPOCH[268/1000] loss0.013-|Sample:0.14|
# EPOCH[269/1000] loss0.013-|Sample:0.14|
# EPOCH[270/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.0556417]), 'recall': array([0.18083322]), 'ndcg': array([0.15570212])}
# EPOCH[271/1000] loss0.013-|Sample:0.15|
# EPOCH[272/1000] loss0.013-|Sample:0.14|
# EPOCH[273/1000] loss0.013-|Sample:0.14|
# EPOCH[274/1000] loss0.013-|Sample:0.14|
# EPOCH[275/1000] loss0.013-|Sample:0.13|
# EPOCH[276/1000] loss0.013-|Sample:0.14|
# EPOCH[277/1000] loss0.013-|Sample:0.14|
# EPOCH[278/1000] loss0.013-|Sample:0.14|
# EPOCH[279/1000] loss0.013-|Sample:0.13|
# EPOCH[280/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05587615]), 'recall': array([0.181296]), 'ndcg': array([0.15582489])}
# EPOCH[281/1000] loss0.013-|Sample:0.16|
# EPOCH[282/1000] loss0.013-|Sample:0.14|
# EPOCH[283/1000] loss0.013-|Sample:0.14|
# EPOCH[284/1000] loss0.013-|Sample:0.13|
# EPOCH[285/1000] loss0.013-|Sample:0.15|
# EPOCH[286/1000] loss0.013-|Sample:0.14|
# EPOCH[287/1000] loss0.013-|Sample:0.14|
# EPOCH[288/1000] loss0.013-|Sample:0.14|
# EPOCH[289/1000] loss0.013-|Sample:0.14|
# EPOCH[290/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05588954]), 'recall': array([0.18153233]), 'ndcg': array([0.15603898])}
# EPOCH[291/1000] loss0.013-|Sample:0.13|
# EPOCH[292/1000] loss0.013-|Sample:0.14|
# EPOCH[293/1000] loss0.013-|Sample:0.14|
# EPOCH[294/1000] loss0.013-|Sample:0.14|
# EPOCH[295/1000] loss0.013-|Sample:0.17|
# EPOCH[296/1000] loss0.013-|Sample:0.14|
# EPOCH[297/1000] loss0.013-|Sample:0.14|
# EPOCH[298/1000] loss0.013-|Sample:0.14|
# EPOCH[299/1000] loss0.013-|Sample:0.14|
# EPOCH[300/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05606035]), 'recall': array([0.18206613]), 'ndcg': array([0.156199])}
# EPOCH[301/1000] loss0.013-|Sample:0.15|
# EPOCH[302/1000] loss0.013-|Sample:0.14|
# EPOCH[303/1000] loss0.013-|Sample:0.18|
# EPOCH[304/1000] loss0.013-|Sample:0.14|
# EPOCH[305/1000] loss0.013-|Sample:0.15|
# EPOCH[306/1000] loss0.013-|Sample:0.14|
# EPOCH[307/1000] loss0.013-|Sample:0.15|
# EPOCH[308/1000] loss0.013-|Sample:0.14|
# EPOCH[309/1000] loss0.013-|Sample:0.14|
# EPOCH[310/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05619097]), 'recall': array([0.18243509]), 'ndcg': array([0.15651758])}
# EPOCH[311/1000] loss0.013-|Sample:0.12|
# EPOCH[312/1000] loss0.013-|Sample:0.14|
# EPOCH[313/1000] loss0.013-|Sample:0.14|
# EPOCH[314/1000] loss0.013-|Sample:0.14|
# EPOCH[315/1000] loss0.013-|Sample:0.14|
# EPOCH[316/1000] loss0.013-|Sample:0.13|
# EPOCH[317/1000] loss0.013-|Sample:0.14|
# EPOCH[318/1000] loss0.013-|Sample:0.14|
# EPOCH[319/1000] loss0.013-|Sample:0.14|
# EPOCH[320/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05598165]), 'recall': array([0.18182162]), 'ndcg': array([0.15589462])}
# EPOCH[321/1000] loss0.013-|Sample:0.13|
# EPOCH[322/1000] loss0.013-|Sample:0.14|
# EPOCH[323/1000] loss0.013-|Sample:0.14|
# EPOCH[324/1000] loss0.013-|Sample:0.17|
# EPOCH[325/1000] loss0.013-|Sample:0.14|
# EPOCH[326/1000] loss0.013-|Sample:0.13|
# EPOCH[327/1000] loss0.013-|Sample:0.14|
# EPOCH[328/1000] loss0.013-|Sample:0.14|
# EPOCH[329/1000] loss0.012-|Sample:0.14|
# EPOCH[330/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05582758]), 'recall': array([0.18122238]), 'ndcg': array([0.1558096])}
# EPOCH[331/1000] loss0.012-|Sample:0.13|
# EPOCH[332/1000] loss0.012-|Sample:0.13|
# EPOCH[333/1000] loss0.012-|Sample:0.14|
# EPOCH[334/1000] loss0.012-|Sample:0.14|
# EPOCH[335/1000] loss0.012-|Sample:0.13|
# EPOCH[336/1000] loss0.013-|Sample:0.14|
# EPOCH[337/1000] loss0.012-|Sample:0.14|
# EPOCH[338/1000] loss0.013-|Sample:0.14|
# EPOCH[339/1000] loss0.012-|Sample:0.14|
# EPOCH[340/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05617088]), 'recall': array([0.1823977]), 'ndcg': array([0.1566057])}
# EPOCH[341/1000] loss0.012-|Sample:0.13|
# EPOCH[342/1000] loss0.012-|Sample:0.14|
# EPOCH[343/1000] loss0.013-|Sample:0.14|
# EPOCH[344/1000] loss0.012-|Sample:0.14|
# EPOCH[345/1000] loss0.013-|Sample:0.17|
# EPOCH[346/1000] loss0.012-|Sample:0.14|
# EPOCH[347/1000] loss0.012-|Sample:0.13|
# EPOCH[348/1000] loss0.012-|Sample:0.13|
# EPOCH[349/1000] loss0.012-|Sample:0.14|
# EPOCH[350/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05623284]), 'recall': array([0.18224887]), 'ndcg': array([0.15665583])}
# EPOCH[351/1000] loss0.012-|Sample:0.16|
# EPOCH[352/1000] loss0.012-|Sample:0.14|
# EPOCH[353/1000] loss0.012-|Sample:0.15|
# EPOCH[354/1000] loss0.012-|Sample:0.14|
# EPOCH[355/1000] loss0.012-|Sample:0.14|
# EPOCH[356/1000] loss0.012-|Sample:0.14|
# EPOCH[357/1000] loss0.012-|Sample:0.14|
# EPOCH[358/1000] loss0.012-|Sample:0.14|
# EPOCH[359/1000] loss0.012-|Sample:0.14|
# EPOCH[360/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05641369]), 'recall': array([0.18335321]), 'ndcg': array([0.15689224])}
# EPOCH[361/1000] loss0.012-|Sample:0.13|
# EPOCH[362/1000] loss0.012-|Sample:0.14|
# EPOCH[363/1000] loss0.012-|Sample:0.14|
# EPOCH[364/1000] loss0.012-|Sample:0.14|
# EPOCH[365/1000] loss0.012-|Sample:0.13|
# EPOCH[366/1000] loss0.012-|Sample:0.14|
# EPOCH[367/1000] loss0.012-|Sample:0.14|
# EPOCH[368/1000] loss0.012-|Sample:0.14|
# EPOCH[369/1000] loss0.012-|Sample:0.14|
# EPOCH[370/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05652756]), 'recall': array([0.18312328]), 'ndcg': array([0.15664699])}
# EPOCH[371/1000] loss0.012-|Sample:0.15|
# EPOCH[372/1000] loss0.012-|Sample:0.13|
# EPOCH[373/1000] loss0.012-|Sample:0.14|
# EPOCH[374/1000] loss0.012-|Sample:0.13|
# EPOCH[375/1000] loss0.012-|Sample:0.14|
# EPOCH[376/1000] loss0.012-|Sample:0.14|
# EPOCH[377/1000] loss0.013-|Sample:0.14|
# EPOCH[378/1000] loss0.012-|Sample:0.14|
# EPOCH[379/1000] loss0.012-|Sample:0.14|
# EPOCH[380/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05637183]), 'recall': array([0.18255268]), 'ndcg': array([0.15676351])}
# EPOCH[381/1000] loss0.012-|Sample:0.16|
# EPOCH[382/1000] loss0.012-|Sample:0.13|
# EPOCH[383/1000] loss0.012-|Sample:0.14|
# EPOCH[384/1000] loss0.012-|Sample:0.14|
# EPOCH[385/1000] loss0.012-|Sample:0.14|
# EPOCH[386/1000] loss0.012-|Sample:0.14|
# EPOCH[387/1000] loss0.012-|Sample:0.14|
# EPOCH[388/1000] loss0.012-|Sample:0.15|
# EPOCH[389/1000] loss0.012-|Sample:0.14|
# EPOCH[390/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05645891]), 'recall': array([0.18292718]), 'ndcg': array([0.15703133])}
# EPOCH[391/1000] loss0.012-|Sample:0.13|
# EPOCH[392/1000] loss0.012-|Sample:0.14|
# EPOCH[393/1000] loss0.012-|Sample:0.14|
# EPOCH[394/1000] loss0.012-|Sample:0.14|
# EPOCH[395/1000] loss0.012-|Sample:0.15|
# EPOCH[396/1000] loss0.012-|Sample:0.14|
# EPOCH[397/1000] loss0.012-|Sample:0.15|
# EPOCH[398/1000] loss0.012-|Sample:0.14|
# EPOCH[399/1000] loss0.012-|Sample:0.18|
# EPOCH[400/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05658617]), 'recall': array([0.18319816]), 'ndcg': array([0.15700648])}
# EPOCH[401/1000] loss0.012-|Sample:0.13|
# EPOCH[402/1000] loss0.012-|Sample:0.14|
# EPOCH[403/1000] loss0.012-|Sample:0.14|
# EPOCH[404/1000] loss0.012-|Sample:0.14|
# EPOCH[405/1000] loss0.012-|Sample:0.13|
# EPOCH[406/1000] loss0.012-|Sample:0.14|
# EPOCH[407/1000] loss0.012-|Sample:0.14|
# EPOCH[408/1000] loss0.012-|Sample:0.14|
# EPOCH[409/1000] loss0.012-|Sample:0.13|
# EPOCH[410/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05669]), 'recall': array([0.18356522]), 'ndcg': array([0.15728637])}
# EPOCH[411/1000] loss0.012-|Sample:0.15|
# EPOCH[412/1000] loss0.012-|Sample:0.14|
# EPOCH[413/1000] loss0.012-|Sample:0.13|
# EPOCH[414/1000] loss0.012-|Sample:0.14|
# EPOCH[415/1000] loss0.012-|Sample:0.14|
# EPOCH[416/1000] loss0.012-|Sample:0.14|
# EPOCH[417/1000] loss0.012-|Sample:0.14|
# EPOCH[418/1000] loss0.012-|Sample:0.13|
# EPOCH[419/1000] loss0.012-|Sample:0.14|
# EPOCH[420/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05675028]), 'recall': array([0.18376788]), 'ndcg': array([0.15735971])}
# EPOCH[421/1000] loss0.012-|Sample:0.13|
# EPOCH[422/1000] loss0.012-|Sample:0.20|
# EPOCH[423/1000] loss0.012-|Sample:0.14|
# EPOCH[424/1000] loss0.012-|Sample:0.14|
# EPOCH[425/1000] loss0.012-|Sample:0.15|
# EPOCH[426/1000] loss0.012-|Sample:0.13|
# EPOCH[427/1000] loss0.012-|Sample:0.14|
# EPOCH[428/1000] loss0.012-|Sample:0.14|
# EPOCH[429/1000] loss0.012-|Sample:0.14|
# EPOCH[430/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05669502]), 'recall': array([0.18383251]), 'ndcg': array([0.15745115])}
# EPOCH[431/1000] loss0.012-|Sample:0.13|
# EPOCH[432/1000] loss0.012-|Sample:0.13|
# EPOCH[433/1000] loss0.012-|Sample:0.14|
# EPOCH[434/1000] loss0.012-|Sample:0.14|
# EPOCH[435/1000] loss0.012-|Sample:0.14|
# EPOCH[436/1000] loss0.012-|Sample:0.14|
# EPOCH[437/1000] loss0.012-|Sample:0.14|
# EPOCH[438/1000] loss0.012-|Sample:0.14|
# EPOCH[439/1000] loss0.012-|Sample:0.14|
# EPOCH[440/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05661632]), 'recall': array([0.18359882]), 'ndcg': array([0.15714184])}
# EPOCH[441/1000] loss0.012-|Sample:0.14|
# EPOCH[442/1000] loss0.012-|Sample:0.14|
# EPOCH[443/1000] loss0.012-|Sample:0.14|
# EPOCH[444/1000] loss0.012-|Sample:0.14|
# EPOCH[445/1000] loss0.012-|Sample:0.14|
# EPOCH[446/1000] loss0.012-|Sample:0.13|
# EPOCH[447/1000] loss0.012-|Sample:0.14|
# EPOCH[448/1000] loss0.012-|Sample:0.14|
# EPOCH[449/1000] loss0.012-|Sample:0.14|
# EPOCH[450/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05663474]), 'recall': array([0.18309677]), 'ndcg': array([0.15730801])}
# EPOCH[451/1000] loss0.012-|Sample:0.14|
# EPOCH[452/1000] loss0.012-|Sample:0.14|
# EPOCH[453/1000] loss0.012-|Sample:0.14|
# EPOCH[454/1000] loss0.012-|Sample:0.14|
# EPOCH[455/1000] loss0.012-|Sample:0.14|
# EPOCH[456/1000] loss0.012-|Sample:0.14|
# EPOCH[457/1000] loss0.012-|Sample:0.14|
# EPOCH[458/1000] loss0.012-|Sample:0.14|
# EPOCH[459/1000] loss0.012-|Sample:0.14|
# EPOCH[460/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05657278]), 'recall': array([0.18288218]), 'ndcg': array([0.15711249])}
# EPOCH[461/1000] loss0.012-|Sample:0.15|
# EPOCH[462/1000] loss0.012-|Sample:0.14|
# EPOCH[463/1000] loss0.012-|Sample:0.14|
# EPOCH[464/1000] loss0.012-|Sample:0.14|
# EPOCH[465/1000] loss0.012-|Sample:0.14|
# EPOCH[466/1000] loss0.012-|Sample:0.16|
# EPOCH[467/1000] loss0.012-|Sample:0.16|
# EPOCH[468/1000] loss0.012-|Sample:0.13|
# EPOCH[469/1000] loss0.012-|Sample:0.17|
# EPOCH[470/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05682732]), 'recall': array([0.18390727]), 'ndcg': array([0.15767819])}
# EPOCH[471/1000] loss0.012-|Sample:0.15|
# EPOCH[472/1000] loss0.012-|Sample:0.14|
# EPOCH[473/1000] loss0.012-|Sample:0.14|
# EPOCH[474/1000] loss0.012-|Sample:0.14|
# EPOCH[475/1000] loss0.012-|Sample:0.14|
# EPOCH[476/1000] loss0.012-|Sample:0.14|
# EPOCH[477/1000] loss0.012-|Sample:0.16|
# EPOCH[478/1000] loss0.012-|Sample:0.15|
# EPOCH[479/1000] loss0.012-|Sample:0.12|
# EPOCH[480/1000] loss0.012-|Sample:0.17|
# [TEST]
# {'precision': array([0.05698138]), 'recall': array([0.18419228]), 'ndcg': array([0.15787892])}
# EPOCH[481/1000] loss0.012-|Sample:0.13|
# EPOCH[482/1000] loss0.012-|Sample:0.14|
# EPOCH[483/1000] loss0.012-|Sample:0.14|
# EPOCH[484/1000] loss0.012-|Sample:0.14|
# EPOCH[485/1000] loss0.012-|Sample:0.14|
# EPOCH[486/1000] loss0.012-|Sample:0.14|
# EPOCH[487/1000] loss0.012-|Sample:0.13|
# EPOCH[488/1000] loss0.012-|Sample:0.13|
# EPOCH[489/1000] loss0.012-|Sample:0.14|
# EPOCH[490/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05683234]), 'recall': array([0.18366318]), 'ndcg': array([0.15759994])}
# EPOCH[491/1000] loss0.012-|Sample:0.14|
# EPOCH[492/1000] loss0.012-|Sample:0.13|
# EPOCH[493/1000] loss0.012-|Sample:0.14|
# EPOCH[494/1000] loss0.012-|Sample:0.14|
# EPOCH[495/1000] loss0.012-|Sample:0.15|
# EPOCH[496/1000] loss0.012-|Sample:0.14|
# EPOCH[497/1000] loss0.012-|Sample:0.14|
# EPOCH[498/1000] loss0.012-|Sample:0.14|
# EPOCH[499/1000] loss0.012-|Sample:0.14|
# EPOCH[500/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05682564]), 'recall': array([0.18343447]), 'ndcg': array([0.15784418])}
# EPOCH[501/1000] loss0.012-|Sample:0.13|
# EPOCH[502/1000] loss0.012-|Sample:0.13|
# EPOCH[503/1000] loss0.012-|Sample:0.14|
# EPOCH[504/1000] loss0.012-|Sample:0.14|
# EPOCH[505/1000] loss0.012-|Sample:0.13|
# EPOCH[506/1000] loss0.012-|Sample:0.14|
# EPOCH[507/1000] loss0.012-|Sample:0.14|
# EPOCH[508/1000] loss0.012-|Sample:0.14|
# EPOCH[509/1000] loss0.012-|Sample:0.14|
# EPOCH[510/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05686416]), 'recall': array([0.18400314]), 'ndcg': array([0.15815726])}
# EPOCH[511/1000] loss0.012-|Sample:0.14|
# EPOCH[512/1000] loss0.012-|Sample:0.14|
# EPOCH[513/1000] loss0.012-|Sample:0.14|
# EPOCH[514/1000] loss0.012-|Sample:0.14|
# EPOCH[515/1000] loss0.012-|Sample:0.14|
# EPOCH[516/1000] loss0.012-|Sample:0.25|
# EPOCH[517/1000] loss0.012-|Sample:0.14|
# EPOCH[518/1000] loss0.012-|Sample:0.14|
# EPOCH[519/1000] loss0.012-|Sample:0.14|
# EPOCH[520/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05693449]), 'recall': array([0.18393272]), 'ndcg': array([0.1580342])}
# EPOCH[521/1000] loss0.012-|Sample:0.15|
# EPOCH[522/1000] loss0.012-|Sample:0.14|
# EPOCH[523/1000] loss0.012-|Sample:0.14|
# EPOCH[524/1000] loss0.012-|Sample:0.13|
# EPOCH[525/1000] loss0.012-|Sample:0.14|
# EPOCH[526/1000] loss0.012-|Sample:0.13|
# EPOCH[527/1000] loss0.012-|Sample:0.14|
# EPOCH[528/1000] loss0.012-|Sample:0.14|
# EPOCH[529/1000] loss0.012-|Sample:0.14|
# EPOCH[530/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05678043]), 'recall': array([0.1834839]), 'ndcg': array([0.15749878])}
# EPOCH[531/1000] loss0.012-|Sample:0.15|
# EPOCH[532/1000] loss0.012-|Sample:0.14|
# EPOCH[533/1000] loss0.012-|Sample:0.14|
# EPOCH[534/1000] loss0.012-|Sample:0.13|
# EPOCH[535/1000] loss0.011-|Sample:0.14|
# EPOCH[536/1000] loss0.012-|Sample:0.14|
# EPOCH[537/1000] loss0.012-|Sample:0.14|
# EPOCH[538/1000] loss0.012-|Sample:0.14|
# EPOCH[539/1000] loss0.011-|Sample:0.14|
# EPOCH[540/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05683736]), 'recall': array([0.18340985]), 'ndcg': array([0.15760892])}
# EPOCH[541/1000] loss0.012-|Sample:0.13|
# EPOCH[542/1000] loss0.012-|Sample:0.14|
# EPOCH[543/1000] loss0.012-|Sample:0.13|
# EPOCH[544/1000] loss0.012-|Sample:0.14|
# EPOCH[545/1000] loss0.012-|Sample:0.13|
# EPOCH[546/1000] loss0.012-|Sample:0.14|
# EPOCH[547/1000] loss0.012-|Sample:0.14|
# EPOCH[548/1000] loss0.012-|Sample:0.14|
# EPOCH[549/1000] loss0.012-|Sample:0.14|
# EPOCH[550/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05706678]), 'recall': array([0.18390331]), 'ndcg': array([0.15795566])}
# EPOCH[551/1000] loss0.012-|Sample:0.14|
# EPOCH[552/1000] loss0.011-|Sample:0.14|
# EPOCH[553/1000] loss0.012-|Sample:0.14|
# EPOCH[554/1000] loss0.012-|Sample:0.14|
# EPOCH[555/1000] loss0.011-|Sample:0.14|
# EPOCH[556/1000] loss0.012-|Sample:0.14|
# EPOCH[557/1000] loss0.011-|Sample:0.14|
# EPOCH[558/1000] loss0.012-|Sample:0.14|
# EPOCH[559/1000] loss0.012-|Sample:0.14|
# EPOCH[560/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.0571974]), 'recall': array([0.18428854]), 'ndcg': array([0.15824542])}
# EPOCH[561/1000] loss0.012-|Sample:0.13|
# EPOCH[562/1000] loss0.012-|Sample:0.13|
# EPOCH[563/1000] loss0.012-|Sample:0.13|
# EPOCH[564/1000] loss0.011-|Sample:0.14|
# EPOCH[565/1000] loss0.011-|Sample:0.13|
# EPOCH[566/1000] loss0.012-|Sample:0.14|
# EPOCH[567/1000] loss0.012-|Sample:0.14|
# EPOCH[568/1000] loss0.012-|Sample:0.13|
# EPOCH[569/1000] loss0.011-|Sample:0.14|
# EPOCH[570/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05706511]), 'recall': array([0.18414428]), 'ndcg': array([0.15809989])}
# EPOCH[571/1000] loss0.012-|Sample:0.15|
# EPOCH[572/1000] loss0.012-|Sample:0.14|
# EPOCH[573/1000] loss0.011-|Sample:0.14|
# EPOCH[574/1000] loss0.012-|Sample:0.13|
# EPOCH[575/1000] loss0.012-|Sample:0.14|
# EPOCH[576/1000] loss0.012-|Sample:0.14|
# EPOCH[577/1000] loss0.011-|Sample:0.14|
# EPOCH[578/1000] loss0.012-|Sample:0.14|
# EPOCH[579/1000] loss0.011-|Sample:0.14|
# EPOCH[580/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.0570785]), 'recall': array([0.18411527]), 'ndcg': array([0.15825503])}
# EPOCH[581/1000] loss0.011-|Sample:0.14|
# EPOCH[582/1000] loss0.012-|Sample:0.14|
# EPOCH[583/1000] loss0.011-|Sample:0.24|
# EPOCH[584/1000] loss0.011-|Sample:0.14|
# EPOCH[585/1000] loss0.011-|Sample:0.14|
# EPOCH[586/1000] loss0.011-|Sample:0.14|
# EPOCH[587/1000] loss0.011-|Sample:0.22|
# EPOCH[588/1000] loss0.012-|Sample:0.20|
# EPOCH[589/1000] loss0.012-|Sample:0.13|
# EPOCH[590/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05694119]), 'recall': array([0.1833781]), 'ndcg': array([0.15760902])}
# EPOCH[591/1000] loss0.011-|Sample:0.13|
# EPOCH[592/1000] loss0.011-|Sample:0.14|
# EPOCH[593/1000] loss0.011-|Sample:0.13|
# EPOCH[594/1000] loss0.011-|Sample:0.13|
# EPOCH[595/1000] loss0.011-|Sample:0.16|
# EPOCH[596/1000] loss0.011-|Sample:0.14|
# EPOCH[597/1000] loss0.012-|Sample:0.14|
# EPOCH[598/1000] loss0.011-|Sample:0.14|
# EPOCH[599/1000] loss0.011-|Sample:0.14|
# EPOCH[600/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05696966]), 'recall': array([0.18368614]), 'ndcg': array([0.15780709])}
# EPOCH[601/1000] loss0.012-|Sample:0.13|
# EPOCH[602/1000] loss0.011-|Sample:0.14|
# EPOCH[603/1000] loss0.011-|Sample:0.14|
# EPOCH[604/1000] loss0.011-|Sample:0.13|
# EPOCH[605/1000] loss0.011-|Sample:0.14|
# EPOCH[606/1000] loss0.011-|Sample:0.17|
# EPOCH[607/1000] loss0.011-|Sample:0.14|
# EPOCH[608/1000] loss0.012-|Sample:0.14|
# EPOCH[609/1000] loss0.011-|Sample:0.13|
# EPOCH[610/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.0568943]), 'recall': array([0.18344766]), 'ndcg': array([0.15759175])}
# EPOCH[611/1000] loss0.012-|Sample:0.13|
# EPOCH[612/1000] loss0.012-|Sample:0.13|
# EPOCH[613/1000] loss0.011-|Sample:0.14|
# EPOCH[614/1000] loss0.012-|Sample:0.14|
# EPOCH[615/1000] loss0.011-|Sample:0.14|
# EPOCH[616/1000] loss0.012-|Sample:0.14|
# EPOCH[617/1000] loss0.011-|Sample:0.13|
# EPOCH[618/1000] loss0.011-|Sample:0.14|
# EPOCH[619/1000] loss0.012-|Sample:0.14|
# EPOCH[620/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.0569797]), 'recall': array([0.18411774]), 'ndcg': array([0.15808753])}
# EPOCH[621/1000] loss0.011-|Sample:0.15|
# EPOCH[622/1000] loss0.011-|Sample:0.13|
# EPOCH[623/1000] loss0.011-|Sample:0.14|
# EPOCH[624/1000] loss0.011-|Sample:0.13|
# EPOCH[625/1000] loss0.011-|Sample:0.14|
# EPOCH[626/1000] loss0.011-|Sample:0.14|
# EPOCH[627/1000] loss0.011-|Sample:0.14|
# EPOCH[628/1000] loss0.011-|Sample:0.14|
# EPOCH[629/1000] loss0.012-|Sample:0.14|
# EPOCH[630/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05718735]), 'recall': array([0.18447837]), 'ndcg': array([0.1582475])}
# EPOCH[631/1000] loss0.011-|Sample:0.13|
# EPOCH[632/1000] loss0.011-|Sample:0.14|
# EPOCH[633/1000] loss0.011-|Sample:0.14|
# EPOCH[634/1000] loss0.011-|Sample:0.13|
# EPOCH[635/1000] loss0.011-|Sample:0.13|
# EPOCH[636/1000] loss0.011-|Sample:0.14|
# EPOCH[637/1000] loss0.011-|Sample:0.13|
# EPOCH[638/1000] loss0.011-|Sample:0.14|
# EPOCH[639/1000] loss0.011-|Sample:0.14|
# EPOCH[640/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05724931]), 'recall': array([0.18474392]), 'ndcg': array([0.15862659])}
# EPOCH[641/1000] loss0.011-|Sample:0.13|
# EPOCH[642/1000] loss0.011-|Sample:0.14|
# EPOCH[643/1000] loss0.011-|Sample:0.14|
# EPOCH[644/1000] loss0.011-|Sample:0.14|
# EPOCH[645/1000] loss0.011-|Sample:0.14|
# EPOCH[646/1000] loss0.011-|Sample:0.14|
# EPOCH[647/1000] loss0.011-|Sample:0.14|
# EPOCH[648/1000] loss0.011-|Sample:0.17|
# EPOCH[649/1000] loss0.011-|Sample:0.14|
# EPOCH[650/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05708855]), 'recall': array([0.18396468]), 'ndcg': array([0.15801625])}
# EPOCH[651/1000] loss0.011-|Sample:0.16|
# EPOCH[652/1000] loss0.011-|Sample:0.12|
# EPOCH[653/1000] loss0.011-|Sample:0.13|
# EPOCH[654/1000] loss0.011-|Sample:0.14|
# EPOCH[655/1000] loss0.012-|Sample:0.14|
# EPOCH[656/1000] loss0.011-|Sample:0.14|
# EPOCH[657/1000] loss0.011-|Sample:0.14|
# EPOCH[658/1000] loss0.011-|Sample:0.13|
# EPOCH[659/1000] loss0.012-|Sample:0.14|
# EPOCH[660/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05717228]), 'recall': array([0.18428708]), 'ndcg': array([0.15857042])}
# EPOCH[661/1000] loss0.011-|Sample:0.12|
# EPOCH[662/1000] loss0.011-|Sample:0.13|
# EPOCH[663/1000] loss0.011-|Sample:0.14|
# EPOCH[664/1000] loss0.011-|Sample:0.14|
# EPOCH[665/1000] loss0.011-|Sample:0.14|
# EPOCH[666/1000] loss0.012-|Sample:0.14|
# EPOCH[667/1000] loss0.011-|Sample:0.14|
# EPOCH[668/1000] loss0.011-|Sample:0.14|
# EPOCH[669/1000] loss0.011-|Sample:0.14|
# EPOCH[670/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.057112]), 'recall': array([0.18435488]), 'ndcg': array([0.15833349])}
# EPOCH[671/1000] loss0.011-|Sample:0.12|
# EPOCH[672/1000] loss0.011-|Sample:0.14|
# EPOCH[673/1000] loss0.011-|Sample:0.13|
# EPOCH[674/1000] loss0.011-|Sample:0.14|
# EPOCH[675/1000] loss0.011-|Sample:0.14|
# EPOCH[676/1000] loss0.011-|Sample:0.14|
# EPOCH[677/1000] loss0.011-|Sample:0.14|
# EPOCH[678/1000] loss0.011-|Sample:0.14|
# EPOCH[679/1000] loss0.011-|Sample:0.14|
# EPOCH[680/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05701487]), 'recall': array([0.18392535]), 'ndcg': array([0.15782727])}
# EPOCH[681/1000] loss0.011-|Sample:0.13|
# EPOCH[682/1000] loss0.011-|Sample:0.13|
# EPOCH[683/1000] loss0.011-|Sample:0.14|
# EPOCH[684/1000] loss0.011-|Sample:0.14|
# EPOCH[685/1000] loss0.011-|Sample:0.14|
# EPOCH[686/1000] loss0.011-|Sample:0.14|
# EPOCH[687/1000] loss0.011-|Sample:0.14|
# EPOCH[688/1000] loss0.011-|Sample:0.14|
# EPOCH[689/1000] loss0.011-|Sample:0.13|
# EPOCH[690/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05695459]), 'recall': array([0.18361067]), 'ndcg': array([0.15792175])}
# EPOCH[691/1000] loss0.011-|Sample:0.13|
# EPOCH[692/1000] loss0.011-|Sample:0.14|
# EPOCH[693/1000] loss0.011-|Sample:0.14|
# EPOCH[694/1000] loss0.011-|Sample:0.13|
# EPOCH[695/1000] loss0.011-|Sample:0.14|
# EPOCH[696/1000] loss0.011-|Sample:0.14|
# EPOCH[697/1000] loss0.011-|Sample:0.14|
# EPOCH[698/1000] loss0.011-|Sample:0.14|
# EPOCH[699/1000] loss0.011-|Sample:0.14|
# EPOCH[700/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05700985]), 'recall': array([0.18401349]), 'ndcg': array([0.15797523])}
# EPOCH[701/1000] loss0.011-|Sample:0.15|
# EPOCH[702/1000] loss0.011-|Sample:0.14|
# EPOCH[703/1000] loss0.011-|Sample:0.13|
# EPOCH[704/1000] loss0.011-|Sample:0.14|
# EPOCH[705/1000] loss0.011-|Sample:0.14|
# EPOCH[706/1000] loss0.011-|Sample:0.14|
# EPOCH[707/1000] loss0.011-|Sample:0.14|
# EPOCH[708/1000] loss0.011-|Sample:0.13|
# EPOCH[709/1000] loss0.011-|Sample:0.14|
# EPOCH[710/1000] loss0.011-|Sample:0.18|
# [TEST]
# {'precision': array([0.0571187]), 'recall': array([0.18377339]), 'ndcg': array([0.15807276])}
# EPOCH[711/1000] loss0.011-|Sample:0.13|
# EPOCH[712/1000] loss0.011-|Sample:0.14|
# EPOCH[713/1000] loss0.011-|Sample:0.14|
# EPOCH[714/1000] loss0.011-|Sample:0.13|
# EPOCH[715/1000] loss0.011-|Sample:0.13|
# EPOCH[716/1000] loss0.011-|Sample:0.14|
# EPOCH[717/1000] loss0.011-|Sample:0.14|
# EPOCH[718/1000] loss0.011-|Sample:0.14|
# EPOCH[719/1000] loss0.011-|Sample:0.14|
# EPOCH[720/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05709023]), 'recall': array([0.18372321]), 'ndcg': array([0.1580548])}
# EPOCH[721/1000] loss0.011-|Sample:0.15|
# EPOCH[722/1000] loss0.011-|Sample:0.14|
# EPOCH[723/1000] loss0.011-|Sample:0.14|
# EPOCH[724/1000] loss0.011-|Sample:0.14|
# EPOCH[725/1000] loss0.011-|Sample:0.14|
# EPOCH[726/1000] loss0.011-|Sample:0.14|
# EPOCH[727/1000] loss0.011-|Sample:0.14|
# EPOCH[728/1000] loss0.011-|Sample:0.15|
# EPOCH[729/1000] loss0.011-|Sample:0.14|
# EPOCH[730/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.0571187]), 'recall': array([0.18355356]), 'ndcg': array([0.15821836])}
# EPOCH[731/1000] loss0.011-|Sample:0.13|
# EPOCH[732/1000] loss0.011-|Sample:0.14|
# EPOCH[733/1000] loss0.011-|Sample:0.14|
# EPOCH[734/1000] loss0.011-|Sample:0.13|
# EPOCH[735/1000] loss0.011-|Sample:0.14|
# EPOCH[736/1000] loss0.011-|Sample:0.14|
# EPOCH[737/1000] loss0.011-|Sample:0.14|
# EPOCH[738/1000] loss0.011-|Sample:0.14|
# EPOCH[739/1000] loss0.011-|Sample:0.14|
# EPOCH[740/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05719908]), 'recall': array([0.1843581]), 'ndcg': array([0.158346])}
# EPOCH[741/1000] loss0.011-|Sample:0.16|
# EPOCH[742/1000] loss0.011-|Sample:0.13|
# EPOCH[743/1000] loss0.011-|Sample:0.14|
# EPOCH[744/1000] loss0.011-|Sample:0.14|
# EPOCH[745/1000] loss0.011-|Sample:0.14|
# EPOCH[746/1000] loss0.011-|Sample:0.14|
# EPOCH[747/1000] loss0.011-|Sample:0.13|
# EPOCH[748/1000] loss0.011-|Sample:0.15|
# EPOCH[749/1000] loss0.011-|Sample:0.14|
# EPOCH[750/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05722419]), 'recall': array([0.18455701]), 'ndcg': array([0.15834919])}
# EPOCH[751/1000] loss0.011-|Sample:0.15|
# EPOCH[752/1000] loss0.011-|Sample:0.14|
# EPOCH[753/1000] loss0.011-|Sample:0.14|
# EPOCH[754/1000] loss0.011-|Sample:0.14|
# EPOCH[755/1000] loss0.011-|Sample:0.14|
# EPOCH[756/1000] loss0.011-|Sample:0.14|
# EPOCH[757/1000] loss0.011-|Sample:0.14|
# EPOCH[758/1000] loss0.011-|Sample:0.14|
# EPOCH[759/1000] loss0.011-|Sample:0.14|
# EPOCH[760/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05725936]), 'recall': array([0.18449573]), 'ndcg': array([0.15849353])}
# EPOCH[761/1000] loss0.011-|Sample:0.13|
# EPOCH[762/1000] loss0.011-|Sample:0.13|
# EPOCH[763/1000] loss0.011-|Sample:0.14|
# EPOCH[764/1000] loss0.011-|Sample:0.13|
# EPOCH[765/1000] loss0.011-|Sample:0.14|
# EPOCH[766/1000] loss0.011-|Sample:0.14|
# EPOCH[767/1000] loss0.011-|Sample:0.14|
# EPOCH[768/1000] loss0.011-|Sample:0.13|
# EPOCH[769/1000] loss0.011-|Sample:0.14|
# EPOCH[770/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05736821]), 'recall': array([0.1847677]), 'ndcg': array([0.15873376])}
# EPOCH[771/1000] loss0.011-|Sample:0.14|
# EPOCH[772/1000] loss0.011-|Sample:0.14|
# EPOCH[773/1000] loss0.011-|Sample:0.14|
# EPOCH[774/1000] loss0.011-|Sample:0.14|
# EPOCH[775/1000] loss0.011-|Sample:0.14|
# EPOCH[776/1000] loss0.011-|Sample:0.14|
# EPOCH[777/1000] loss0.011-|Sample:0.14|
# EPOCH[778/1000] loss0.011-|Sample:0.14|
# EPOCH[779/1000] loss0.011-|Sample:0.14|
# EPOCH[780/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05720912]), 'recall': array([0.18430408]), 'ndcg': array([0.15854375])}
# EPOCH[781/1000] loss0.011-|Sample:0.13|
# EPOCH[782/1000] loss0.011-|Sample:0.13|
# EPOCH[783/1000] loss0.011-|Sample:0.14|
# EPOCH[784/1000] loss0.011-|Sample:0.14|
# EPOCH[785/1000] loss0.011-|Sample:0.14|
# EPOCH[786/1000] loss0.011-|Sample:0.14|
# EPOCH[787/1000] loss0.011-|Sample:0.14|
# EPOCH[788/1000] loss0.011-|Sample:0.14|
# EPOCH[789/1000] loss0.011-|Sample:0.14|
# EPOCH[790/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05715386]), 'recall': array([0.18420668]), 'ndcg': array([0.15843021])}
# EPOCH[791/1000] loss0.011-|Sample:0.16|
# EPOCH[792/1000] loss0.011-|Sample:0.13|
# EPOCH[793/1000] loss0.011-|Sample:0.14|
# EPOCH[794/1000] loss0.011-|Sample:0.14|
# EPOCH[795/1000] loss0.011-|Sample:0.14|
# EPOCH[796/1000] loss0.011-|Sample:0.14|
# EPOCH[797/1000] loss0.011-|Sample:0.15|
# EPOCH[798/1000] loss0.011-|Sample:0.14|
# EPOCH[799/1000] loss0.011-|Sample:0.14|
# EPOCH[800/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05723089]), 'recall': array([0.18417088]), 'ndcg': array([0.1584408])}
# EPOCH[801/1000] loss0.011-|Sample:0.14|
# EPOCH[802/1000] loss0.011-|Sample:0.13|
# EPOCH[803/1000] loss0.011-|Sample:0.13|
# EPOCH[804/1000] loss0.011-|Sample:0.14|
# EPOCH[805/1000] loss0.011-|Sample:0.14|
# EPOCH[806/1000] loss0.011-|Sample:0.14|
# EPOCH[807/1000] loss0.011-|Sample:0.14|
# EPOCH[808/1000] loss0.011-|Sample:0.14|
# EPOCH[809/1000] loss0.011-|Sample:0.14|
# EPOCH[810/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05718903]), 'recall': array([0.18401051]), 'ndcg': array([0.15818245])}
# EPOCH[811/1000] loss0.011-|Sample:0.13|
# EPOCH[812/1000] loss0.011-|Sample:0.13|
# EPOCH[813/1000] loss0.011-|Sample:0.14|
# EPOCH[814/1000] loss0.011-|Sample:0.14|
# EPOCH[815/1000] loss0.011-|Sample:0.14|
# EPOCH[816/1000] loss0.011-|Sample:0.13|
# EPOCH[817/1000] loss0.011-|Sample:0.14|
# EPOCH[818/1000] loss0.011-|Sample:0.14|
# EPOCH[819/1000] loss0.011-|Sample:0.14|
# EPOCH[820/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05714214]), 'recall': array([0.18420964]), 'ndcg': array([0.15836648])}
# EPOCH[821/1000] loss0.011-|Sample:0.15|
# EPOCH[822/1000] loss0.011-|Sample:0.14|
# EPOCH[823/1000] loss0.011-|Sample:0.14|
# EPOCH[824/1000] loss0.011-|Sample:0.14|
# EPOCH[825/1000] loss0.011-|Sample:0.14|
# EPOCH[826/1000] loss0.011-|Sample:0.14|
# EPOCH[827/1000] loss0.011-|Sample:0.14|
# EPOCH[828/1000] loss0.011-|Sample:0.14|
# EPOCH[829/1000] loss0.011-|Sample:0.14|
# EPOCH[830/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05730792]), 'recall': array([0.1843303]), 'ndcg': array([0.15839353])}
# EPOCH[831/1000] loss0.011-|Sample:0.13|
# EPOCH[832/1000] loss0.011-|Sample:0.16|
# EPOCH[833/1000] loss0.011-|Sample:0.14|
# EPOCH[834/1000] loss0.011-|Sample:0.13|
# EPOCH[835/1000] loss0.011-|Sample:0.13|
# EPOCH[836/1000] loss0.011-|Sample:0.13|
# EPOCH[837/1000] loss0.011-|Sample:0.14|
# EPOCH[838/1000] loss0.011-|Sample:0.13|
# EPOCH[839/1000] loss0.011-|Sample:0.14|
# EPOCH[840/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05722587]), 'recall': array([0.18432547]), 'ndcg': array([0.15860368])}
# EPOCH[841/1000] loss0.011-|Sample:0.13|
# EPOCH[842/1000] loss0.011-|Sample:0.14|
# EPOCH[843/1000] loss0.011-|Sample:0.14|
# EPOCH[844/1000] loss0.011-|Sample:0.14|
# EPOCH[845/1000] loss0.011-|Sample:0.14|
# EPOCH[846/1000] loss0.011-|Sample:0.14|
# EPOCH[847/1000] loss0.011-|Sample:0.14|
# EPOCH[848/1000] loss0.011-|Sample:0.17|
# EPOCH[849/1000] loss0.011-|Sample:0.17|
# EPOCH[850/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05725936]), 'recall': array([0.18442149]), 'ndcg': array([0.15849782])}
# EPOCH[851/1000] loss0.011-|Sample:0.13|
# EPOCH[852/1000] loss0.011-|Sample:0.14|
# EPOCH[853/1000] loss0.011-|Sample:0.14|
# EPOCH[854/1000] loss0.011-|Sample:0.13|
# EPOCH[855/1000] loss0.011-|Sample:0.14|
# EPOCH[856/1000] loss0.011-|Sample:0.13|
# EPOCH[857/1000] loss0.011-|Sample:0.18|
# EPOCH[858/1000] loss0.011-|Sample:0.14|
# EPOCH[859/1000] loss0.011-|Sample:0.14|
# EPOCH[860/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05717898]), 'recall': array([0.18461463]), 'ndcg': array([0.15848484])}
# EPOCH[861/1000] loss0.011-|Sample:0.14|
# EPOCH[862/1000] loss0.011-|Sample:0.13|
# EPOCH[863/1000] loss0.011-|Sample:0.13|
# EPOCH[864/1000] loss0.011-|Sample:0.14|
# EPOCH[865/1000] loss0.011-|Sample:0.14|
# EPOCH[866/1000] loss0.011-|Sample:0.14|
# EPOCH[867/1000] loss0.011-|Sample:0.14|
# EPOCH[868/1000] loss0.011-|Sample:0.14|
# EPOCH[869/1000] loss0.011-|Sample:0.14|
# EPOCH[870/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05710027]), 'recall': array([0.18426824]), 'ndcg': array([0.15828256])}
# EPOCH[871/1000] loss0.011-|Sample:0.15|
# EPOCH[872/1000] loss0.011-|Sample:0.14|
# EPOCH[873/1000] loss0.011-|Sample:0.14|
# EPOCH[874/1000] loss0.011-|Sample:0.14|
# EPOCH[875/1000] loss0.011-|Sample:0.14|
# EPOCH[876/1000] loss0.011-|Sample:0.13|
# EPOCH[877/1000] loss0.011-|Sample:0.14|
# EPOCH[878/1000] loss0.011-|Sample:0.13|
# EPOCH[879/1000] loss0.011-|Sample:0.14|
# EPOCH[880/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05701989]), 'recall': array([0.18375651]), 'ndcg': array([0.15798274])}
# EPOCH[881/1000] loss0.011-|Sample:0.13|
# EPOCH[882/1000] loss0.011-|Sample:0.14|
# EPOCH[883/1000] loss0.011-|Sample:0.14|
# EPOCH[884/1000] loss0.011-|Sample:0.14|
# EPOCH[885/1000] loss0.011-|Sample:0.14|
# EPOCH[886/1000] loss0.011-|Sample:0.14|
# EPOCH[887/1000] loss0.011-|Sample:0.15|
# EPOCH[888/1000] loss0.011-|Sample:0.14|
# EPOCH[889/1000] loss0.011-|Sample:0.14|
# EPOCH[890/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05709358]), 'recall': array([0.1837718]), 'ndcg': array([0.15808717])}
# EPOCH[891/1000] loss0.011-|Sample:0.14|
# EPOCH[892/1000] loss0.011-|Sample:0.14|
# EPOCH[893/1000] loss0.011-|Sample:0.14|
# EPOCH[894/1000] loss0.011-|Sample:0.16|
# EPOCH[895/1000] loss0.011-|Sample:0.14|
# EPOCH[896/1000] loss0.011-|Sample:0.14|
# EPOCH[897/1000] loss0.011-|Sample:0.14|
# EPOCH[898/1000] loss0.011-|Sample:0.14|
# EPOCH[899/1000] loss0.011-|Sample:0.14|
# EPOCH[900/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05713712]), 'recall': array([0.18408067]), 'ndcg': array([0.1581563])}
# EPOCH[901/1000] loss0.011-|Sample:0.13|
# EPOCH[902/1000] loss0.011-|Sample:0.14|
# EPOCH[903/1000] loss0.011-|Sample:0.14|
# EPOCH[904/1000] loss0.011-|Sample:0.14|
# EPOCH[905/1000] loss0.011-|Sample:0.13|
# EPOCH[906/1000] loss0.011-|Sample:0.14|
# EPOCH[907/1000] loss0.011-|Sample:0.13|
# EPOCH[908/1000] loss0.011-|Sample:0.14|
# EPOCH[909/1000] loss0.011-|Sample:0.14|
# EPOCH[910/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05705674]), 'recall': array([0.18352372]), 'ndcg': array([0.15773575])}
# EPOCH[911/1000] loss0.011-|Sample:0.14|
# EPOCH[912/1000] loss0.011-|Sample:0.14|
# EPOCH[913/1000] loss0.011-|Sample:0.14|
# EPOCH[914/1000] loss0.011-|Sample:0.14|
# EPOCH[915/1000] loss0.011-|Sample:0.14|
# EPOCH[916/1000] loss0.011-|Sample:0.14|
# EPOCH[917/1000] loss0.011-|Sample:0.13|
# EPOCH[918/1000] loss0.011-|Sample:0.14|
# EPOCH[919/1000] loss0.011-|Sample:0.13|
# EPOCH[920/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05699645]), 'recall': array([0.18348572]), 'ndcg': array([0.15775753])}
# EPOCH[921/1000] loss0.011-|Sample:0.15|
# EPOCH[922/1000] loss0.011-|Sample:0.14|
# EPOCH[923/1000] loss0.011-|Sample:0.12|
# EPOCH[924/1000] loss0.011-|Sample:0.14|
# EPOCH[925/1000] loss0.011-|Sample:0.14|
# EPOCH[926/1000] loss0.011-|Sample:0.14|
# EPOCH[927/1000] loss0.011-|Sample:0.14|
# EPOCH[928/1000] loss0.011-|Sample:0.13|
# EPOCH[929/1000] loss0.011-|Sample:0.14|
# EPOCH[930/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05718233]), 'recall': array([0.18390756]), 'ndcg': array([0.15802734])}
# EPOCH[931/1000] loss0.011-|Sample:0.17|
# EPOCH[932/1000] loss0.011-|Sample:0.14|
# EPOCH[933/1000] loss0.011-|Sample:0.14|
# EPOCH[934/1000] loss0.011-|Sample:0.14|
# EPOCH[935/1000] loss0.011-|Sample:0.14|
# EPOCH[936/1000] loss0.011-|Sample:0.14|
# EPOCH[937/1000] loss0.011-|Sample:0.13|
# EPOCH[938/1000] loss0.011-|Sample:0.14|
# EPOCH[939/1000] loss0.011-|Sample:0.14|
# EPOCH[940/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05720242]), 'recall': array([0.18426766]), 'ndcg': array([0.15813476])}
# EPOCH[941/1000] loss0.011-|Sample:0.14|
# EPOCH[942/1000] loss0.011-|Sample:0.14|
# EPOCH[943/1000] loss0.011-|Sample:0.14|
# EPOCH[944/1000] loss0.011-|Sample:0.14|
# EPOCH[945/1000] loss0.011-|Sample:0.14|
# EPOCH[946/1000] loss0.011-|Sample:0.14|
# EPOCH[947/1000] loss0.011-|Sample:0.14|
# EPOCH[948/1000] loss0.011-|Sample:0.14|
# EPOCH[949/1000] loss0.011-|Sample:0.14|
# EPOCH[950/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.0571907]), 'recall': array([0.1842289]), 'ndcg': array([0.1584829])}
# EPOCH[951/1000] loss0.011-|Sample:0.14|
# EPOCH[952/1000] loss0.011-|Sample:0.13|
# EPOCH[953/1000] loss0.011-|Sample:0.14|
# EPOCH[954/1000] loss0.011-|Sample:0.15|
# EPOCH[955/1000] loss0.011-|Sample:0.13|
# EPOCH[956/1000] loss0.011-|Sample:0.17|
# EPOCH[957/1000] loss0.011-|Sample:0.14|
# EPOCH[958/1000] loss0.011-|Sample:0.14|
# EPOCH[959/1000] loss0.011-|Sample:0.14|
# EPOCH[960/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05736319]), 'recall': array([0.18444132]), 'ndcg': array([0.15838604])}
# EPOCH[961/1000] loss0.011-|Sample:0.13|
# EPOCH[962/1000] loss0.011-|Sample:0.14|
# EPOCH[963/1000] loss0.011-|Sample:0.15|
# EPOCH[964/1000] loss0.011-|Sample:0.14|
# EPOCH[965/1000] loss0.011-|Sample:0.14|
# EPOCH[966/1000] loss0.011-|Sample:0.13|
# EPOCH[967/1000] loss0.011-|Sample:0.14|
# EPOCH[968/1000] loss0.011-|Sample:0.13|
# EPOCH[969/1000] loss0.011-|Sample:0.14|
# EPOCH[970/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05720912]), 'recall': array([0.18433019]), 'ndcg': array([0.15820359])}
# EPOCH[971/1000] loss0.011-|Sample:0.16|
# EPOCH[972/1000] loss0.011-|Sample:0.13|
# EPOCH[973/1000] loss0.011-|Sample:0.14|
# EPOCH[974/1000] loss0.011-|Sample:0.14|
# EPOCH[975/1000] loss0.011-|Sample:0.13|
# EPOCH[976/1000] loss0.011-|Sample:0.14|
# EPOCH[977/1000] loss0.011-|Sample:0.14|
# EPOCH[978/1000] loss0.011-|Sample:0.13|
# EPOCH[979/1000] loss0.011-|Sample:0.14|
# EPOCH[980/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05713544]), 'recall': array([0.18416088]), 'ndcg': array([0.1579064])}
# EPOCH[981/1000] loss0.011-|Sample:0.14|
# EPOCH[982/1000] loss0.011-|Sample:0.14|
# EPOCH[983/1000] loss0.011-|Sample:0.14|
# EPOCH[984/1000] loss0.011-|Sample:0.14|
# EPOCH[985/1000] loss0.011-|Sample:0.14|
# EPOCH[986/1000] loss0.011-|Sample:0.14|
# EPOCH[987/1000] loss0.011-|Sample:0.14|
# EPOCH[988/1000] loss0.011-|Sample:0.14|
# EPOCH[989/1000] loss0.011-|Sample:0.14|
# EPOCH[990/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05723592]), 'recall': array([0.18465546]), 'ndcg': array([0.15838729])}
# EPOCH[991/1000] loss0.011-|Sample:0.13|
# EPOCH[992/1000] loss0.011-|Sample:0.13|
# EPOCH[993/1000] loss0.011-|Sample:0.14|
# EPOCH[994/1000] loss0.011-|Sample:0.14|
# EPOCH[995/1000] loss0.011-|Sample:0.14|
# EPOCH[996/1000] loss0.011-|Sample:0.14|
# EPOCH[997/1000] loss0.011-|Sample:0.14|
# EPOCH[998/1000] loss0.011-|Sample:0.14|
# EPOCH[999/1000] loss0.011-|Sample:0.17|
# EPOCH[1000/1000] loss0.011-|Sample:0.12|
