# %%
# %load main.py
import world
import utils
from world import cprint
import torch
import numpy as np
from tensorboardX import SummaryWriter
import time
import Procedure
from os.path import join
# ==============================
utils.set_seed(world.seed)
print(">>SEED:", world.seed)
# ==============================
import register
from register import dataset

Recmodel = register.MODELS[world.model_name](world.config, dataset)
Recmodel = Recmodel.to(world.device)
bpr = utils.BPRLoss(Recmodel, world.config)

weight_file = utils.getFileName()
print(f"load and save to {weight_file}")
if world.LOAD:
    try:
        Recmodel.load_state_dict(torch.load(weight_file,map_location=torch.device('cpu')))
        world.cprint(f"loaded model weights from {weight_file}")
    except FileNotFoundError:
        print(f"{weight_file} not exists, start from beginning")
Neg_k = 1

# init tensorboard
if world.tensorboard:
    w : SummaryWriter = SummaryWriter(
                                    join(world.BOARD_PATH, time.strftime("%m-%d-%Hh%Mm%Ss-") + "-" + world.comment)
                                    )
else:
    w = None
    world.cprint("not enable tensorflowboard")

try:
    for epoch in range(world.TRAIN_epochs):
        start = time.time()
        if epoch %10 == 0:
            cprint("[TEST]")
            Procedure.Test(dataset, Recmodel, epoch, w, world.config['multicore'])
        output_information = Procedure.BPR_train_original(dataset, Recmodel, bpr, epoch, neg_k=Neg_k,w=w)
        print(f'EPOCH[{epoch+1}/{world.TRAIN_epochs}] {output_information}')
        torch.save(Recmodel.state_dict(), weight_file)
finally:
    if world.tensorboard:
        w.close()
# Out:
# >>SEED: 2020
# loading [../data/gowalla]
# 810128 interactions for training
# 217242 interactions for testing
# gowalla Sparsity : 0.0008396216228570436
# gowalla is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'multicore': 1,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 24
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded heterogeneous graph ...
# don't split the matrix
# loading adjacency matrix
# successfully loaded homogeneous graph ...
# don't split the matrix
# loading degree weight
# successfully loaded heterogeneous degree weight ...
# lgn is already to go(dropout:0)
# load and save to /home/user1/Larry/FGCF/runs/code/checkpoints/lgn-gowalla-3-64.pth.tar
# [TEST]
# {'precision': array([0.00022105]), 'recall': array([0.00068232]), 'ndcg': array([0.00044363])}
# EPOCH[1/1000] loss0.538-|Sample:0.13|
# EPOCH[2/1000] loss0.235-|Sample:0.13|
# EPOCH[3/1000] loss0.160-|Sample:0.13|
# EPOCH[4/1000] loss0.128-|Sample:0.15|
# EPOCH[5/1000] loss0.111-|Sample:0.14|
# EPOCH[6/1000] loss0.099-|Sample:0.14|
# EPOCH[7/1000] loss0.091-|Sample:0.14|
# EPOCH[8/1000] loss0.085-|Sample:0.13|
# EPOCH[9/1000] loss0.081-|Sample:0.14|
# EPOCH[10/1000] loss0.076-|Sample:0.13|
# [TEST]
# {'precision': array([0.03711401]), 'recall': array([0.12012407]), 'ndcg': array([0.10152637])}
# EPOCH[11/1000] loss0.072-|Sample:0.13|
# EPOCH[12/1000] loss0.070-|Sample:0.13|
# EPOCH[13/1000] loss0.067-|Sample:0.13|
# EPOCH[14/1000] loss0.065-|Sample:0.14|
# EPOCH[15/1000] loss0.062-|Sample:0.14|
# EPOCH[16/1000] loss0.060-|Sample:0.13|
# EPOCH[17/1000] loss0.058-|Sample:0.14|
# EPOCH[18/1000] loss0.057-|Sample:0.14|
# EPOCH[19/1000] loss0.056-|Sample:0.14|
# EPOCH[20/1000] loss0.054-|Sample:0.14|
# [TEST]
# {'precision': array([0.04052683]), 'recall': array([0.13199124]), 'ndcg': array([0.11058205])}
# EPOCH[21/1000] loss0.053-|Sample:0.14|
# EPOCH[22/1000] loss0.051-|Sample:0.14|
# EPOCH[23/1000] loss0.050-|Sample:0.14|
# EPOCH[24/1000] loss0.049-|Sample:0.14|
# EPOCH[25/1000] loss0.048-|Sample:0.14|
# EPOCH[26/1000] loss0.047-|Sample:0.14|
# EPOCH[27/1000] loss0.046-|Sample:0.14|
# EPOCH[28/1000] loss0.045-|Sample:0.14|
# EPOCH[29/1000] loss0.044-|Sample:0.14|
# EPOCH[30/1000] loss0.044-|Sample:0.14|
# [TEST]
# {'precision': array([0.04298178]), 'recall': array([0.1404196]), 'ndcg': array([0.11801561])}
# EPOCH[31/1000] loss0.042-|Sample:0.14|
# EPOCH[32/1000] loss0.042-|Sample:0.14|
# EPOCH[33/1000] loss0.041-|Sample:0.13|
# EPOCH[34/1000] loss0.041-|Sample:0.14|
# EPOCH[35/1000] loss0.040-|Sample:0.14|
# EPOCH[36/1000] loss0.039-|Sample:0.14|
# EPOCH[37/1000] loss0.038-|Sample:0.14|
# EPOCH[38/1000] loss0.038-|Sample:0.14|
# EPOCH[39/1000] loss0.037-|Sample:0.14|
# EPOCH[40/1000] loss0.037-|Sample:0.14|
# [TEST]
# {'precision': array([0.04475015]), 'recall': array([0.14661548]), 'ndcg': array([0.12335454])}
# EPOCH[41/1000] loss0.036-|Sample:0.13|
# EPOCH[42/1000] loss0.036-|Sample:0.14|
# EPOCH[43/1000] loss0.035-|Sample:0.14|
# EPOCH[44/1000] loss0.035-|Sample:0.15|
# EPOCH[45/1000] loss0.035-|Sample:0.14|
# EPOCH[46/1000] loss0.034-|Sample:0.14|
# EPOCH[47/1000] loss0.034-|Sample:0.13|
# EPOCH[48/1000] loss0.033-|Sample:0.14|
# EPOCH[49/1000] loss0.033-|Sample:0.14|
# EPOCH[50/1000] loss0.032-|Sample:0.14|
# [TEST]
# {'precision': array([0.04601949]), 'recall': array([0.15092728]), 'ndcg': array([0.12731584])}
# EPOCH[51/1000] loss0.032-|Sample:0.14|
# EPOCH[52/1000] loss0.032-|Sample:0.14|
# EPOCH[53/1000] loss0.032-|Sample:0.14|
# EPOCH[54/1000] loss0.031-|Sample:0.14|
# EPOCH[55/1000] loss0.031-|Sample:0.14|
# EPOCH[56/1000] loss0.030-|Sample:0.14|
# EPOCH[57/1000] loss0.030-|Sample:0.14|
# EPOCH[58/1000] loss0.031-|Sample:0.14|
# EPOCH[59/1000] loss0.030-|Sample:0.14|
# EPOCH[60/1000] loss0.029-|Sample:0.14|
# [TEST]
# {'precision': array([0.04722352]), 'recall': array([0.15513394]), 'ndcg': array([0.1306126])}
# EPOCH[61/1000] loss0.029-|Sample:0.14|
# EPOCH[62/1000] loss0.029-|Sample:0.15|
# EPOCH[63/1000] loss0.029-|Sample:0.14|
# EPOCH[64/1000] loss0.028-|Sample:0.14|
# EPOCH[65/1000] loss0.028-|Sample:0.14|
# EPOCH[66/1000] loss0.027-|Sample:0.14|
# EPOCH[67/1000] loss0.028-|Sample:0.14|
# EPOCH[68/1000] loss0.027-|Sample:0.14|
# EPOCH[69/1000] loss0.027-|Sample:0.14|
# EPOCH[70/1000] loss0.027-|Sample:0.14|
# [TEST]
# {'precision': array([0.04810604]), 'recall': array([0.15795388]), 'ndcg': array([0.13319771])}
# EPOCH[71/1000] loss0.027-|Sample:0.13|
# EPOCH[72/1000] loss0.026-|Sample:0.14|
# EPOCH[73/1000] loss0.026-|Sample:0.14|
# EPOCH[74/1000] loss0.026-|Sample:0.14|
# EPOCH[75/1000] loss0.026-|Sample:0.14|
# EPOCH[76/1000] loss0.025-|Sample:0.13|
# EPOCH[77/1000] loss0.025-|Sample:0.13|
# EPOCH[78/1000] loss0.025-|Sample:0.15|
# EPOCH[79/1000] loss0.025-|Sample:0.14|
# EPOCH[80/1000] loss0.025-|Sample:0.13|
# [TEST]
# {'precision': array([0.04889644]), 'recall': array([0.16067773]), 'ndcg': array([0.13554633])}
# EPOCH[81/1000] loss0.024-|Sample:0.13|
# EPOCH[82/1000] loss0.024-|Sample:0.14|
# EPOCH[83/1000] loss0.024-|Sample:0.14|
# EPOCH[84/1000] loss0.024-|Sample:0.14|
# EPOCH[85/1000] loss0.024-|Sample:0.14|
# EPOCH[86/1000] loss0.024-|Sample:0.14|
# EPOCH[87/1000] loss0.023-|Sample:0.14|
# EPOCH[88/1000] loss0.023-|Sample:0.14|
# EPOCH[89/1000] loss0.023-|Sample:0.14|
# EPOCH[90/1000] loss0.023-|Sample:0.14|
# [TEST]
# {'precision': array([0.04972034]), 'recall': array([0.16354896]), 'ndcg': array([0.13798913])}
# EPOCH[91/1000] loss0.023-|Sample:0.14|
# EPOCH[92/1000] loss0.023-|Sample:0.13|
# EPOCH[93/1000] loss0.023-|Sample:0.14|
# EPOCH[94/1000] loss0.022-|Sample:0.13|
# EPOCH[95/1000] loss0.022-|Sample:0.13|
# EPOCH[96/1000] loss0.022-|Sample:0.14|
# EPOCH[97/1000] loss0.022-|Sample:0.14|
# EPOCH[98/1000] loss0.022-|Sample:0.13|
# EPOCH[99/1000] loss0.022-|Sample:0.14|
# EPOCH[100/1000] loss0.022-|Sample:0.13|
# [TEST]
# {'precision': array([0.05028468]), 'recall': array([0.1651662]), 'ndcg': array([0.13955475])}
# EPOCH[101/1000] loss0.021-|Sample:0.13|
# EPOCH[102/1000] loss0.021-|Sample:0.14|
# EPOCH[103/1000] loss0.021-|Sample:0.14|
# EPOCH[104/1000] loss0.021-|Sample:0.14|
# EPOCH[105/1000] loss0.021-|Sample:0.14|
# EPOCH[106/1000] loss0.021-|Sample:0.13|
# EPOCH[107/1000] loss0.021-|Sample:0.14|
# EPOCH[108/1000] loss0.021-|Sample:0.14|
# EPOCH[109/1000] loss0.020-|Sample:0.14|
# EPOCH[110/1000] loss0.020-|Sample:0.14|
# [TEST]
# {'precision': array([0.05098801]), 'recall': array([0.16737505]), 'ndcg': array([0.14150087])}
# EPOCH[111/1000] loss0.020-|Sample:0.14|
# EPOCH[112/1000] loss0.020-|Sample:0.14|
# EPOCH[113/1000] loss0.020-|Sample:0.14|
# EPOCH[114/1000] loss0.020-|Sample:0.14|
# EPOCH[115/1000] loss0.020-|Sample:0.13|
# EPOCH[116/1000] loss0.020-|Sample:0.14|
# EPOCH[117/1000] loss0.020-|Sample:0.13|
# EPOCH[118/1000] loss0.019-|Sample:0.13|
# EPOCH[119/1000] loss0.020-|Sample:0.14|
# EPOCH[120/1000] loss0.019-|Sample:0.14|
# [TEST]
# {'precision': array([0.05148369]), 'recall': array([0.16900543]), 'ndcg': array([0.14308047])}
# EPOCH[121/1000] loss0.019-|Sample:0.14|
# EPOCH[122/1000] loss0.019-|Sample:0.14|
# EPOCH[123/1000] loss0.019-|Sample:0.14|
# EPOCH[124/1000] loss0.019-|Sample:0.13|
# EPOCH[125/1000] loss0.019-|Sample:0.14|
# EPOCH[126/1000] loss0.019-|Sample:0.14|
# EPOCH[127/1000] loss0.019-|Sample:0.14|
# EPOCH[128/1000] loss0.019-|Sample:0.14|
# EPOCH[129/1000] loss0.018-|Sample:0.14|
# EPOCH[130/1000] loss0.019-|Sample:0.14|
# [TEST]
# {'precision': array([0.05197435]), 'recall': array([0.17013859]), 'ndcg': array([0.14434675])}
# EPOCH[131/1000] loss0.019-|Sample:0.13|
# EPOCH[132/1000] loss0.018-|Sample:0.14|
# EPOCH[133/1000] loss0.018-|Sample:0.14|
# EPOCH[134/1000] loss0.018-|Sample:0.14|
# EPOCH[135/1000] loss0.018-|Sample:0.14|
# EPOCH[136/1000] loss0.018-|Sample:0.14|
# EPOCH[137/1000] loss0.018-|Sample:0.14|
# EPOCH[138/1000] loss0.018-|Sample:0.14|
# EPOCH[139/1000] loss0.018-|Sample:0.14|
# EPOCH[140/1000] loss0.018-|Sample:0.13|
# [TEST]
# {'precision': array([0.052465]), 'recall': array([0.17182846]), 'ndcg': array([0.14537775])}
# EPOCH[141/1000] loss0.018-|Sample:0.13|
# EPOCH[142/1000] loss0.018-|Sample:0.14|
# EPOCH[143/1000] loss0.018-|Sample:0.14|
# EPOCH[144/1000] loss0.018-|Sample:0.14|
# EPOCH[145/1000] loss0.017-|Sample:0.14|
# EPOCH[146/1000] loss0.017-|Sample:0.14|
# EPOCH[147/1000] loss0.017-|Sample:0.14|
# EPOCH[148/1000] loss0.017-|Sample:0.14|
# EPOCH[149/1000] loss0.017-|Sample:0.14|
# EPOCH[150/1000] loss0.017-|Sample:0.13|
# [TEST]
# {'precision': array([0.05287025]), 'recall': array([0.17303098]), 'ndcg': array([0.14668416])}
# EPOCH[151/1000] loss0.017-|Sample:0.14|
# EPOCH[152/1000] loss0.017-|Sample:0.14|
# EPOCH[153/1000] loss0.017-|Sample:0.14|
# EPOCH[154/1000] loss0.017-|Sample:0.14|
# EPOCH[155/1000] loss0.017-|Sample:0.14|
# EPOCH[156/1000] loss0.017-|Sample:0.14|
# EPOCH[157/1000] loss0.017-|Sample:0.14|
# EPOCH[158/1000] loss0.017-|Sample:0.14|
# EPOCH[159/1000] loss0.017-|Sample:0.14|
# EPOCH[160/1000] loss0.016-|Sample:0.14|
# [TEST]
# {'precision': array([0.05307623]), 'recall': array([0.17332858]), 'ndcg': array([0.14715415])}
# EPOCH[161/1000] loss0.016-|Sample:0.13|
# EPOCH[162/1000] loss0.016-|Sample:0.13|
# EPOCH[163/1000] loss0.016-|Sample:0.14|
# EPOCH[164/1000] loss0.017-|Sample:0.14|
# EPOCH[165/1000] loss0.016-|Sample:0.13|
# EPOCH[166/1000] loss0.016-|Sample:0.13|
# EPOCH[167/1000] loss0.017-|Sample:0.14|
# EPOCH[168/1000] loss0.016-|Sample:0.14|
# EPOCH[169/1000] loss0.016-|Sample:0.14|
# EPOCH[170/1000] loss0.016-|Sample:0.14|
# [TEST]
# {'precision': array([0.05352502]), 'recall': array([0.17505291]), 'ndcg': array([0.14838334])}
# EPOCH[171/1000] loss0.016-|Sample:0.13|
# EPOCH[172/1000] loss0.016-|Sample:0.14|
# EPOCH[173/1000] loss0.016-|Sample:0.14|
# EPOCH[174/1000] loss0.016-|Sample:0.14|
# EPOCH[175/1000] loss0.016-|Sample:0.14|
# EPOCH[176/1000] loss0.016-|Sample:0.14|
# EPOCH[177/1000] loss0.016-|Sample:0.14|
# EPOCH[178/1000] loss0.016-|Sample:0.14|
# EPOCH[179/1000] loss0.016-|Sample:0.14|
# EPOCH[180/1000] loss0.016-|Sample:0.14|
# [TEST]
# {'precision': array([0.05395037]), 'recall': array([0.17677441]), 'ndcg': array([0.14969557])}
# EPOCH[181/1000] loss0.016-|Sample:0.16|
# EPOCH[182/1000] loss0.015-|Sample:0.14|
# EPOCH[183/1000] loss0.016-|Sample:0.13|
# EPOCH[184/1000] loss0.016-|Sample:0.14|
# EPOCH[185/1000] loss0.016-|Sample:0.14|
# EPOCH[186/1000] loss0.015-|Sample:0.14|
# EPOCH[187/1000] loss0.016-|Sample:0.14|
# EPOCH[188/1000] loss0.015-|Sample:0.14|
# EPOCH[189/1000] loss0.015-|Sample:0.13|
# EPOCH[190/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.05401233]), 'recall': array([0.17653]), 'ndcg': array([0.14997272])}
# EPOCH[191/1000] loss0.015-|Sample:0.16|
# EPOCH[192/1000] loss0.015-|Sample:0.13|
# EPOCH[193/1000] loss0.015-|Sample:0.14|
# EPOCH[194/1000] loss0.015-|Sample:0.13|
# EPOCH[195/1000] loss0.015-|Sample:0.14|
# EPOCH[196/1000] loss0.015-|Sample:0.13|
# EPOCH[197/1000] loss0.015-|Sample:0.13|
# EPOCH[198/1000] loss0.015-|Sample:0.14|
# EPOCH[199/1000] loss0.015-|Sample:0.14|
# EPOCH[200/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.0543372]), 'recall': array([0.17746192]), 'ndcg': array([0.15084681])}
# EPOCH[201/1000] loss0.015-|Sample:0.14|
# EPOCH[202/1000] loss0.015-|Sample:0.14|
# EPOCH[203/1000] loss0.015-|Sample:0.14|
# EPOCH[204/1000] loss0.015-|Sample:0.14|
# EPOCH[205/1000] loss0.015-|Sample:0.19|
# EPOCH[206/1000] loss0.015-|Sample:0.14|
# EPOCH[207/1000] loss0.015-|Sample:0.13|
# EPOCH[208/1000] loss0.015-|Sample:0.14|
# EPOCH[209/1000] loss0.015-|Sample:0.14|
# EPOCH[210/1000] loss0.015-|Sample:0.14|
# [TEST]
# {'precision': array([0.05466207]), 'recall': array([0.17849686]), 'ndcg': array([0.15171889])}
# EPOCH[211/1000] loss0.015-|Sample:0.15|
# EPOCH[212/1000] loss0.015-|Sample:0.14|
# EPOCH[213/1000] loss0.014-|Sample:0.14|
# EPOCH[214/1000] loss0.014-|Sample:0.14|
# EPOCH[215/1000] loss0.015-|Sample:0.14|
# EPOCH[216/1000] loss0.014-|Sample:0.14|
# EPOCH[217/1000] loss0.014-|Sample:0.14|
# EPOCH[218/1000] loss0.015-|Sample:0.14|
# EPOCH[219/1000] loss0.014-|Sample:0.14|
# EPOCH[220/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05488981]), 'recall': array([0.17935289]), 'ndcg': array([0.15237986])}
# EPOCH[221/1000] loss0.014-|Sample:0.13|
# EPOCH[222/1000] loss0.014-|Sample:0.14|
# EPOCH[223/1000] loss0.014-|Sample:0.14|
# EPOCH[224/1000] loss0.014-|Sample:0.14|
# EPOCH[225/1000] loss0.014-|Sample:0.14|
# EPOCH[226/1000] loss0.014-|Sample:0.14|
# EPOCH[227/1000] loss0.014-|Sample:0.14|
# EPOCH[228/1000] loss0.014-|Sample:0.14|
# EPOCH[229/1000] loss0.014-|Sample:0.14|
# EPOCH[230/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05496349]), 'recall': array([0.17942894]), 'ndcg': array([0.15292972])}
# EPOCH[231/1000] loss0.014-|Sample:0.13|
# EPOCH[232/1000] loss0.014-|Sample:0.18|
# EPOCH[233/1000] loss0.014-|Sample:0.14|
# EPOCH[234/1000] loss0.014-|Sample:0.13|
# EPOCH[235/1000] loss0.014-|Sample:0.14|
# EPOCH[236/1000] loss0.014-|Sample:0.14|
# EPOCH[237/1000] loss0.014-|Sample:0.14|
# EPOCH[238/1000] loss0.014-|Sample:0.14|
# EPOCH[239/1000] loss0.014-|Sample:0.13|
# EPOCH[240/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05520798]), 'recall': array([0.18029439]), 'ndcg': array([0.1534306])}
# EPOCH[241/1000] loss0.014-|Sample:0.14|
# EPOCH[242/1000] loss0.014-|Sample:0.14|
# EPOCH[243/1000] loss0.014-|Sample:0.14|
# EPOCH[244/1000] loss0.014-|Sample:0.13|
# EPOCH[245/1000] loss0.014-|Sample:0.14|
# EPOCH[246/1000] loss0.014-|Sample:0.14|
# EPOCH[247/1000] loss0.014-|Sample:0.14|
# EPOCH[248/1000] loss0.014-|Sample:0.14|
# EPOCH[249/1000] loss0.014-|Sample:0.14|
# EPOCH[250/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05527162]), 'recall': array([0.18049461]), 'ndcg': array([0.1537105])}
# EPOCH[251/1000] loss0.014-|Sample:0.13|
# EPOCH[252/1000] loss0.014-|Sample:0.13|
# EPOCH[253/1000] loss0.014-|Sample:0.14|
# EPOCH[254/1000] loss0.014-|Sample:0.14|
# EPOCH[255/1000] loss0.013-|Sample:0.13|
# EPOCH[256/1000] loss0.014-|Sample:0.14|
# EPOCH[257/1000] loss0.014-|Sample:0.14|
# EPOCH[258/1000] loss0.013-|Sample:0.14|
# EPOCH[259/1000] loss0.014-|Sample:0.14|
# EPOCH[260/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05549434]), 'recall': array([0.18086655]), 'ndcg': array([0.15425152])}
# EPOCH[261/1000] loss0.014-|Sample:0.14|
# EPOCH[262/1000] loss0.014-|Sample:0.13|
# EPOCH[263/1000] loss0.014-|Sample:0.14|
# EPOCH[264/1000] loss0.013-|Sample:0.14|
# EPOCH[265/1000] loss0.013-|Sample:0.14|
# EPOCH[266/1000] loss0.014-|Sample:0.14|
# EPOCH[267/1000] loss0.013-|Sample:0.14|
# EPOCH[268/1000] loss0.013-|Sample:0.14|
# EPOCH[269/1000] loss0.013-|Sample:0.14|
# EPOCH[270/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05557305]), 'recall': array([0.18126591]), 'ndcg': array([0.15461606])}
# EPOCH[271/1000] loss0.013-|Sample:0.13|
# EPOCH[272/1000] loss0.013-|Sample:0.14|
# EPOCH[273/1000] loss0.013-|Sample:0.14|
# EPOCH[274/1000] loss0.013-|Sample:0.14|
# EPOCH[275/1000] loss0.013-|Sample:0.14|
# EPOCH[276/1000] loss0.013-|Sample:0.13|
# EPOCH[277/1000] loss0.013-|Sample:0.14|
# EPOCH[278/1000] loss0.013-|Sample:0.14|
# EPOCH[279/1000] loss0.013-|Sample:0.14|
# EPOCH[280/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05551443]), 'recall': array([0.18082037]), 'ndcg': array([0.15439567])}
# EPOCH[281/1000] loss0.013-|Sample:0.13|
# EPOCH[282/1000] loss0.013-|Sample:0.13|
# EPOCH[283/1000] loss0.013-|Sample:0.15|
# EPOCH[284/1000] loss0.013-|Sample:0.14|
# EPOCH[285/1000] loss0.013-|Sample:0.13|
# EPOCH[286/1000] loss0.013-|Sample:0.14|
# EPOCH[287/1000] loss0.013-|Sample:0.14|
# EPOCH[288/1000] loss0.013-|Sample:0.14|
# EPOCH[289/1000] loss0.013-|Sample:0.13|
# EPOCH[290/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05556635]), 'recall': array([0.18117845]), 'ndcg': array([0.15478339])}
# EPOCH[291/1000] loss0.013-|Sample:0.16|
# EPOCH[292/1000] loss0.013-|Sample:0.14|
# EPOCH[293/1000] loss0.013-|Sample:0.14|
# EPOCH[294/1000] loss0.013-|Sample:0.14|
# EPOCH[295/1000] loss0.013-|Sample:0.14|
# EPOCH[296/1000] loss0.013-|Sample:0.14|
# EPOCH[297/1000] loss0.013-|Sample:0.14|
# EPOCH[298/1000] loss0.013-|Sample:0.14|
# EPOCH[299/1000] loss0.013-|Sample:0.14|
# EPOCH[300/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05570366]), 'recall': array([0.18156683]), 'ndcg': array([0.15503981])}
# EPOCH[301/1000] loss0.013-|Sample:0.15|
# EPOCH[302/1000] loss0.013-|Sample:0.13|
# EPOCH[303/1000] loss0.013-|Sample:0.14|
# EPOCH[304/1000] loss0.013-|Sample:0.12|
# EPOCH[305/1000] loss0.013-|Sample:0.14|
# EPOCH[306/1000] loss0.013-|Sample:0.14|
# EPOCH[307/1000] loss0.013-|Sample:0.14|
# EPOCH[308/1000] loss0.013-|Sample:0.14|
# EPOCH[309/1000] loss0.013-|Sample:0.14|
# EPOCH[310/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05594146]), 'recall': array([0.1823727]), 'ndcg': array([0.15544846])}
# EPOCH[311/1000] loss0.013-|Sample:0.13|
# EPOCH[312/1000] loss0.013-|Sample:0.14|
# EPOCH[313/1000] loss0.013-|Sample:0.14|
# EPOCH[314/1000] loss0.013-|Sample:0.14|
# EPOCH[315/1000] loss0.013-|Sample:0.13|
# EPOCH[316/1000] loss0.013-|Sample:0.14|
# EPOCH[317/1000] loss0.013-|Sample:0.14|
# EPOCH[318/1000] loss0.013-|Sample:0.14|
# EPOCH[319/1000] loss0.013-|Sample:0.14|
# EPOCH[320/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05588619]), 'recall': array([0.18210064]), 'ndcg': array([0.1552298])}
# EPOCH[321/1000] loss0.013-|Sample:0.13|
# EPOCH[322/1000] loss0.013-|Sample:0.13|
# EPOCH[323/1000] loss0.013-|Sample:0.13|
# EPOCH[324/1000] loss0.013-|Sample:0.14|
# EPOCH[325/1000] loss0.013-|Sample:0.14|
# EPOCH[326/1000] loss0.013-|Sample:0.14|
# EPOCH[327/1000] loss0.013-|Sample:0.14|
# EPOCH[328/1000] loss0.013-|Sample:0.14|
# EPOCH[329/1000] loss0.013-|Sample:0.14|
# EPOCH[330/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.055985]), 'recall': array([0.18220053]), 'ndcg': array([0.15528106])}
# EPOCH[331/1000] loss0.013-|Sample:0.13|
# EPOCH[332/1000] loss0.013-|Sample:0.14|
# EPOCH[333/1000] loss0.013-|Sample:0.14|
# EPOCH[334/1000] loss0.013-|Sample:0.14|
# EPOCH[335/1000] loss0.012-|Sample:0.14|
# EPOCH[336/1000] loss0.013-|Sample:0.13|
# EPOCH[337/1000] loss0.013-|Sample:0.14|
# EPOCH[338/1000] loss0.013-|Sample:0.14|
# EPOCH[339/1000] loss0.013-|Sample:0.14|
# EPOCH[340/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05599839]), 'recall': array([0.18240696]), 'ndcg': array([0.15560854])}
# EPOCH[341/1000] loss0.012-|Sample:0.15|
# EPOCH[342/1000] loss0.012-|Sample:0.14|
# EPOCH[343/1000] loss0.013-|Sample:0.14|
# EPOCH[344/1000] loss0.012-|Sample:0.14|
# EPOCH[345/1000] loss0.013-|Sample:0.14|
# EPOCH[346/1000] loss0.013-|Sample:0.14|
# EPOCH[347/1000] loss0.012-|Sample:0.14|
# EPOCH[348/1000] loss0.013-|Sample:0.14|
# EPOCH[349/1000] loss0.012-|Sample:0.14|
# EPOCH[350/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05610557]), 'recall': array([0.18280976]), 'ndcg': array([0.15581082])}
# EPOCH[351/1000] loss0.012-|Sample:0.14|
# EPOCH[352/1000] loss0.012-|Sample:0.14|
# EPOCH[353/1000] loss0.012-|Sample:0.14|
# EPOCH[354/1000] loss0.012-|Sample:0.19|
# EPOCH[355/1000] loss0.012-|Sample:0.13|
# EPOCH[356/1000] loss0.012-|Sample:0.17|
# EPOCH[357/1000] loss0.012-|Sample:0.14|
# EPOCH[358/1000] loss0.012-|Sample:0.14|
# EPOCH[359/1000] loss0.012-|Sample:0.14|
# EPOCH[360/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05634503]), 'recall': array([0.18371803]), 'ndcg': array([0.15633536])}
# EPOCH[361/1000] loss0.012-|Sample:0.14|
# EPOCH[362/1000] loss0.013-|Sample:0.15|
# EPOCH[363/1000] loss0.012-|Sample:0.14|
# EPOCH[364/1000] loss0.012-|Sample:0.14|
# EPOCH[365/1000] loss0.012-|Sample:0.14|
# EPOCH[366/1000] loss0.012-|Sample:0.14|
# EPOCH[367/1000] loss0.013-|Sample:0.14|
# EPOCH[368/1000] loss0.012-|Sample:0.14|
# EPOCH[369/1000] loss0.012-|Sample:0.14|
# EPOCH[370/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05642541]), 'recall': array([0.18368928]), 'ndcg': array([0.15638163])}
# EPOCH[371/1000] loss0.012-|Sample:0.13|
# EPOCH[372/1000] loss0.012-|Sample:0.14|
# EPOCH[373/1000] loss0.012-|Sample:0.14|
# EPOCH[374/1000] loss0.012-|Sample:0.14|
# EPOCH[375/1000] loss0.012-|Sample:0.14|
# EPOCH[376/1000] loss0.012-|Sample:0.14|
# EPOCH[377/1000] loss0.013-|Sample:0.14|
# EPOCH[378/1000] loss0.012-|Sample:0.14|
# EPOCH[379/1000] loss0.012-|Sample:0.14|
# EPOCH[380/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05640532]), 'recall': array([0.18370625]), 'ndcg': array([0.15641298])}
# EPOCH[381/1000] loss0.012-|Sample:0.14|
# EPOCH[382/1000] loss0.012-|Sample:0.14|
# EPOCH[383/1000] loss0.012-|Sample:0.13|
# EPOCH[384/1000] loss0.012-|Sample:0.14|
# EPOCH[385/1000] loss0.012-|Sample:0.14|
# EPOCH[386/1000] loss0.012-|Sample:0.14|
# EPOCH[387/1000] loss0.012-|Sample:0.14|
# EPOCH[388/1000] loss0.012-|Sample:0.14|
# EPOCH[389/1000] loss0.012-|Sample:0.13|
# EPOCH[390/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05644048]), 'recall': array([0.18380118]), 'ndcg': array([0.15667607])}
# EPOCH[391/1000] loss0.012-|Sample:0.17|
# EPOCH[392/1000] loss0.012-|Sample:0.18|
# EPOCH[393/1000] loss0.012-|Sample:0.14|
# EPOCH[394/1000] loss0.012-|Sample:0.14|
# EPOCH[395/1000] loss0.012-|Sample:0.14|
# EPOCH[396/1000] loss0.012-|Sample:0.13|
# EPOCH[397/1000] loss0.012-|Sample:0.14|
# EPOCH[398/1000] loss0.012-|Sample:0.14|
# EPOCH[399/1000] loss0.012-|Sample:0.14|
# EPOCH[400/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05647733]), 'recall': array([0.18373556]), 'ndcg': array([0.15660698])}
# EPOCH[401/1000] loss0.012-|Sample:0.14|
# EPOCH[402/1000] loss0.012-|Sample:0.13|
# EPOCH[403/1000] loss0.012-|Sample:0.13|
# EPOCH[404/1000] loss0.012-|Sample:0.14|
# EPOCH[405/1000] loss0.012-|Sample:0.14|
# EPOCH[406/1000] loss0.012-|Sample:0.13|
# EPOCH[407/1000] loss0.012-|Sample:0.13|
# EPOCH[408/1000] loss0.012-|Sample:0.14|
# EPOCH[409/1000] loss0.012-|Sample:0.14|
# EPOCH[410/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05651249]), 'recall': array([0.18417261]), 'ndcg': array([0.15691964])}
# EPOCH[411/1000] loss0.012-|Sample:0.15|
# EPOCH[412/1000] loss0.012-|Sample:0.13|
# EPOCH[413/1000] loss0.012-|Sample:0.13|
# EPOCH[414/1000] loss0.012-|Sample:0.14|
# EPOCH[415/1000] loss0.012-|Sample:0.14|
# EPOCH[416/1000] loss0.012-|Sample:0.14|
# EPOCH[417/1000] loss0.012-|Sample:0.14|
# EPOCH[418/1000] loss0.012-|Sample:0.14|
# EPOCH[419/1000] loss0.012-|Sample:0.14|
# EPOCH[420/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05662971]), 'recall': array([0.18429876]), 'ndcg': array([0.15680413])}
# EPOCH[421/1000] loss0.012-|Sample:0.13|
# EPOCH[422/1000] loss0.012-|Sample:0.14|
# EPOCH[423/1000] loss0.012-|Sample:0.13|
# EPOCH[424/1000] loss0.012-|Sample:0.14|
# EPOCH[425/1000] loss0.012-|Sample:0.14|
# EPOCH[426/1000] loss0.012-|Sample:0.14|
# EPOCH[427/1000] loss0.012-|Sample:0.14|
# EPOCH[428/1000] loss0.012-|Sample:0.14|
# EPOCH[429/1000] loss0.012-|Sample:0.14|
# EPOCH[430/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05667158]), 'recall': array([0.18464402]), 'ndcg': array([0.15707863])}
# EPOCH[431/1000] loss0.012-|Sample:0.15|
# EPOCH[432/1000] loss0.012-|Sample:0.14|
# EPOCH[433/1000] loss0.012-|Sample:0.13|
# EPOCH[434/1000] loss0.012-|Sample:0.13|
# EPOCH[435/1000] loss0.012-|Sample:0.13|
# EPOCH[436/1000] loss0.012-|Sample:0.14|
# EPOCH[437/1000] loss0.012-|Sample:0.13|
# EPOCH[438/1000] loss0.012-|Sample:0.14|
# EPOCH[439/1000] loss0.012-|Sample:0.14|
# EPOCH[440/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05663139]), 'recall': array([0.18449116]), 'ndcg': array([0.15691854])}
# EPOCH[441/1000] loss0.012-|Sample:0.14|
# EPOCH[442/1000] loss0.012-|Sample:0.14|
# EPOCH[443/1000] loss0.012-|Sample:0.14|
# EPOCH[444/1000] loss0.012-|Sample:0.13|
# EPOCH[445/1000] loss0.012-|Sample:0.14|
# EPOCH[446/1000] loss0.012-|Sample:0.14|
# EPOCH[447/1000] loss0.012-|Sample:0.14|
# EPOCH[448/1000] loss0.012-|Sample:0.13|
# EPOCH[449/1000] loss0.012-|Sample:0.14|
# EPOCH[450/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05676871]), 'recall': array([0.18449839]), 'ndcg': array([0.15708193])}
# EPOCH[451/1000] loss0.012-|Sample:0.13|
# EPOCH[452/1000] loss0.012-|Sample:0.14|
# EPOCH[453/1000] loss0.012-|Sample:0.14|
# EPOCH[454/1000] loss0.012-|Sample:0.14|
# EPOCH[455/1000] loss0.012-|Sample:0.14|
# EPOCH[456/1000] loss0.012-|Sample:0.14|
# EPOCH[457/1000] loss0.012-|Sample:0.14|
# EPOCH[458/1000] loss0.012-|Sample:0.14|
# EPOCH[459/1000] loss0.012-|Sample:0.13|
# EPOCH[460/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05668498]), 'recall': array([0.18429851]), 'ndcg': array([0.1567806])}
# EPOCH[461/1000] loss0.012-|Sample:0.16|
# EPOCH[462/1000] loss0.012-|Sample:0.13|
# EPOCH[463/1000] loss0.012-|Sample:0.14|
# EPOCH[464/1000] loss0.012-|Sample:0.15|
# EPOCH[465/1000] loss0.012-|Sample:0.14|
# EPOCH[466/1000] loss0.012-|Sample:0.14|
# EPOCH[467/1000] loss0.012-|Sample:0.13|
# EPOCH[468/1000] loss0.012-|Sample:0.16|
# EPOCH[469/1000] loss0.012-|Sample:0.16|
# EPOCH[470/1000] loss0.012-|Sample:0.16|
# [TEST]
# {'precision': array([0.05679717]), 'recall': array([0.18478481]), 'ndcg': array([0.15707388])}
# EPOCH[471/1000] loss0.012-|Sample:0.13|
# EPOCH[472/1000] loss0.012-|Sample:0.14|
# EPOCH[473/1000] loss0.012-|Sample:0.14|
# EPOCH[474/1000] loss0.012-|Sample:0.14|
# EPOCH[475/1000] loss0.012-|Sample:0.14|
# EPOCH[476/1000] loss0.012-|Sample:0.14|
# EPOCH[477/1000] loss0.012-|Sample:0.13|
# EPOCH[478/1000] loss0.012-|Sample:0.14|
# EPOCH[479/1000] loss0.012-|Sample:0.14|
# EPOCH[480/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05693951]), 'recall': array([0.18513899]), 'ndcg': array([0.15743214])}
# EPOCH[481/1000] loss0.012-|Sample:0.14|
# EPOCH[482/1000] loss0.012-|Sample:0.14|
# EPOCH[483/1000] loss0.012-|Sample:0.14|
# EPOCH[484/1000] loss0.012-|Sample:0.14|
# EPOCH[485/1000] loss0.012-|Sample:0.14|
# EPOCH[486/1000] loss0.012-|Sample:0.13|
# EPOCH[487/1000] loss0.012-|Sample:0.14|
# EPOCH[488/1000] loss0.012-|Sample:0.14|
# EPOCH[489/1000] loss0.012-|Sample:0.14|
# EPOCH[490/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.0569864]), 'recall': array([0.18543659]), 'ndcg': array([0.15765189])}
# EPOCH[491/1000] loss0.012-|Sample:0.15|
# EPOCH[492/1000] loss0.012-|Sample:0.14|
# EPOCH[493/1000] loss0.012-|Sample:0.14|
# EPOCH[494/1000] loss0.012-|Sample:0.14|
# EPOCH[495/1000] loss0.012-|Sample:0.14|
# EPOCH[496/1000] loss0.012-|Sample:0.14|
# EPOCH[497/1000] loss0.012-|Sample:0.14|
# EPOCH[498/1000] loss0.012-|Sample:0.13|
# EPOCH[499/1000] loss0.012-|Sample:0.14|
# EPOCH[500/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05706511]), 'recall': array([0.18536611]), 'ndcg': array([0.15793584])}
# EPOCH[501/1000] loss0.012-|Sample:0.15|
# EPOCH[502/1000] loss0.012-|Sample:0.13|
# EPOCH[503/1000] loss0.012-|Sample:0.14|
# EPOCH[504/1000] loss0.012-|Sample:0.13|
# EPOCH[505/1000] loss0.011-|Sample:0.14|
# EPOCH[506/1000] loss0.012-|Sample:0.14|
# EPOCH[507/1000] loss0.012-|Sample:0.14|
# EPOCH[508/1000] loss0.012-|Sample:0.14|
# EPOCH[509/1000] loss0.012-|Sample:0.14|
# EPOCH[510/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05699645]), 'recall': array([0.18504602]), 'ndcg': array([0.15773015])}
# EPOCH[511/1000] loss0.012-|Sample:0.13|
# EPOCH[512/1000] loss0.012-|Sample:0.13|
# EPOCH[513/1000] loss0.011-|Sample:0.13|
# EPOCH[514/1000] loss0.012-|Sample:0.14|
# EPOCH[515/1000] loss0.012-|Sample:0.14|
# EPOCH[516/1000] loss0.012-|Sample:0.13|
# EPOCH[517/1000] loss0.012-|Sample:0.14|
# EPOCH[518/1000] loss0.012-|Sample:0.14|
# EPOCH[519/1000] loss0.012-|Sample:0.14|
# EPOCH[520/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05703831]), 'recall': array([0.18541434]), 'ndcg': array([0.15799914])}
# EPOCH[521/1000] loss0.012-|Sample:0.13|
# EPOCH[522/1000] loss0.012-|Sample:0.14|
# EPOCH[523/1000] loss0.012-|Sample:0.14|
# EPOCH[524/1000] loss0.012-|Sample:0.14|
# EPOCH[525/1000] loss0.012-|Sample:0.14|
# EPOCH[526/1000] loss0.012-|Sample:0.14|
# EPOCH[527/1000] loss0.012-|Sample:0.13|
# EPOCH[528/1000] loss0.012-|Sample:0.14|
# EPOCH[529/1000] loss0.012-|Sample:0.13|
# EPOCH[530/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05710027]), 'recall': array([0.18554058]), 'ndcg': array([0.15779015])}
# EPOCH[531/1000] loss0.012-|Sample:0.14|
# EPOCH[532/1000] loss0.011-|Sample:0.13|
# EPOCH[533/1000] loss0.012-|Sample:0.13|
# EPOCH[534/1000] loss0.011-|Sample:0.14|
# EPOCH[535/1000] loss0.011-|Sample:0.14|
# EPOCH[536/1000] loss0.011-|Sample:0.13|
# EPOCH[537/1000] loss0.012-|Sample:0.13|
# EPOCH[538/1000] loss0.012-|Sample:0.13|
# EPOCH[539/1000] loss0.011-|Sample:0.14|
# EPOCH[540/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05717563]), 'recall': array([0.18553211]), 'ndcg': array([0.15784377])}
# EPOCH[541/1000] loss0.011-|Sample:0.13|
# EPOCH[542/1000] loss0.012-|Sample:0.14|
# EPOCH[543/1000] loss0.012-|Sample:0.13|
# EPOCH[544/1000] loss0.012-|Sample:0.13|
# EPOCH[545/1000] loss0.012-|Sample:0.14|
# EPOCH[546/1000] loss0.012-|Sample:0.14|
# EPOCH[547/1000] loss0.012-|Sample:0.14|
# EPOCH[548/1000] loss0.012-|Sample:0.13|
# EPOCH[549/1000] loss0.011-|Sample:0.14|
# EPOCH[550/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05727108]), 'recall': array([0.18607096]), 'ndcg': array([0.15832839])}
# EPOCH[551/1000] loss0.012-|Sample:0.12|
# EPOCH[552/1000] loss0.011-|Sample:0.13|
# EPOCH[553/1000] loss0.012-|Sample:0.14|
# EPOCH[554/1000] loss0.012-|Sample:0.14|
# EPOCH[555/1000] loss0.011-|Sample:0.14|
# EPOCH[556/1000] loss0.012-|Sample:0.14|
# EPOCH[557/1000] loss0.011-|Sample:0.14|
# EPOCH[558/1000] loss0.011-|Sample:0.14|
# EPOCH[559/1000] loss0.012-|Sample:0.14|
# EPOCH[560/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.057323]), 'recall': array([0.18639252]), 'ndcg': array([0.15845749])}
# EPOCH[561/1000] loss0.011-|Sample:0.13|
# EPOCH[562/1000] loss0.012-|Sample:0.13|
# EPOCH[563/1000] loss0.012-|Sample:0.13|
# EPOCH[564/1000] loss0.011-|Sample:0.14|
# EPOCH[565/1000] loss0.011-|Sample:0.14|
# EPOCH[566/1000] loss0.011-|Sample:0.13|
# EPOCH[567/1000] loss0.011-|Sample:0.14|
# EPOCH[568/1000] loss0.012-|Sample:0.14|
# EPOCH[569/1000] loss0.011-|Sample:0.14|
# EPOCH[570/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05740673]), 'recall': array([0.18644733]), 'ndcg': array([0.15842263])}
# EPOCH[571/1000] loss0.011-|Sample:0.16|
# EPOCH[572/1000] loss0.011-|Sample:0.13|
# EPOCH[573/1000] loss0.011-|Sample:0.14|
# EPOCH[574/1000] loss0.011-|Sample:0.14|
# EPOCH[575/1000] loss0.012-|Sample:0.13|
# EPOCH[576/1000] loss0.011-|Sample:0.14|
# EPOCH[577/1000] loss0.012-|Sample:0.13|
# EPOCH[578/1000] loss0.012-|Sample:0.14|
# EPOCH[579/1000] loss0.011-|Sample:0.14|
# EPOCH[580/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05734309]), 'recall': array([0.1862893]), 'ndcg': array([0.15835221])}
# EPOCH[581/1000] loss0.011-|Sample:0.13|
# EPOCH[582/1000] loss0.011-|Sample:0.13|
# EPOCH[583/1000] loss0.011-|Sample:0.14|
# EPOCH[584/1000] loss0.011-|Sample:0.14|
# EPOCH[585/1000] loss0.011-|Sample:0.14|
# EPOCH[586/1000] loss0.011-|Sample:0.14|
# EPOCH[587/1000] loss0.011-|Sample:0.18|
# EPOCH[588/1000] loss0.012-|Sample:0.14|
# EPOCH[589/1000] loss0.011-|Sample:0.14|
# EPOCH[590/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05731295]), 'recall': array([0.18649701]), 'ndcg': array([0.1581181])}
# EPOCH[591/1000] loss0.011-|Sample:0.13|
# EPOCH[592/1000] loss0.011-|Sample:0.13|
# EPOCH[593/1000] loss0.011-|Sample:0.14|
# EPOCH[594/1000] loss0.011-|Sample:0.14|
# EPOCH[595/1000] loss0.011-|Sample:0.14|
# EPOCH[596/1000] loss0.011-|Sample:0.14|
# EPOCH[597/1000] loss0.011-|Sample:0.14|
# EPOCH[598/1000] loss0.011-|Sample:0.14|
# EPOCH[599/1000] loss0.011-|Sample:0.14|
# EPOCH[600/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05723257]), 'recall': array([0.18611208]), 'ndcg': array([0.15795038])}
# EPOCH[601/1000] loss0.011-|Sample:0.15|
# EPOCH[602/1000] loss0.011-|Sample:0.14|
# EPOCH[603/1000] loss0.011-|Sample:0.14|
# EPOCH[604/1000] loss0.011-|Sample:0.14|
# EPOCH[605/1000] loss0.011-|Sample:0.13|
# EPOCH[606/1000] loss0.011-|Sample:0.14|
# EPOCH[607/1000] loss0.011-|Sample:0.14|
# EPOCH[608/1000] loss0.011-|Sample:0.13|
# EPOCH[609/1000] loss0.011-|Sample:0.14|
# EPOCH[610/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05718233]), 'recall': array([0.18604611]), 'ndcg': array([0.15794087])}
# EPOCH[611/1000] loss0.012-|Sample:0.15|
# EPOCH[612/1000] loss0.011-|Sample:0.13|
# EPOCH[613/1000] loss0.011-|Sample:0.14|
# EPOCH[614/1000] loss0.011-|Sample:0.14|
# EPOCH[615/1000] loss0.011-|Sample:0.14|
# EPOCH[616/1000] loss0.011-|Sample:0.14|
# EPOCH[617/1000] loss0.011-|Sample:0.14|
# EPOCH[618/1000] loss0.011-|Sample:0.14|
# EPOCH[619/1000] loss0.011-|Sample:0.14|
# EPOCH[620/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05735314]), 'recall': array([0.18637023]), 'ndcg': array([0.15845077])}
# EPOCH[621/1000] loss0.011-|Sample:0.13|
# EPOCH[622/1000] loss0.011-|Sample:0.14|
# EPOCH[623/1000] loss0.011-|Sample:0.14|
# EPOCH[624/1000] loss0.011-|Sample:0.14|
# EPOCH[625/1000] loss0.011-|Sample:0.14|
# EPOCH[626/1000] loss0.011-|Sample:0.14|
# EPOCH[627/1000] loss0.011-|Sample:0.14|
# EPOCH[628/1000] loss0.011-|Sample:0.14|
# EPOCH[629/1000] loss0.011-|Sample:0.14|
# EPOCH[630/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05755074]), 'recall': array([0.18691201]), 'ndcg': array([0.15869554])}
# EPOCH[631/1000] loss0.011-|Sample:0.14|
# EPOCH[632/1000] loss0.011-|Sample:0.14|
# EPOCH[633/1000] loss0.011-|Sample:0.14|
# EPOCH[634/1000] loss0.011-|Sample:0.15|
# EPOCH[635/1000] loss0.011-|Sample:0.14|
# EPOCH[636/1000] loss0.011-|Sample:0.14|
# EPOCH[637/1000] loss0.011-|Sample:0.13|
# EPOCH[638/1000] loss0.011-|Sample:0.13|
# EPOCH[639/1000] loss0.011-|Sample:0.14|
# EPOCH[640/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05751892]), 'recall': array([0.1868958]), 'ndcg': array([0.15866299])}
# EPOCH[641/1000] loss0.011-|Sample:0.15|
# EPOCH[642/1000] loss0.011-|Sample:0.14|
# EPOCH[643/1000] loss0.011-|Sample:0.14|
# EPOCH[644/1000] loss0.011-|Sample:0.14|
# EPOCH[645/1000] loss0.011-|Sample:0.14|
# EPOCH[646/1000] loss0.011-|Sample:0.14|
# EPOCH[647/1000] loss0.011-|Sample:0.14|
# EPOCH[648/1000] loss0.011-|Sample:0.14|
# EPOCH[649/1000] loss0.011-|Sample:0.14|
# EPOCH[650/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.0575005]), 'recall': array([0.18656628]), 'ndcg': array([0.15840971])}
# EPOCH[651/1000] loss0.011-|Sample:0.13|
# EPOCH[652/1000] loss0.011-|Sample:0.14|
# EPOCH[653/1000] loss0.011-|Sample:0.14|
# EPOCH[654/1000] loss0.011-|Sample:0.14|
# EPOCH[655/1000] loss0.011-|Sample:0.14|
# EPOCH[656/1000] loss0.011-|Sample:0.13|
# EPOCH[657/1000] loss0.011-|Sample:0.13|
# EPOCH[658/1000] loss0.011-|Sample:0.14|
# EPOCH[659/1000] loss0.011-|Sample:0.14|
# EPOCH[660/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05756079]), 'recall': array([0.18697206]), 'ndcg': array([0.15908624])}
# EPOCH[661/1000] loss0.011-|Sample:0.16|
# EPOCH[662/1000] loss0.011-|Sample:0.14|
# EPOCH[663/1000] loss0.011-|Sample:0.14|
# EPOCH[664/1000] loss0.011-|Sample:0.16|
# EPOCH[665/1000] loss0.011-|Sample:0.13|
# EPOCH[666/1000] loss0.011-|Sample:0.14|
# EPOCH[667/1000] loss0.011-|Sample:0.13|
# EPOCH[668/1000] loss0.011-|Sample:0.14|
# EPOCH[669/1000] loss0.011-|Sample:0.14|
# EPOCH[670/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05750553]), 'recall': array([0.18659332]), 'ndcg': array([0.15865536])}
# EPOCH[671/1000] loss0.011-|Sample:0.13|
# EPOCH[672/1000] loss0.011-|Sample:0.14|
# EPOCH[673/1000] loss0.011-|Sample:0.14|
# EPOCH[674/1000] loss0.011-|Sample:0.15|
# EPOCH[675/1000] loss0.011-|Sample:0.14|
# EPOCH[676/1000] loss0.011-|Sample:0.15|
# EPOCH[677/1000] loss0.011-|Sample:0.15|
# EPOCH[678/1000] loss0.011-|Sample:0.15|
# EPOCH[679/1000] loss0.011-|Sample:0.14|
# EPOCH[680/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.057323]), 'recall': array([0.18596325]), 'ndcg': array([0.15810145])}
# EPOCH[681/1000] loss0.011-|Sample:0.13|
# EPOCH[682/1000] loss0.011-|Sample:0.14|
# EPOCH[683/1000] loss0.011-|Sample:0.14|
# EPOCH[684/1000] loss0.011-|Sample:0.16|
# EPOCH[685/1000] loss0.011-|Sample:0.14|
# EPOCH[686/1000] loss0.011-|Sample:0.14|
# EPOCH[687/1000] loss0.011-|Sample:0.13|
# EPOCH[688/1000] loss0.011-|Sample:0.14|
# EPOCH[689/1000] loss0.011-|Sample:0.13|
# EPOCH[690/1000] loss0.011-|Sample:0.17|
# [TEST]
# {'precision': array([0.05747538]), 'recall': array([0.18636227]), 'ndcg': array([0.15851549])}
# EPOCH[691/1000] loss0.011-|Sample:0.14|
# EPOCH[692/1000] loss0.011-|Sample:0.14|
# EPOCH[693/1000] loss0.011-|Sample:0.14|
# EPOCH[694/1000] loss0.011-|Sample:0.14|
# EPOCH[695/1000] loss0.011-|Sample:0.14|
# EPOCH[696/1000] loss0.011-|Sample:0.14|
# EPOCH[697/1000] loss0.011-|Sample:0.14|
# EPOCH[698/1000] loss0.011-|Sample:0.14|
# EPOCH[699/1000] loss0.011-|Sample:0.14|
# EPOCH[700/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05751892]), 'recall': array([0.18669599]), 'ndcg': array([0.15871222])}
# EPOCH[701/1000] loss0.011-|Sample:0.13|
# EPOCH[702/1000] loss0.011-|Sample:0.13|
# EPOCH[703/1000] loss0.011-|Sample:0.14|
# EPOCH[704/1000] loss0.011-|Sample:0.14|
# EPOCH[705/1000] loss0.011-|Sample:0.13|
# EPOCH[706/1000] loss0.011-|Sample:0.14|
# EPOCH[707/1000] loss0.011-|Sample:0.14|
# EPOCH[708/1000] loss0.011-|Sample:0.14|
# EPOCH[709/1000] loss0.011-|Sample:0.14|
# EPOCH[710/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05748041]), 'recall': array([0.18655743]), 'ndcg': array([0.15874324])}
# EPOCH[711/1000] loss0.011-|Sample:0.13|
# EPOCH[712/1000] loss0.011-|Sample:0.13|
# EPOCH[713/1000] loss0.011-|Sample:0.14|
# EPOCH[714/1000] loss0.011-|Sample:0.14|
# EPOCH[715/1000] loss0.011-|Sample:0.14|
# EPOCH[716/1000] loss0.011-|Sample:0.14|
# EPOCH[717/1000] loss0.011-|Sample:0.14|
# EPOCH[718/1000] loss0.011-|Sample:0.14|
# EPOCH[719/1000] loss0.011-|Sample:0.14|
# EPOCH[720/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05746031]), 'recall': array([0.18634601]), 'ndcg': array([0.1589682])}
# EPOCH[721/1000] loss0.011-|Sample:0.14|
# EPOCH[722/1000] loss0.011-|Sample:0.14|
# EPOCH[723/1000] loss0.011-|Sample:0.13|
# EPOCH[724/1000] loss0.011-|Sample:0.14|
# EPOCH[725/1000] loss0.011-|Sample:0.14|
# EPOCH[726/1000] loss0.011-|Sample:0.14|
# EPOCH[727/1000] loss0.011-|Sample:0.14|
# EPOCH[728/1000] loss0.011-|Sample:0.13|
# EPOCH[729/1000] loss0.011-|Sample:0.14|
# EPOCH[730/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05754739]), 'recall': array([0.18657937]), 'ndcg': array([0.1591621])}
# EPOCH[731/1000] loss0.011-|Sample:0.14|
# EPOCH[732/1000] loss0.011-|Sample:0.14|
# EPOCH[733/1000] loss0.011-|Sample:0.14|
# EPOCH[734/1000] loss0.011-|Sample:0.14|
# EPOCH[735/1000] loss0.011-|Sample:0.14|
# EPOCH[736/1000] loss0.011-|Sample:0.14|
# EPOCH[737/1000] loss0.011-|Sample:0.14|
# EPOCH[738/1000] loss0.011-|Sample:0.14|
# EPOCH[739/1000] loss0.011-|Sample:0.14|
# EPOCH[740/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05764284]), 'recall': array([0.18721249]), 'ndcg': array([0.15902195])}
# EPOCH[741/1000] loss0.011-|Sample:0.13|
# EPOCH[742/1000] loss0.011-|Sample:0.14|
# EPOCH[743/1000] loss0.011-|Sample:0.13|
# EPOCH[744/1000] loss0.011-|Sample:0.14|
# EPOCH[745/1000] loss0.011-|Sample:0.14|
# EPOCH[746/1000] loss0.011-|Sample:0.13|
# EPOCH[747/1000] loss0.011-|Sample:0.14|
# EPOCH[748/1000] loss0.011-|Sample:0.14|
# EPOCH[749/1000] loss0.011-|Sample:0.14|
# EPOCH[750/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.0575926]), 'recall': array([0.18645579]), 'ndcg': array([0.15889683])}
# EPOCH[751/1000] loss0.011-|Sample:0.14|
# EPOCH[752/1000] loss0.011-|Sample:0.14|
# EPOCH[753/1000] loss0.011-|Sample:0.14|
# EPOCH[754/1000] loss0.011-|Sample:0.14|
# EPOCH[755/1000] loss0.011-|Sample:0.14|
# EPOCH[756/1000] loss0.011-|Sample:0.14|
# EPOCH[757/1000] loss0.011-|Sample:0.14|
# EPOCH[758/1000] loss0.011-|Sample:0.14|
# EPOCH[759/1000] loss0.011-|Sample:0.13|
# EPOCH[760/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05776509]), 'recall': array([0.18735848]), 'ndcg': array([0.15897645])}
# EPOCH[761/1000] loss0.011-|Sample:0.17|
# EPOCH[762/1000] loss0.011-|Sample:0.13|
# EPOCH[763/1000] loss0.011-|Sample:0.14|
# EPOCH[764/1000] loss0.011-|Sample:0.14|
# EPOCH[765/1000] loss0.011-|Sample:0.14|
# EPOCH[766/1000] loss0.011-|Sample:0.14|
# EPOCH[767/1000] loss0.011-|Sample:0.14|
# EPOCH[768/1000] loss0.011-|Sample:0.14|
# EPOCH[769/1000] loss0.011-|Sample:0.14|
# EPOCH[770/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05764954]), 'recall': array([0.18691707]), 'ndcg': array([0.15904947])}
# EPOCH[771/1000] loss0.011-|Sample:0.13|
# EPOCH[772/1000] loss0.011-|Sample:0.14|
# EPOCH[773/1000] loss0.011-|Sample:0.15|
# EPOCH[774/1000] loss0.011-|Sample:0.14|
# EPOCH[775/1000] loss0.011-|Sample:0.14|
# EPOCH[776/1000] loss0.011-|Sample:0.14|
# EPOCH[777/1000] loss0.011-|Sample:0.14|
# EPOCH[778/1000] loss0.011-|Sample:0.14|
# EPOCH[779/1000] loss0.011-|Sample:0.14|
# EPOCH[780/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05777848]), 'recall': array([0.18756362]), 'ndcg': array([0.15946735])}
# EPOCH[781/1000] loss0.011-|Sample:0.17|
# EPOCH[782/1000] loss0.011-|Sample:0.14|
# EPOCH[783/1000] loss0.011-|Sample:0.14|
# EPOCH[784/1000] loss0.011-|Sample:0.14|
# EPOCH[785/1000] loss0.011-|Sample:0.14|
# EPOCH[786/1000] loss0.011-|Sample:0.14|
# EPOCH[787/1000] loss0.011-|Sample:0.14|
# EPOCH[788/1000] loss0.011-|Sample:0.14|
# EPOCH[789/1000] loss0.011-|Sample:0.14|
# EPOCH[790/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05766294]), 'recall': array([0.18737093]), 'ndcg': array([0.15918936])}
# EPOCH[791/1000] loss0.011-|Sample:0.15|
# EPOCH[792/1000] loss0.011-|Sample:0.14|
# EPOCH[793/1000] loss0.011-|Sample:0.13|
# EPOCH[794/1000] loss0.011-|Sample:0.14|
# EPOCH[795/1000] loss0.011-|Sample:0.14|
# EPOCH[796/1000] loss0.011-|Sample:0.14|
# EPOCH[797/1000] loss0.011-|Sample:0.14|
# EPOCH[798/1000] loss0.011-|Sample:0.16|
# EPOCH[799/1000] loss0.011-|Sample:0.14|
# EPOCH[800/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05778518]), 'recall': array([0.18741127]), 'ndcg': array([0.15945645])}
# EPOCH[801/1000] loss0.011-|Sample:0.15|
# EPOCH[802/1000] loss0.011-|Sample:0.14|
# EPOCH[803/1000] loss0.011-|Sample:0.14|
# EPOCH[804/1000] loss0.011-|Sample:0.14|
# EPOCH[805/1000] loss0.011-|Sample:0.14|
# EPOCH[806/1000] loss0.011-|Sample:0.14|
# EPOCH[807/1000] loss0.011-|Sample:0.14|
# EPOCH[808/1000] loss0.011-|Sample:0.14|
# EPOCH[809/1000] loss0.011-|Sample:0.15|
# EPOCH[810/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05766964]), 'recall': array([0.18687588]), 'ndcg': array([0.15911172])}
# EPOCH[811/1000] loss0.011-|Sample:0.18|
# EPOCH[812/1000] loss0.011-|Sample:0.13|
# EPOCH[813/1000] loss0.011-|Sample:0.14|
# EPOCH[814/1000] loss0.011-|Sample:0.13|
# EPOCH[815/1000] loss0.011-|Sample:0.14|
# EPOCH[816/1000] loss0.011-|Sample:0.14|
# EPOCH[817/1000] loss0.011-|Sample:0.14|
# EPOCH[818/1000] loss0.011-|Sample:0.14|
# EPOCH[819/1000] loss0.011-|Sample:0.14|
# EPOCH[820/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05779523]), 'recall': array([0.18767086]), 'ndcg': array([0.15936688])}
# EPOCH[821/1000] loss0.011-|Sample:0.13|
# EPOCH[822/1000] loss0.011-|Sample:0.13|
# EPOCH[823/1000] loss0.011-|Sample:0.14|
# EPOCH[824/1000] loss0.011-|Sample:0.14|
# EPOCH[825/1000] loss0.011-|Sample:0.14|
# EPOCH[826/1000] loss0.011-|Sample:0.14|
# EPOCH[827/1000] loss0.011-|Sample:0.14|
# EPOCH[828/1000] loss0.011-|Sample:0.13|
# EPOCH[829/1000] loss0.011-|Sample:0.14|
# EPOCH[830/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05779188]), 'recall': array([0.18753553]), 'ndcg': array([0.15917921])}
# EPOCH[831/1000] loss0.011-|Sample:0.15|
# EPOCH[832/1000] loss0.011-|Sample:0.14|
# EPOCH[833/1000] loss0.011-|Sample:0.14|
# EPOCH[834/1000] loss0.011-|Sample:0.14|
# EPOCH[835/1000] loss0.011-|Sample:0.14|
# EPOCH[836/1000] loss0.011-|Sample:0.14|
# EPOCH[837/1000] loss0.011-|Sample:0.14|
# EPOCH[838/1000] loss0.011-|Sample:0.14|
# EPOCH[839/1000] loss0.011-|Sample:0.14|
# EPOCH[840/1000] loss0.011-|Sample:0.17|
# [TEST]
# {'precision': array([0.05765122]), 'recall': array([0.18697652]), 'ndcg': array([0.15925648])}
# EPOCH[841/1000] loss0.011-|Sample:0.13|
# EPOCH[842/1000] loss0.011-|Sample:0.14|
# EPOCH[843/1000] loss0.011-|Sample:0.14|
# EPOCH[844/1000] loss0.011-|Sample:0.14|
# EPOCH[845/1000] loss0.011-|Sample:0.13|
# EPOCH[846/1000] loss0.011-|Sample:0.13|
# EPOCH[847/1000] loss0.011-|Sample:0.14|
# EPOCH[848/1000] loss0.011-|Sample:0.14|
# EPOCH[849/1000] loss0.011-|Sample:0.14|
# EPOCH[850/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05771485]), 'recall': array([0.18712182]), 'ndcg': array([0.15930496])}
# EPOCH[851/1000] loss0.011-|Sample:0.15|
# EPOCH[852/1000] loss0.011-|Sample:0.14|
# EPOCH[853/1000] loss0.011-|Sample:0.14|
# EPOCH[854/1000] loss0.011-|Sample:0.14|
# EPOCH[855/1000] loss0.011-|Sample:0.14|
# EPOCH[856/1000] loss0.011-|Sample:0.14|
# EPOCH[857/1000] loss0.011-|Sample:0.14|
# EPOCH[858/1000] loss0.011-|Sample:0.14|
# EPOCH[859/1000] loss0.011-|Sample:0.14|
# EPOCH[860/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05774499]), 'recall': array([0.18731169]), 'ndcg': array([0.15937204])}
# EPOCH[861/1000] loss0.011-|Sample:0.15|
# EPOCH[862/1000] loss0.011-|Sample:0.14|
# EPOCH[863/1000] loss0.011-|Sample:0.14|
# EPOCH[864/1000] loss0.011-|Sample:0.14|
# EPOCH[865/1000] loss0.011-|Sample:0.13|
# EPOCH[866/1000] loss0.011-|Sample:0.13|
# EPOCH[867/1000] loss0.011-|Sample:0.14|
# EPOCH[868/1000] loss0.011-|Sample:0.14|
# EPOCH[869/1000] loss0.011-|Sample:0.14|
# EPOCH[870/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05775839]), 'recall': array([0.18758912]), 'ndcg': array([0.15937665])}
# EPOCH[871/1000] loss0.011-|Sample:0.13|
# EPOCH[872/1000] loss0.011-|Sample:0.13|
# EPOCH[873/1000] loss0.011-|Sample:0.14|
# EPOCH[874/1000] loss0.011-|Sample:0.14|
# EPOCH[875/1000] loss0.011-|Sample:0.14|
# EPOCH[876/1000] loss0.011-|Sample:0.17|
# EPOCH[877/1000] loss0.011-|Sample:0.14|
# EPOCH[878/1000] loss0.011-|Sample:0.14|
# EPOCH[879/1000] loss0.011-|Sample:0.14|
# EPOCH[880/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05765791]), 'recall': array([0.1871999]), 'ndcg': array([0.15927101])}
# EPOCH[881/1000] loss0.011-|Sample:0.14|
# EPOCH[882/1000] loss0.011-|Sample:0.14|
# EPOCH[883/1000] loss0.011-|Sample:0.15|
# EPOCH[884/1000] loss0.011-|Sample:0.14|
# EPOCH[885/1000] loss0.011-|Sample:0.14|
# EPOCH[886/1000] loss0.011-|Sample:0.14|
# EPOCH[887/1000] loss0.011-|Sample:0.14|
# EPOCH[888/1000] loss0.011-|Sample:0.14|
# EPOCH[889/1000] loss0.011-|Sample:0.14|
# EPOCH[890/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.0576328]), 'recall': array([0.18690821]), 'ndcg': array([0.15947874])}
# EPOCH[891/1000] loss0.011-|Sample:0.13|
# EPOCH[892/1000] loss0.011-|Sample:0.14|
# EPOCH[893/1000] loss0.011-|Sample:0.13|
# EPOCH[894/1000] loss0.011-|Sample:0.14|
# EPOCH[895/1000] loss0.011-|Sample:0.14|
# EPOCH[896/1000] loss0.011-|Sample:0.14|
# EPOCH[897/1000] loss0.011-|Sample:0.14|
# EPOCH[898/1000] loss0.011-|Sample:0.14|
# EPOCH[899/1000] loss0.011-|Sample:0.14|
# EPOCH[900/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05771318]), 'recall': array([0.18723453]), 'ndcg': array([0.15946703])}
# EPOCH[901/1000] loss0.011-|Sample:0.14|
# EPOCH[902/1000] loss0.011-|Sample:0.14|
# EPOCH[903/1000] loss0.011-|Sample:0.15|
# EPOCH[904/1000] loss0.011-|Sample:0.14|
# EPOCH[905/1000] loss0.011-|Sample:0.14|
# EPOCH[906/1000] loss0.011-|Sample:0.13|
# EPOCH[907/1000] loss0.011-|Sample:0.14|
# EPOCH[908/1000] loss0.011-|Sample:0.13|
# EPOCH[909/1000] loss0.011-|Sample:0.14|
# EPOCH[910/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05769643]), 'recall': array([0.18717789]), 'ndcg': array([0.15918228])}
# EPOCH[911/1000] loss0.011-|Sample:0.15|
# EPOCH[912/1000] loss0.011-|Sample:0.14|
# EPOCH[913/1000] loss0.011-|Sample:0.14|
# EPOCH[914/1000] loss0.011-|Sample:0.14|
# EPOCH[915/1000] loss0.011-|Sample:0.14|
# EPOCH[916/1000] loss0.011-|Sample:0.15|
# EPOCH[917/1000] loss0.011-|Sample:0.15|
# EPOCH[918/1000] loss0.011-|Sample:0.14|
# EPOCH[919/1000] loss0.011-|Sample:0.13|
# EPOCH[920/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05769141]), 'recall': array([0.18687097]), 'ndcg': array([0.15915184])}
# EPOCH[921/1000] loss0.011-|Sample:0.14|
# EPOCH[922/1000] loss0.011-|Sample:0.13|
# EPOCH[923/1000] loss0.011-|Sample:0.14|
# EPOCH[924/1000] loss0.011-|Sample:0.14|
# EPOCH[925/1000] loss0.011-|Sample:0.14|
# EPOCH[926/1000] loss0.011-|Sample:0.14|
# EPOCH[927/1000] loss0.011-|Sample:0.14|
# EPOCH[928/1000] loss0.011-|Sample:0.13|
# EPOCH[929/1000] loss0.011-|Sample:0.13|
# EPOCH[930/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.0578103]), 'recall': array([0.18743762]), 'ndcg': array([0.15951906])}
# EPOCH[931/1000] loss0.011-|Sample:0.16|
# EPOCH[932/1000] loss0.011-|Sample:0.14|
# EPOCH[933/1000] loss0.011-|Sample:0.13|
# EPOCH[934/1000] loss0.011-|Sample:0.14|
# EPOCH[935/1000] loss0.011-|Sample:0.14|
# EPOCH[936/1000] loss0.011-|Sample:0.14|
# EPOCH[937/1000] loss0.011-|Sample:0.14|
# EPOCH[938/1000] loss0.011-|Sample:0.14|
# EPOCH[939/1000] loss0.011-|Sample:0.14|
# EPOCH[940/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05784714]), 'recall': array([0.18774226]), 'ndcg': array([0.15960946])}
# EPOCH[941/1000] loss0.011-|Sample:0.15|
# EPOCH[942/1000] loss0.011-|Sample:0.13|
# EPOCH[943/1000] loss0.011-|Sample:0.14|
# EPOCH[944/1000] loss0.011-|Sample:0.14|
# EPOCH[945/1000] loss0.011-|Sample:0.14|
# EPOCH[946/1000] loss0.011-|Sample:0.14|
# EPOCH[947/1000] loss0.011-|Sample:0.14|
# EPOCH[948/1000] loss0.011-|Sample:0.14|
# EPOCH[949/1000] loss0.011-|Sample:0.14|
# EPOCH[950/1000] loss0.011-|Sample:0.15|
# [TEST]
# {'precision': array([0.05789403]), 'recall': array([0.18767831]), 'ndcg': array([0.15965614])}
# EPOCH[951/1000] loss0.011-|Sample:0.15|
# EPOCH[952/1000] loss0.011-|Sample:0.21|
# EPOCH[953/1000] loss0.011-|Sample:0.14|
# EPOCH[954/1000] loss0.011-|Sample:0.14|
# EPOCH[955/1000] loss0.011-|Sample:0.13|
# EPOCH[956/1000] loss0.011-|Sample:0.14|
# EPOCH[957/1000] loss0.011-|Sample:0.14|
# EPOCH[958/1000] loss0.011-|Sample:0.13|
# EPOCH[959/1000] loss0.011-|Sample:0.14|
# EPOCH[960/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05784212]), 'recall': array([0.18741499]), 'ndcg': array([0.15958818])}
# EPOCH[961/1000] loss0.011-|Sample:0.13|
# EPOCH[962/1000] loss0.011-|Sample:0.13|
# EPOCH[963/1000] loss0.011-|Sample:0.13|
# EPOCH[964/1000] loss0.011-|Sample:0.13|
# EPOCH[965/1000] loss0.011-|Sample:0.14|
# EPOCH[966/1000] loss0.011-|Sample:0.14|
# EPOCH[967/1000] loss0.011-|Sample:0.14|
# EPOCH[968/1000] loss0.011-|Sample:0.13|
# EPOCH[969/1000] loss0.011-|Sample:0.14|
# EPOCH[970/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.0579225]), 'recall': array([0.18752679]), 'ndcg': array([0.15958954])}
# EPOCH[971/1000] loss0.011-|Sample:0.13|
# EPOCH[972/1000] loss0.011-|Sample:0.14|
# EPOCH[973/1000] loss0.011-|Sample:0.14|
# EPOCH[974/1000] loss0.011-|Sample:0.13|
# EPOCH[975/1000] loss0.011-|Sample:0.14|
# EPOCH[976/1000] loss0.011-|Sample:0.14|
# EPOCH[977/1000] loss0.011-|Sample:0.13|
# EPOCH[978/1000] loss0.011-|Sample:0.14|
# EPOCH[979/1000] loss0.011-|Sample:0.14|
# EPOCH[980/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05779523]), 'recall': array([0.18720274]), 'ndcg': array([0.15955308])}
# EPOCH[981/1000] loss0.011-|Sample:0.13|
# EPOCH[982/1000] loss0.011-|Sample:0.14|
# EPOCH[983/1000] loss0.011-|Sample:0.14|
# EPOCH[984/1000] loss0.011-|Sample:0.14|
# EPOCH[985/1000] loss0.011-|Sample:0.14|
# EPOCH[986/1000] loss0.011-|Sample:0.14|
# EPOCH[987/1000] loss0.011-|Sample:0.14|
# EPOCH[988/1000] loss0.011-|Sample:0.15|
# EPOCH[989/1000] loss0.011-|Sample:0.14|
# EPOCH[990/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05786054]), 'recall': array([0.18727426]), 'ndcg': array([0.15953341])}
# EPOCH[991/1000] loss0.011-|Sample:0.14|
# EPOCH[992/1000] loss0.011-|Sample:0.14|
# EPOCH[993/1000] loss0.011-|Sample:0.14|
# EPOCH[994/1000] loss0.011-|Sample:0.14|
# EPOCH[995/1000] loss0.011-|Sample:0.14|
# EPOCH[996/1000] loss0.011-|Sample:0.14|
# EPOCH[997/1000] loss0.011-|Sample:0.14|
# EPOCH[998/1000] loss0.011-|Sample:0.14|
# EPOCH[999/1000] loss0.011-|Sample:0.14|
# EPOCH[1000/1000] loss0.011-|Sample:0.14|
