# %%
# %load main.py
import world
import utils
from world import cprint
import torch
import numpy as np
from tensorboardX import SummaryWriter
import time
import Procedure
from os.path import join
# ==============================
utils.set_seed(world.seed)
print(">>SEED:", world.seed)
# ==============================
import register
from register import dataset

Recmodel = register.MODELS[world.model_name](world.config, dataset)
Recmodel = Recmodel.to(world.device)
bpr = utils.BPRLoss(Recmodel, world.config)

weight_file = utils.getFileName()
print(f"load and save to {weight_file}")
if world.LOAD:
    try:
        Recmodel.load_state_dict(torch.load(weight_file,map_location=torch.device('cpu')))
        world.cprint(f"loaded model weights from {weight_file}")
    except FileNotFoundError:
        print(f"{weight_file} not exists, start from beginning")
Neg_k = 1

# init tensorboard
if world.tensorboard:
    w : SummaryWriter = SummaryWriter(
                                    join(world.BOARD_PATH, time.strftime("%m-%d-%Hh%Mm%Ss-") + "-" + world.comment)
                                    )
else:
    w = None
    world.cprint("not enable tensorflowboard")

try:
    for epoch in range(world.TRAIN_epochs):
        start = time.time()
        if epoch %10 == 0:
            cprint("[TEST]")
            Procedure.Test(dataset, Recmodel, epoch, w, world.config['multicore'])
        output_information = Procedure.BPR_train_original(dataset, Recmodel, bpr, epoch, neg_k=Neg_k,w=w)
        print(f'EPOCH[{epoch+1}/{world.TRAIN_epochs}] {output_information}')
        torch.save(Recmodel.state_dict(), weight_file)
finally:
    if world.tensorboard:
        w.close()
# Out:
# >>SEED: 2020
# loading [../data/gowalla]
# 810128 interactions for training
# 217242 interactions for testing
# gowalla Sparsity : 0.0008396216228570436
# gowalla is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 4,
#  'lr': 0.001,
#  'multicore': 1,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 24
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded heterogeneous graph ...
# don't split the matrix
# loading adjacency matrix
# successfully loaded homogeneous graph ...
# don't split the matrix
# loading degree weight
# successfully loaded heterogeneous degree weight ...
# lgn is already to go(dropout:0)
# load and save to /home/user1/Larry/FGCF/runs/code/checkpoints/lgn-gowalla-4-64.pth.tar
# [TEST]
# {'precision': array([0.00040023]), 'recall': array([0.00133206]), 'ndcg': array([0.00090378])}
# EPOCH[1/1000] loss0.489-|Sample:0.15|
# EPOCH[2/1000] loss0.218-|Sample:0.12|
# EPOCH[3/1000] loss0.155-|Sample:0.14|
# EPOCH[4/1000] loss0.126-|Sample:0.13|
# EPOCH[5/1000] loss0.111-|Sample:0.14|
# EPOCH[6/1000] loss0.099-|Sample:0.14|
# EPOCH[7/1000] loss0.092-|Sample:0.14|
# EPOCH[8/1000] loss0.086-|Sample:0.14|
# EPOCH[9/1000] loss0.081-|Sample:0.14|
# EPOCH[10/1000] loss0.078-|Sample:0.14|
# [TEST]
# {'precision': array([0.03713745]), 'recall': array([0.12092412]), 'ndcg': array([0.10220741])}
# EPOCH[11/1000] loss0.074-|Sample:0.15|
# EPOCH[12/1000] loss0.071-|Sample:0.14|
# EPOCH[13/1000] loss0.068-|Sample:0.14|
# EPOCH[14/1000] loss0.065-|Sample:0.14|
# EPOCH[15/1000] loss0.063-|Sample:0.14|
# EPOCH[16/1000] loss0.061-|Sample:0.14|
# EPOCH[17/1000] loss0.058-|Sample:0.14|
# EPOCH[18/1000] loss0.058-|Sample:0.14|
# EPOCH[19/1000] loss0.057-|Sample:0.14|
# EPOCH[20/1000] loss0.055-|Sample:0.14|
# [TEST]
# {'precision': array([0.04013497]), 'recall': array([0.13173106]), 'ndcg': array([0.11151729])}
# EPOCH[21/1000] loss0.053-|Sample:0.16|
# EPOCH[22/1000] loss0.052-|Sample:0.13|
# EPOCH[23/1000] loss0.051-|Sample:0.15|
# EPOCH[24/1000] loss0.050-|Sample:0.14|
# EPOCH[25/1000] loss0.049-|Sample:0.14|
# EPOCH[26/1000] loss0.047-|Sample:0.14|
# EPOCH[27/1000] loss0.047-|Sample:0.14|
# EPOCH[28/1000] loss0.046-|Sample:0.15|
# EPOCH[29/1000] loss0.045-|Sample:0.14|
# EPOCH[30/1000] loss0.045-|Sample:0.14|
# [TEST]
# {'precision': array([0.04237055]), 'recall': array([0.13965357]), 'ndcg': array([0.11801503])}
# EPOCH[31/1000] loss0.043-|Sample:0.13|
# EPOCH[32/1000] loss0.044-|Sample:0.14|
# EPOCH[33/1000] loss0.043-|Sample:0.14|
# EPOCH[34/1000] loss0.042-|Sample:0.15|
# EPOCH[35/1000] loss0.041-|Sample:0.15|
# EPOCH[36/1000] loss0.040-|Sample:0.14|
# EPOCH[37/1000] loss0.040-|Sample:0.14|
# EPOCH[38/1000] loss0.039-|Sample:0.13|
# EPOCH[39/1000] loss0.038-|Sample:0.14|
# EPOCH[40/1000] loss0.038-|Sample:0.14|
# [TEST]
# {'precision': array([0.04420758]), 'recall': array([0.14598082]), 'ndcg': array([0.12326882])}
# EPOCH[41/1000] loss0.038-|Sample:0.13|
# EPOCH[42/1000] loss0.037-|Sample:0.14|
# EPOCH[43/1000] loss0.037-|Sample:0.14|
# EPOCH[44/1000] loss0.036-|Sample:0.14|
# EPOCH[45/1000] loss0.036-|Sample:0.14|
# EPOCH[46/1000] loss0.035-|Sample:0.14|
# EPOCH[47/1000] loss0.035-|Sample:0.14|
# EPOCH[48/1000] loss0.034-|Sample:0.15|
# EPOCH[49/1000] loss0.035-|Sample:0.14|
# EPOCH[50/1000] loss0.034-|Sample:0.14|
# [TEST]
# {'precision': array([0.04579342]), 'recall': array([0.1512671]), 'ndcg': array([0.12775277])}
# EPOCH[51/1000] loss0.034-|Sample:0.13|
# EPOCH[52/1000] loss0.033-|Sample:0.14|
# EPOCH[53/1000] loss0.033-|Sample:0.14|
# EPOCH[54/1000] loss0.032-|Sample:0.13|
# EPOCH[55/1000] loss0.032-|Sample:0.13|
# EPOCH[56/1000] loss0.032-|Sample:0.14|
# EPOCH[57/1000] loss0.031-|Sample:0.14|
# EPOCH[58/1000] loss0.032-|Sample:0.15|
# EPOCH[59/1000] loss0.031-|Sample:0.14|
# EPOCH[60/1000] loss0.031-|Sample:0.14|
# [TEST]
# {'precision': array([0.04693549]), 'recall': array([0.15524013]), 'ndcg': array([0.13133042])}
# EPOCH[61/1000] loss0.030-|Sample:0.14|
# EPOCH[62/1000] loss0.030-|Sample:0.14|
# EPOCH[63/1000] loss0.030-|Sample:0.14|
# EPOCH[64/1000] loss0.029-|Sample:0.13|
# EPOCH[65/1000] loss0.029-|Sample:0.14|
# EPOCH[66/1000] loss0.029-|Sample:0.14|
# EPOCH[67/1000] loss0.029-|Sample:0.14|
# EPOCH[68/1000] loss0.028-|Sample:0.13|
# EPOCH[69/1000] loss0.028-|Sample:0.13|
# EPOCH[70/1000] loss0.028-|Sample:0.13|
# [TEST]
# {'precision': array([0.04804073]), 'recall': array([0.15891903]), 'ndcg': array([0.13461268])}
# EPOCH[71/1000] loss0.028-|Sample:0.14|
# EPOCH[72/1000] loss0.027-|Sample:0.14|
# EPOCH[73/1000] loss0.027-|Sample:0.14|
# EPOCH[74/1000] loss0.027-|Sample:0.14|
# EPOCH[75/1000] loss0.028-|Sample:0.14|
# EPOCH[76/1000] loss0.027-|Sample:0.14|
# EPOCH[77/1000] loss0.026-|Sample:0.14|
# EPOCH[78/1000] loss0.026-|Sample:0.13|
# EPOCH[79/1000] loss0.026-|Sample:0.14|
# EPOCH[80/1000] loss0.026-|Sample:0.14|
# [TEST]
# {'precision': array([0.04892659]), 'recall': array([0.16185982]), 'ndcg': array([0.13699741])}
# EPOCH[81/1000] loss0.026-|Sample:0.13|
# EPOCH[82/1000] loss0.026-|Sample:0.14|
# EPOCH[83/1000] loss0.025-|Sample:0.14|
# EPOCH[84/1000] loss0.025-|Sample:0.14|
# EPOCH[85/1000] loss0.025-|Sample:0.14|
# EPOCH[86/1000] loss0.025-|Sample:0.13|
# EPOCH[87/1000] loss0.025-|Sample:0.13|
# EPOCH[88/1000] loss0.024-|Sample:0.14|
# EPOCH[89/1000] loss0.025-|Sample:0.15|
# EPOCH[90/1000] loss0.024-|Sample:0.14|
# [TEST]
# {'precision': array([0.05002847]), 'recall': array([0.16566799]), 'ndcg': array([0.13987353])}
# EPOCH[91/1000] loss0.024-|Sample:0.13|
# EPOCH[92/1000] loss0.024-|Sample:0.14|
# EPOCH[93/1000] loss0.024-|Sample:0.14|
# EPOCH[94/1000] loss0.024-|Sample:0.14|
# EPOCH[95/1000] loss0.024-|Sample:0.14|
# EPOCH[96/1000] loss0.023-|Sample:0.14|
# EPOCH[97/1000] loss0.023-|Sample:0.14|
# EPOCH[98/1000] loss0.023-|Sample:0.14|
# EPOCH[99/1000] loss0.023-|Sample:0.14|
# EPOCH[100/1000] loss0.023-|Sample:0.14|
# [TEST]
# {'precision': array([0.05077534]), 'recall': array([0.16799993]), 'ndcg': array([0.14192982])}
# EPOCH[101/1000] loss0.023-|Sample:0.16|
# EPOCH[102/1000] loss0.023-|Sample:0.14|
# EPOCH[103/1000] loss0.023-|Sample:0.14|
# EPOCH[104/1000] loss0.023-|Sample:0.15|
# EPOCH[105/1000] loss0.023-|Sample:0.14|
# EPOCH[106/1000] loss0.022-|Sample:0.14|
# EPOCH[107/1000] loss0.022-|Sample:0.14|
# EPOCH[108/1000] loss0.022-|Sample:0.14|
# EPOCH[109/1000] loss0.022-|Sample:0.14|
# EPOCH[110/1000] loss0.022-|Sample:0.14|
# [TEST]
# {'precision': array([0.05148871]), 'recall': array([0.17036602]), 'ndcg': array([0.1438717])}
# EPOCH[111/1000] loss0.022-|Sample:0.13|
# EPOCH[112/1000] loss0.022-|Sample:0.14|
# EPOCH[113/1000] loss0.022-|Sample:0.14|
# EPOCH[114/1000] loss0.022-|Sample:0.14|
# EPOCH[115/1000] loss0.021-|Sample:0.13|
# EPOCH[116/1000] loss0.021-|Sample:0.14|
# EPOCH[117/1000] loss0.021-|Sample:0.14|
# EPOCH[118/1000] loss0.021-|Sample:0.13|
# EPOCH[119/1000] loss0.021-|Sample:0.14|
# EPOCH[120/1000] loss0.021-|Sample:0.14|
# [TEST]
# {'precision': array([0.05203798]), 'recall': array([0.17186572]), 'ndcg': array([0.14552163])}
# EPOCH[121/1000] loss0.021-|Sample:0.14|
# EPOCH[122/1000] loss0.021-|Sample:0.14|
# EPOCH[123/1000] loss0.020-|Sample:0.15|
# EPOCH[124/1000] loss0.020-|Sample:0.15|
# EPOCH[125/1000] loss0.021-|Sample:0.14|
# EPOCH[126/1000] loss0.020-|Sample:0.14|
# EPOCH[127/1000] loss0.021-|Sample:0.14|
# EPOCH[128/1000] loss0.021-|Sample:0.14|
# EPOCH[129/1000] loss0.020-|Sample:0.14|
# EPOCH[130/1000] loss0.020-|Sample:0.16|
# [TEST]
# {'precision': array([0.05253031]), 'recall': array([0.17337373]), 'ndcg': array([0.14694638])}
# EPOCH[131/1000] loss0.020-|Sample:0.13|
# EPOCH[132/1000] loss0.020-|Sample:0.14|
# EPOCH[133/1000] loss0.020-|Sample:0.14|
# EPOCH[134/1000] loss0.020-|Sample:0.14|
# EPOCH[135/1000] loss0.019-|Sample:0.14|
# EPOCH[136/1000] loss0.019-|Sample:0.14|
# EPOCH[137/1000] loss0.020-|Sample:0.14|
# EPOCH[138/1000] loss0.019-|Sample:0.14|
# EPOCH[139/1000] loss0.020-|Sample:0.14|
# EPOCH[140/1000] loss0.019-|Sample:0.14|
# [TEST]
# {'precision': array([0.0529925]), 'recall': array([0.17498268]), 'ndcg': array([0.14796938])}
# EPOCH[141/1000] loss0.019-|Sample:0.13|
# EPOCH[142/1000] loss0.020-|Sample:0.14|
# EPOCH[143/1000] loss0.019-|Sample:0.13|
# EPOCH[144/1000] loss0.019-|Sample:0.14|
# EPOCH[145/1000] loss0.019-|Sample:0.14|
# EPOCH[146/1000] loss0.019-|Sample:0.14|
# EPOCH[147/1000] loss0.019-|Sample:0.22|
# EPOCH[148/1000] loss0.019-|Sample:0.14|
# EPOCH[149/1000] loss0.019-|Sample:0.14|
# EPOCH[150/1000] loss0.019-|Sample:0.13|
# [TEST]
# {'precision': array([0.05352167]), 'recall': array([0.17634866]), 'ndcg': array([0.1491577])}
# EPOCH[151/1000] loss0.019-|Sample:0.15|
# EPOCH[152/1000] loss0.019-|Sample:0.20|
# EPOCH[153/1000] loss0.019-|Sample:0.13|
# EPOCH[154/1000] loss0.018-|Sample:0.14|
# EPOCH[155/1000] loss0.018-|Sample:0.14|
# EPOCH[156/1000] loss0.019-|Sample:0.14|
# EPOCH[157/1000] loss0.019-|Sample:0.14|
# EPOCH[158/1000] loss0.018-|Sample:0.13|
# EPOCH[159/1000] loss0.019-|Sample:0.14|
# EPOCH[160/1000] loss0.018-|Sample:0.14|
# [TEST]
# {'precision': array([0.05392525]), 'recall': array([0.17769545]), 'ndcg': array([0.15036131])}
# EPOCH[161/1000] loss0.018-|Sample:0.16|
# EPOCH[162/1000] loss0.018-|Sample:0.16|
# EPOCH[163/1000] loss0.018-|Sample:0.15|
# EPOCH[164/1000] loss0.018-|Sample:0.14|
# EPOCH[165/1000] loss0.018-|Sample:0.14|
# EPOCH[166/1000] loss0.018-|Sample:0.14|
# EPOCH[167/1000] loss0.018-|Sample:0.13|
# EPOCH[168/1000] loss0.018-|Sample:0.13|
# EPOCH[169/1000] loss0.018-|Sample:0.14|
# EPOCH[170/1000] loss0.018-|Sample:0.13|
# [TEST]
# {'precision': array([0.05422165]), 'recall': array([0.17834573]), 'ndcg': array([0.15120587])}
# EPOCH[171/1000] loss0.018-|Sample:0.14|
# EPOCH[172/1000] loss0.018-|Sample:0.14|
# EPOCH[173/1000] loss0.018-|Sample:0.13|
# EPOCH[174/1000] loss0.017-|Sample:0.14|
# EPOCH[175/1000] loss0.018-|Sample:0.15|
# EPOCH[176/1000] loss0.017-|Sample:0.14|
# EPOCH[177/1000] loss0.018-|Sample:0.13|
# EPOCH[178/1000] loss0.018-|Sample:0.13|
# EPOCH[179/1000] loss0.017-|Sample:0.14|
# EPOCH[180/1000] loss0.018-|Sample:0.14|
# [TEST]
# {'precision': array([0.05461015]), 'recall': array([0.17977231]), 'ndcg': array([0.15222113])}
# EPOCH[181/1000] loss0.017-|Sample:0.13|
# EPOCH[182/1000] loss0.017-|Sample:0.14|
# EPOCH[183/1000] loss0.017-|Sample:0.14|
# EPOCH[184/1000] loss0.017-|Sample:0.14|
# EPOCH[185/1000] loss0.017-|Sample:0.14|
# EPOCH[186/1000] loss0.017-|Sample:0.14|
# EPOCH[187/1000] loss0.017-|Sample:0.14|
# EPOCH[188/1000] loss0.017-|Sample:0.14|
# EPOCH[189/1000] loss0.017-|Sample:0.15|
# EPOCH[190/1000] loss0.017-|Sample:0.15|
# [TEST]
# {'precision': array([0.0548312]), 'recall': array([0.18031359]), 'ndcg': array([0.15280682])}
# EPOCH[191/1000] loss0.017-|Sample:0.13|
# EPOCH[192/1000] loss0.017-|Sample:0.17|
# EPOCH[193/1000] loss0.017-|Sample:0.14|
# EPOCH[194/1000] loss0.017-|Sample:0.14|
# EPOCH[195/1000] loss0.017-|Sample:0.14|
# EPOCH[196/1000] loss0.017-|Sample:0.14|
# EPOCH[197/1000] loss0.017-|Sample:0.13|
# EPOCH[198/1000] loss0.017-|Sample:0.14|
# EPOCH[199/1000] loss0.017-|Sample:0.14|
# EPOCH[200/1000] loss0.017-|Sample:0.13|
# [TEST]
# {'precision': array([0.05524817]), 'recall': array([0.18156873]), 'ndcg': array([0.15394706])}
# EPOCH[201/1000] loss0.017-|Sample:0.14|
# EPOCH[202/1000] loss0.017-|Sample:0.14|
# EPOCH[203/1000] loss0.016-|Sample:0.14|
# EPOCH[204/1000] loss0.016-|Sample:0.13|
# EPOCH[205/1000] loss0.016-|Sample:0.14|
# EPOCH[206/1000] loss0.016-|Sample:0.14|
# EPOCH[207/1000] loss0.016-|Sample:0.14|
# EPOCH[208/1000] loss0.016-|Sample:0.14|
# EPOCH[209/1000] loss0.016-|Sample:0.14|
# EPOCH[210/1000] loss0.017-|Sample:0.14|
# [TEST]
# {'precision': array([0.05540559]), 'recall': array([0.18218624]), 'ndcg': array([0.15444902])}
# EPOCH[211/1000] loss0.016-|Sample:0.13|
# EPOCH[212/1000] loss0.016-|Sample:0.14|
# EPOCH[213/1000] loss0.016-|Sample:0.13|
# EPOCH[214/1000] loss0.016-|Sample:0.13|
# EPOCH[215/1000] loss0.017-|Sample:0.14|
# EPOCH[216/1000] loss0.016-|Sample:0.14|
# EPOCH[217/1000] loss0.016-|Sample:0.14|
# EPOCH[218/1000] loss0.016-|Sample:0.14|
# EPOCH[219/1000] loss0.016-|Sample:0.14|
# EPOCH[220/1000] loss0.016-|Sample:0.14|
# [TEST]
# {'precision': array([0.05561993]), 'recall': array([0.18300274]), 'ndcg': array([0.15496745])}
# EPOCH[221/1000] loss0.016-|Sample:0.13|
# EPOCH[222/1000] loss0.016-|Sample:0.14|
# EPOCH[223/1000] loss0.016-|Sample:0.13|
# EPOCH[224/1000] loss0.016-|Sample:0.14|
# EPOCH[225/1000] loss0.016-|Sample:0.14|
# EPOCH[226/1000] loss0.016-|Sample:0.14|
# EPOCH[227/1000] loss0.016-|Sample:0.14|
# EPOCH[228/1000] loss0.016-|Sample:0.14|
# EPOCH[229/1000] loss0.016-|Sample:0.14|
# EPOCH[230/1000] loss0.016-|Sample:0.14|
# [TEST]
# {'precision': array([0.05569362]), 'recall': array([0.18322664]), 'ndcg': array([0.15548326])}
# EPOCH[231/1000] loss0.016-|Sample:0.16|
# EPOCH[232/1000] loss0.016-|Sample:0.14|
# EPOCH[233/1000] loss0.016-|Sample:0.14|
# EPOCH[234/1000] loss0.016-|Sample:0.13|
# EPOCH[235/1000] loss0.016-|Sample:0.14|
# EPOCH[236/1000] loss0.016-|Sample:0.14|
# EPOCH[237/1000] loss0.016-|Sample:0.13|
# EPOCH[238/1000] loss0.016-|Sample:0.14|
# EPOCH[239/1000] loss0.016-|Sample:0.14|
# EPOCH[240/1000] loss0.016-|Sample:0.16|
# [TEST]
# {'precision': array([0.05596658]), 'recall': array([0.18412622]), 'ndcg': array([0.15585293])}
# EPOCH[241/1000] loss0.016-|Sample:0.13|
# EPOCH[242/1000] loss0.016-|Sample:0.14|
# EPOCH[243/1000] loss0.015-|Sample:0.14|
# EPOCH[244/1000] loss0.015-|Sample:0.13|
# EPOCH[245/1000] loss0.015-|Sample:0.14|
# EPOCH[246/1000] loss0.015-|Sample:0.14|
# EPOCH[247/1000] loss0.016-|Sample:0.14|
# EPOCH[248/1000] loss0.016-|Sample:0.14|
# EPOCH[249/1000] loss0.015-|Sample:0.14|
# EPOCH[250/1000] loss0.016-|Sample:0.14|
# [TEST]
# {'precision': array([0.05598332]), 'recall': array([0.18408589]), 'ndcg': array([0.15626144])}
# EPOCH[251/1000] loss0.016-|Sample:0.14|
# EPOCH[252/1000] loss0.016-|Sample:0.14|
# EPOCH[253/1000] loss0.015-|Sample:0.14|
# EPOCH[254/1000] loss0.015-|Sample:0.14|
# EPOCH[255/1000] loss0.015-|Sample:0.14|
# EPOCH[256/1000] loss0.015-|Sample:0.14|
# EPOCH[257/1000] loss0.015-|Sample:0.14|
# EPOCH[258/1000] loss0.015-|Sample:0.14|
# EPOCH[259/1000] loss0.015-|Sample:0.14|
# EPOCH[260/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.05638857]), 'recall': array([0.18494406]), 'ndcg': array([0.15699376])}
# EPOCH[261/1000] loss0.015-|Sample:0.15|
# EPOCH[262/1000] loss0.015-|Sample:0.13|
# EPOCH[263/1000] loss0.015-|Sample:0.14|
# EPOCH[264/1000] loss0.015-|Sample:0.13|
# EPOCH[265/1000] loss0.015-|Sample:0.14|
# EPOCH[266/1000] loss0.015-|Sample:0.14|
# EPOCH[267/1000] loss0.015-|Sample:0.13|
# EPOCH[268/1000] loss0.015-|Sample:0.13|
# EPOCH[269/1000] loss0.015-|Sample:0.13|
# EPOCH[270/1000] loss0.015-|Sample:0.14|
# [TEST]
# {'precision': array([0.05630484]), 'recall': array([0.18509736]), 'ndcg': array([0.1570116])}
# EPOCH[271/1000] loss0.015-|Sample:0.13|
# EPOCH[272/1000] loss0.015-|Sample:0.14|
# EPOCH[273/1000] loss0.015-|Sample:0.14|
# EPOCH[274/1000] loss0.015-|Sample:0.14|
# EPOCH[275/1000] loss0.015-|Sample:0.14|
# EPOCH[276/1000] loss0.015-|Sample:0.14|
# EPOCH[277/1000] loss0.015-|Sample:0.14|
# EPOCH[278/1000] loss0.015-|Sample:0.14|
# EPOCH[279/1000] loss0.015-|Sample:0.14|
# EPOCH[280/1000] loss0.015-|Sample:0.14|
# [TEST]
# {'precision': array([0.05640699]), 'recall': array([0.18501864]), 'ndcg': array([0.15707275])}
# EPOCH[281/1000] loss0.015-|Sample:0.12|
# EPOCH[282/1000] loss0.015-|Sample:0.14|
# EPOCH[283/1000] loss0.015-|Sample:0.14|
# EPOCH[284/1000] loss0.015-|Sample:0.13|
# EPOCH[285/1000] loss0.015-|Sample:0.14|
# EPOCH[286/1000] loss0.015-|Sample:0.14|
# EPOCH[287/1000] loss0.015-|Sample:0.13|
# EPOCH[288/1000] loss0.015-|Sample:0.14|
# EPOCH[289/1000] loss0.015-|Sample:0.13|
# EPOCH[290/1000] loss0.015-|Sample:0.14|
# [TEST]
# {'precision': array([0.05662134]), 'recall': array([0.18537907]), 'ndcg': array([0.15752642])}
# EPOCH[291/1000] loss0.015-|Sample:0.15|
# EPOCH[292/1000] loss0.015-|Sample:0.13|
# EPOCH[293/1000] loss0.015-|Sample:0.14|
# EPOCH[294/1000] loss0.015-|Sample:0.14|
# EPOCH[295/1000] loss0.015-|Sample:0.14|
# EPOCH[296/1000] loss0.015-|Sample:0.14|
# EPOCH[297/1000] loss0.015-|Sample:0.14|
# EPOCH[298/1000] loss0.015-|Sample:0.14|
# EPOCH[299/1000] loss0.015-|Sample:0.14|
# EPOCH[300/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.05664479]), 'recall': array([0.18564051]), 'ndcg': array([0.1574889])}
# EPOCH[301/1000] loss0.015-|Sample:0.16|
# EPOCH[302/1000] loss0.015-|Sample:0.14|
# EPOCH[303/1000] loss0.015-|Sample:0.14|
# EPOCH[304/1000] loss0.015-|Sample:0.13|
# EPOCH[305/1000] loss0.015-|Sample:0.14|
# EPOCH[306/1000] loss0.015-|Sample:0.13|
# EPOCH[307/1000] loss0.014-|Sample:0.14|
# EPOCH[308/1000] loss0.015-|Sample:0.14|
# EPOCH[309/1000] loss0.015-|Sample:0.14|
# EPOCH[310/1000] loss0.015-|Sample:0.14|
# [TEST]
# {'precision': array([0.0568876]), 'recall': array([0.18625569]), 'ndcg': array([0.15783777])}
# EPOCH[311/1000] loss0.015-|Sample:0.13|
# EPOCH[312/1000] loss0.014-|Sample:0.13|
# EPOCH[313/1000] loss0.014-|Sample:0.14|
# EPOCH[314/1000] loss0.014-|Sample:0.13|
# EPOCH[315/1000] loss0.014-|Sample:0.14|
# EPOCH[316/1000] loss0.014-|Sample:0.14|
# EPOCH[317/1000] loss0.015-|Sample:0.14|
# EPOCH[318/1000] loss0.014-|Sample:0.14|
# EPOCH[319/1000] loss0.015-|Sample:0.14|
# EPOCH[320/1000] loss0.015-|Sample:0.14|
# [TEST]
# {'precision': array([0.05676703]), 'recall': array([0.1856091]), 'ndcg': array([0.15791822])}
# EPOCH[321/1000] loss0.014-|Sample:0.16|
# EPOCH[322/1000] loss0.015-|Sample:0.14|
# EPOCH[323/1000] loss0.014-|Sample:0.14|
# EPOCH[324/1000] loss0.015-|Sample:0.14|
# EPOCH[325/1000] loss0.014-|Sample:0.14|
# EPOCH[326/1000] loss0.015-|Sample:0.14|
# EPOCH[327/1000] loss0.014-|Sample:0.13|
# EPOCH[328/1000] loss0.014-|Sample:0.16|
# EPOCH[329/1000] loss0.014-|Sample:0.17|
# EPOCH[330/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05696966]), 'recall': array([0.18640916]), 'ndcg': array([0.15845247])}
# EPOCH[331/1000] loss0.014-|Sample:0.16|
# EPOCH[332/1000] loss0.014-|Sample:0.14|
# EPOCH[333/1000] loss0.014-|Sample:0.14|
# EPOCH[334/1000] loss0.014-|Sample:0.13|
# EPOCH[335/1000] loss0.014-|Sample:0.14|
# EPOCH[336/1000] loss0.014-|Sample:0.14|
# EPOCH[337/1000] loss0.014-|Sample:0.14|
# EPOCH[338/1000] loss0.015-|Sample:0.14|
# EPOCH[339/1000] loss0.014-|Sample:0.14|
# EPOCH[340/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05701989]), 'recall': array([0.18636513]), 'ndcg': array([0.15830867])}
# EPOCH[341/1000] loss0.014-|Sample:0.13|
# EPOCH[342/1000] loss0.014-|Sample:0.14|
# EPOCH[343/1000] loss0.014-|Sample:0.14|
# EPOCH[344/1000] loss0.014-|Sample:0.14|
# EPOCH[345/1000] loss0.014-|Sample:0.14|
# EPOCH[346/1000] loss0.014-|Sample:0.14|
# EPOCH[347/1000] loss0.014-|Sample:0.14|
# EPOCH[348/1000] loss0.014-|Sample:0.13|
# EPOCH[349/1000] loss0.014-|Sample:0.14|
# EPOCH[350/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05713377]), 'recall': array([0.18689266]), 'ndcg': array([0.15864667])}
# EPOCH[351/1000] loss0.014-|Sample:0.13|
# EPOCH[352/1000] loss0.014-|Sample:0.14|
# EPOCH[353/1000] loss0.014-|Sample:0.14|
# EPOCH[354/1000] loss0.014-|Sample:0.13|
# EPOCH[355/1000] loss0.014-|Sample:0.14|
# EPOCH[356/1000] loss0.014-|Sample:0.14|
# EPOCH[357/1000] loss0.014-|Sample:0.14|
# EPOCH[358/1000] loss0.014-|Sample:0.13|
# EPOCH[359/1000] loss0.014-|Sample:0.14|
# EPOCH[360/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05725434]), 'recall': array([0.18734012]), 'ndcg': array([0.1589687])}
# EPOCH[361/1000] loss0.014-|Sample:0.14|
# EPOCH[362/1000] loss0.014-|Sample:0.14|
# EPOCH[363/1000] loss0.014-|Sample:0.14|
# EPOCH[364/1000] loss0.014-|Sample:0.14|
# EPOCH[365/1000] loss0.014-|Sample:0.14|
# EPOCH[366/1000] loss0.014-|Sample:0.14|
# EPOCH[367/1000] loss0.014-|Sample:0.14|
# EPOCH[368/1000] loss0.014-|Sample:0.14|
# EPOCH[369/1000] loss0.014-|Sample:0.14|
# EPOCH[370/1000] loss0.014-|Sample:0.15|
# [TEST]
# {'precision': array([0.05712372]), 'recall': array([0.18676722]), 'ndcg': array([0.15879259])}
# EPOCH[371/1000] loss0.014-|Sample:0.16|
# EPOCH[372/1000] loss0.014-|Sample:0.14|
# EPOCH[373/1000] loss0.014-|Sample:0.14|
# EPOCH[374/1000] loss0.014-|Sample:0.14|
# EPOCH[375/1000] loss0.014-|Sample:0.14|
# EPOCH[376/1000] loss0.014-|Sample:0.14|
# EPOCH[377/1000] loss0.014-|Sample:0.13|
# EPOCH[378/1000] loss0.014-|Sample:0.14|
# EPOCH[379/1000] loss0.014-|Sample:0.14|
# EPOCH[380/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05724596]), 'recall': array([0.18733423]), 'ndcg': array([0.15906482])}
# EPOCH[381/1000] loss0.014-|Sample:0.13|
# EPOCH[382/1000] loss0.014-|Sample:0.14|
# EPOCH[383/1000] loss0.014-|Sample:0.14|
# EPOCH[384/1000] loss0.014-|Sample:0.13|
# EPOCH[385/1000] loss0.014-|Sample:0.14|
# EPOCH[386/1000] loss0.014-|Sample:0.14|
# EPOCH[387/1000] loss0.014-|Sample:0.13|
# EPOCH[388/1000] loss0.014-|Sample:0.13|
# EPOCH[389/1000] loss0.014-|Sample:0.14|
# EPOCH[390/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05742849]), 'recall': array([0.18753107]), 'ndcg': array([0.1593678])}
# EPOCH[391/1000] loss0.014-|Sample:0.13|
# EPOCH[392/1000] loss0.014-|Sample:0.14|
# EPOCH[393/1000] loss0.014-|Sample:0.14|
# EPOCH[394/1000] loss0.014-|Sample:0.14|
# EPOCH[395/1000] loss0.014-|Sample:0.14|
# EPOCH[396/1000] loss0.014-|Sample:0.14|
# EPOCH[397/1000] loss0.014-|Sample:0.14|
# EPOCH[398/1000] loss0.014-|Sample:0.14|
# EPOCH[399/1000] loss0.014-|Sample:0.14|
# EPOCH[400/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05738496]), 'recall': array([0.18747322]), 'ndcg': array([0.1593918])}
# EPOCH[401/1000] loss0.014-|Sample:0.16|
# EPOCH[402/1000] loss0.014-|Sample:0.14|
# EPOCH[403/1000] loss0.014-|Sample:0.13|
# EPOCH[404/1000] loss0.014-|Sample:0.13|
# EPOCH[405/1000] loss0.014-|Sample:0.13|
# EPOCH[406/1000] loss0.014-|Sample:0.14|
# EPOCH[407/1000] loss0.014-|Sample:0.13|
# EPOCH[408/1000] loss0.014-|Sample:0.14|
# EPOCH[409/1000] loss0.014-|Sample:0.14|
# EPOCH[410/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05755744]), 'recall': array([0.18800398]), 'ndcg': array([0.15955171])}
# EPOCH[411/1000] loss0.014-|Sample:0.16|
# EPOCH[412/1000] loss0.014-|Sample:0.14|
# EPOCH[413/1000] loss0.014-|Sample:0.14|
# EPOCH[414/1000] loss0.014-|Sample:0.14|
# EPOCH[415/1000] loss0.014-|Sample:0.13|
# EPOCH[416/1000] loss0.014-|Sample:0.14|
# EPOCH[417/1000] loss0.014-|Sample:0.14|
# EPOCH[418/1000] loss0.014-|Sample:0.14|
# EPOCH[419/1000] loss0.014-|Sample:0.14|
# EPOCH[420/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05760265]), 'recall': array([0.1878831]), 'ndcg': array([0.15949777])}
# EPOCH[421/1000] loss0.014-|Sample:0.14|
# EPOCH[422/1000] loss0.014-|Sample:0.14|
# EPOCH[423/1000] loss0.014-|Sample:0.19|
# EPOCH[424/1000] loss0.014-|Sample:0.14|
# EPOCH[425/1000] loss0.014-|Sample:0.14|
# EPOCH[426/1000] loss0.014-|Sample:0.14|
# EPOCH[427/1000] loss0.014-|Sample:0.14|
# EPOCH[428/1000] loss0.014-|Sample:0.14|
# EPOCH[429/1000] loss0.014-|Sample:0.14|
# EPOCH[430/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05767466]), 'recall': array([0.18817275]), 'ndcg': array([0.15976357])}
# EPOCH[431/1000] loss0.014-|Sample:0.13|
# EPOCH[432/1000] loss0.014-|Sample:0.14|
# EPOCH[433/1000] loss0.014-|Sample:0.14|
# EPOCH[434/1000] loss0.014-|Sample:0.14|
# EPOCH[435/1000] loss0.014-|Sample:0.17|
# EPOCH[436/1000] loss0.014-|Sample:0.16|
# EPOCH[437/1000] loss0.014-|Sample:0.14|
# EPOCH[438/1000] loss0.014-|Sample:0.13|
# EPOCH[439/1000] loss0.014-|Sample:0.14|
# EPOCH[440/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.0576981]), 'recall': array([0.18834565]), 'ndcg': array([0.15971991])}
# EPOCH[441/1000] loss0.014-|Sample:0.14|
# EPOCH[442/1000] loss0.014-|Sample:0.14|
# EPOCH[443/1000] loss0.014-|Sample:0.14|
# EPOCH[444/1000] loss0.014-|Sample:0.14|
# EPOCH[445/1000] loss0.014-|Sample:0.14|
# EPOCH[446/1000] loss0.013-|Sample:0.13|
# EPOCH[447/1000] loss0.014-|Sample:0.14|
# EPOCH[448/1000] loss0.014-|Sample:0.14|
# EPOCH[449/1000] loss0.014-|Sample:0.14|
# EPOCH[450/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05771318]), 'recall': array([0.18805358]), 'ndcg': array([0.15981853])}
# EPOCH[451/1000] loss0.014-|Sample:0.13|
# EPOCH[452/1000] loss0.014-|Sample:0.14|
# EPOCH[453/1000] loss0.014-|Sample:0.14|
# EPOCH[454/1000] loss0.014-|Sample:0.13|
# EPOCH[455/1000] loss0.014-|Sample:0.13|
# EPOCH[456/1000] loss0.014-|Sample:0.14|
# EPOCH[457/1000] loss0.014-|Sample:0.14|
# EPOCH[458/1000] loss0.014-|Sample:0.14|
# EPOCH[459/1000] loss0.014-|Sample:0.14|
# EPOCH[460/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05775672]), 'recall': array([0.18821451]), 'ndcg': array([0.15976943])}
# EPOCH[461/1000] loss0.014-|Sample:0.13|
# EPOCH[462/1000] loss0.014-|Sample:0.14|
# EPOCH[463/1000] loss0.014-|Sample:0.15|
# EPOCH[464/1000] loss0.014-|Sample:0.14|
# EPOCH[465/1000] loss0.014-|Sample:0.14|
# EPOCH[466/1000] loss0.013-|Sample:0.13|
# EPOCH[467/1000] loss0.013-|Sample:0.13|
# EPOCH[468/1000] loss0.014-|Sample:0.13|
# EPOCH[469/1000] loss0.014-|Sample:0.14|
# EPOCH[470/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05797274]), 'recall': array([0.18856242]), 'ndcg': array([0.1601539])}
# EPOCH[471/1000] loss0.013-|Sample:0.15|
# EPOCH[472/1000] loss0.014-|Sample:0.14|
# EPOCH[473/1000] loss0.014-|Sample:0.14|
# EPOCH[474/1000] loss0.014-|Sample:0.14|
# EPOCH[475/1000] loss0.014-|Sample:0.14|
# EPOCH[476/1000] loss0.013-|Sample:0.14|
# EPOCH[477/1000] loss0.013-|Sample:0.14|
# EPOCH[478/1000] loss0.014-|Sample:0.14|
# EPOCH[479/1000] loss0.014-|Sample:0.14|
# EPOCH[480/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05797441]), 'recall': array([0.18858506]), 'ndcg': array([0.16055566])}
# EPOCH[481/1000] loss0.014-|Sample:0.14|
# EPOCH[482/1000] loss0.013-|Sample:0.14|
# EPOCH[483/1000] loss0.013-|Sample:0.14|
# EPOCH[484/1000] loss0.013-|Sample:0.14|
# EPOCH[485/1000] loss0.013-|Sample:0.14|
# EPOCH[486/1000] loss0.014-|Sample:0.14|
# EPOCH[487/1000] loss0.013-|Sample:0.16|
# EPOCH[488/1000] loss0.013-|Sample:0.14|
# EPOCH[489/1000] loss0.014-|Sample:0.14|
# EPOCH[490/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.0579225]), 'recall': array([0.18843584]), 'ndcg': array([0.16025867])}
# EPOCH[491/1000] loss0.014-|Sample:0.14|
# EPOCH[492/1000] loss0.014-|Sample:0.14|
# EPOCH[493/1000] loss0.013-|Sample:0.14|
# EPOCH[494/1000] loss0.013-|Sample:0.14|
# EPOCH[495/1000] loss0.013-|Sample:0.14|
# EPOCH[496/1000] loss0.014-|Sample:0.14|
# EPOCH[497/1000] loss0.013-|Sample:0.14|
# EPOCH[498/1000] loss0.013-|Sample:0.14|
# EPOCH[499/1000] loss0.013-|Sample:0.14|
# EPOCH[500/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05797776]), 'recall': array([0.18846811]), 'ndcg': array([0.16047346])}
# EPOCH[501/1000] loss0.013-|Sample:0.16|
# EPOCH[502/1000] loss0.013-|Sample:0.14|
# EPOCH[503/1000] loss0.014-|Sample:0.14|
# EPOCH[504/1000] loss0.014-|Sample:0.14|
# EPOCH[505/1000] loss0.013-|Sample:0.14|
# EPOCH[506/1000] loss0.013-|Sample:0.14|
# EPOCH[507/1000] loss0.013-|Sample:0.13|
# EPOCH[508/1000] loss0.014-|Sample:0.14|
# EPOCH[509/1000] loss0.014-|Sample:0.14|
# EPOCH[510/1000] loss0.013-|Sample:0.17|
# [TEST]
# {'precision': array([0.05796604]), 'recall': array([0.18848472]), 'ndcg': array([0.16023699])}
# EPOCH[511/1000] loss0.013-|Sample:0.16|
# EPOCH[512/1000] loss0.013-|Sample:0.13|
# EPOCH[513/1000] loss0.013-|Sample:0.14|
# EPOCH[514/1000] loss0.013-|Sample:0.14|
# EPOCH[515/1000] loss0.013-|Sample:0.14|
# EPOCH[516/1000] loss0.013-|Sample:0.14|
# EPOCH[517/1000] loss0.014-|Sample:0.14|
# EPOCH[518/1000] loss0.013-|Sample:0.14|
# EPOCH[519/1000] loss0.013-|Sample:0.14|
# EPOCH[520/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05804809]), 'recall': array([0.18852273]), 'ndcg': array([0.16048637])}
# EPOCH[521/1000] loss0.013-|Sample:0.15|
# EPOCH[522/1000] loss0.013-|Sample:0.14|
# EPOCH[523/1000] loss0.013-|Sample:0.17|
# EPOCH[524/1000] loss0.013-|Sample:0.14|
# EPOCH[525/1000] loss0.013-|Sample:0.13|
# EPOCH[526/1000] loss0.013-|Sample:0.14|
# EPOCH[527/1000] loss0.013-|Sample:0.14|
# EPOCH[528/1000] loss0.013-|Sample:0.14|
# EPOCH[529/1000] loss0.013-|Sample:0.14|
# EPOCH[530/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05797944]), 'recall': array([0.18845988]), 'ndcg': array([0.1603239])}
# EPOCH[531/1000] loss0.013-|Sample:0.13|
# EPOCH[532/1000] loss0.013-|Sample:0.17|
# EPOCH[533/1000] loss0.013-|Sample:0.16|
# EPOCH[534/1000] loss0.013-|Sample:0.13|
# EPOCH[535/1000] loss0.013-|Sample:0.14|
# EPOCH[536/1000] loss0.013-|Sample:0.13|
# EPOCH[537/1000] loss0.013-|Sample:0.13|
# EPOCH[538/1000] loss0.013-|Sample:0.14|
# EPOCH[539/1000] loss0.013-|Sample:0.14|
# EPOCH[540/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05800121]), 'recall': array([0.18818566]), 'ndcg': array([0.16031297])}
# EPOCH[541/1000] loss0.013-|Sample:0.15|
# EPOCH[542/1000] loss0.013-|Sample:0.14|
# EPOCH[543/1000] loss0.014-|Sample:0.14|
# EPOCH[544/1000] loss0.013-|Sample:0.14|
# EPOCH[545/1000] loss0.013-|Sample:0.14|
# EPOCH[546/1000] loss0.013-|Sample:0.15|
# EPOCH[547/1000] loss0.013-|Sample:0.14|
# EPOCH[548/1000] loss0.013-|Sample:0.14|
# EPOCH[549/1000] loss0.013-|Sample:0.14|
# EPOCH[550/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05816867]), 'recall': array([0.1890369]), 'ndcg': array([0.16081332])}
# EPOCH[551/1000] loss0.013-|Sample:0.14|
# EPOCH[552/1000] loss0.013-|Sample:0.14|
# EPOCH[553/1000] loss0.013-|Sample:0.14|
# EPOCH[554/1000] loss0.013-|Sample:0.14|
# EPOCH[555/1000] loss0.013-|Sample:0.14|
# EPOCH[556/1000] loss0.013-|Sample:0.14|
# EPOCH[557/1000] loss0.013-|Sample:0.14|
# EPOCH[558/1000] loss0.013-|Sample:0.14|
# EPOCH[559/1000] loss0.013-|Sample:0.13|
# EPOCH[560/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05817704]), 'recall': array([0.18912059]), 'ndcg': array([0.16091316])}
# EPOCH[561/1000] loss0.013-|Sample:0.15|
# EPOCH[562/1000] loss0.013-|Sample:0.13|
# EPOCH[563/1000] loss0.013-|Sample:0.14|
# EPOCH[564/1000] loss0.013-|Sample:0.14|
# EPOCH[565/1000] loss0.013-|Sample:0.14|
# EPOCH[566/1000] loss0.013-|Sample:0.14|
# EPOCH[567/1000] loss0.013-|Sample:0.14|
# EPOCH[568/1000] loss0.013-|Sample:0.14|
# EPOCH[569/1000] loss0.013-|Sample:0.14|
# EPOCH[570/1000] loss0.013-|Sample:0.17|
# [TEST]
# {'precision': array([0.05839306]), 'recall': array([0.19044613]), 'ndcg': array([0.16143932])}
# EPOCH[571/1000] loss0.013-|Sample:0.13|
# EPOCH[572/1000] loss0.013-|Sample:0.13|
# EPOCH[573/1000] loss0.013-|Sample:0.14|
# EPOCH[574/1000] loss0.013-|Sample:0.14|
# EPOCH[575/1000] loss0.013-|Sample:0.14|
# EPOCH[576/1000] loss0.013-|Sample:0.13|
# EPOCH[577/1000] loss0.013-|Sample:0.14|
# EPOCH[578/1000] loss0.013-|Sample:0.14|
# EPOCH[579/1000] loss0.013-|Sample:0.14|
# EPOCH[580/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.0584299]), 'recall': array([0.18988569]), 'ndcg': array([0.16144658])}
# EPOCH[581/1000] loss0.013-|Sample:0.14|
# EPOCH[582/1000] loss0.013-|Sample:0.14|
# EPOCH[583/1000] loss0.013-|Sample:0.14|
# EPOCH[584/1000] loss0.013-|Sample:0.14|
# EPOCH[585/1000] loss0.013-|Sample:0.14|
# EPOCH[586/1000] loss0.013-|Sample:0.14|
# EPOCH[587/1000] loss0.013-|Sample:0.14|
# EPOCH[588/1000] loss0.013-|Sample:0.14|
# EPOCH[589/1000] loss0.013-|Sample:0.14|
# EPOCH[590/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05836124]), 'recall': array([0.18944409]), 'ndcg': array([0.16107913])}
# EPOCH[591/1000] loss0.013-|Sample:0.15|
# EPOCH[592/1000] loss0.013-|Sample:0.14|
# EPOCH[593/1000] loss0.013-|Sample:0.14|
# EPOCH[594/1000] loss0.013-|Sample:0.13|
# EPOCH[595/1000] loss0.013-|Sample:0.14|
# EPOCH[596/1000] loss0.013-|Sample:0.14|
# EPOCH[597/1000] loss0.013-|Sample:0.14|
# EPOCH[598/1000] loss0.013-|Sample:0.14|
# EPOCH[599/1000] loss0.013-|Sample:0.14|
# EPOCH[600/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05832273]), 'recall': array([0.189499]), 'ndcg': array([0.16096934])}
# EPOCH[601/1000] loss0.013-|Sample:0.14|
# EPOCH[602/1000] loss0.013-|Sample:0.14|
# EPOCH[603/1000] loss0.013-|Sample:0.14|
# EPOCH[604/1000] loss0.013-|Sample:0.14|
# EPOCH[605/1000] loss0.013-|Sample:0.14|
# EPOCH[606/1000] loss0.013-|Sample:0.14|
# EPOCH[607/1000] loss0.013-|Sample:0.14|
# EPOCH[608/1000] loss0.013-|Sample:0.14|
# EPOCH[609/1000] loss0.013-|Sample:0.14|
# EPOCH[610/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05830933]), 'recall': array([0.18939286]), 'ndcg': array([0.16095])}
# EPOCH[611/1000] loss0.013-|Sample:0.14|
# EPOCH[612/1000] loss0.013-|Sample:0.13|
# EPOCH[613/1000] loss0.013-|Sample:0.14|
# EPOCH[614/1000] loss0.013-|Sample:0.13|
# EPOCH[615/1000] loss0.013-|Sample:0.14|
# EPOCH[616/1000] loss0.013-|Sample:0.13|
# EPOCH[617/1000] loss0.013-|Sample:0.14|
# EPOCH[618/1000] loss0.013-|Sample:0.14|
# EPOCH[619/1000] loss0.013-|Sample:0.14|
# EPOCH[620/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05843325]), 'recall': array([0.18967988]), 'ndcg': array([0.16146467])}
# EPOCH[621/1000] loss0.013-|Sample:0.15|
# EPOCH[622/1000] loss0.013-|Sample:0.14|
# EPOCH[623/1000] loss0.013-|Sample:0.14|
# EPOCH[624/1000] loss0.013-|Sample:0.14|
# EPOCH[625/1000] loss0.013-|Sample:0.14|
# EPOCH[626/1000] loss0.013-|Sample:0.15|
# EPOCH[627/1000] loss0.013-|Sample:0.13|
# EPOCH[628/1000] loss0.013-|Sample:0.14|
# EPOCH[629/1000] loss0.013-|Sample:0.14|
# EPOCH[630/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05848181]), 'recall': array([0.18964552]), 'ndcg': array([0.16162943])}
# EPOCH[631/1000] loss0.013-|Sample:0.13|
# EPOCH[632/1000] loss0.013-|Sample:0.14|
# EPOCH[633/1000] loss0.013-|Sample:0.16|
# EPOCH[634/1000] loss0.013-|Sample:0.16|
# EPOCH[635/1000] loss0.013-|Sample:0.14|
# EPOCH[636/1000] loss0.013-|Sample:0.14|
# EPOCH[637/1000] loss0.013-|Sample:0.14|
# EPOCH[638/1000] loss0.013-|Sample:0.14|
# EPOCH[639/1000] loss0.013-|Sample:0.14|
# EPOCH[640/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05844665]), 'recall': array([0.18969143]), 'ndcg': array([0.16153928])}
# EPOCH[641/1000] loss0.013-|Sample:0.15|
# EPOCH[642/1000] loss0.013-|Sample:0.14|
# EPOCH[643/1000] loss0.013-|Sample:0.14|
# EPOCH[644/1000] loss0.013-|Sample:0.14|
# EPOCH[645/1000] loss0.013-|Sample:0.14|
# EPOCH[646/1000] loss0.013-|Sample:0.13|
# EPOCH[647/1000] loss0.013-|Sample:0.14|
# EPOCH[648/1000] loss0.013-|Sample:0.14|
# EPOCH[649/1000] loss0.013-|Sample:0.14|
# EPOCH[650/1000] loss0.013-|Sample:0.15|
# [TEST]
# {'precision': array([0.05832273]), 'recall': array([0.18931159]), 'ndcg': array([0.16102679])}
# EPOCH[651/1000] loss0.013-|Sample:0.13|
# EPOCH[652/1000] loss0.013-|Sample:0.14|
# EPOCH[653/1000] loss0.013-|Sample:0.14|
# EPOCH[654/1000] loss0.013-|Sample:0.14|
# EPOCH[655/1000] loss0.013-|Sample:0.14|
# EPOCH[656/1000] loss0.013-|Sample:0.14|
# EPOCH[657/1000] loss0.013-|Sample:0.14|
# EPOCH[658/1000] loss0.013-|Sample:0.13|
# EPOCH[659/1000] loss0.013-|Sample:0.15|
# EPOCH[660/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05841985]), 'recall': array([0.18973305]), 'ndcg': array([0.16172353])}
# EPOCH[661/1000] loss0.013-|Sample:0.15|
# EPOCH[662/1000] loss0.013-|Sample:0.14|
# EPOCH[663/1000] loss0.013-|Sample:0.14|
# EPOCH[664/1000] loss0.013-|Sample:0.14|
# EPOCH[665/1000] loss0.013-|Sample:0.14|
# EPOCH[666/1000] loss0.013-|Sample:0.14|
# EPOCH[667/1000] loss0.013-|Sample:0.13|
# EPOCH[668/1000] loss0.013-|Sample:0.14|
# EPOCH[669/1000] loss0.013-|Sample:0.14|
# EPOCH[670/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.0583244]), 'recall': array([0.18938587]), 'ndcg': array([0.16125961])}
# EPOCH[671/1000] loss0.013-|Sample:0.13|
# EPOCH[672/1000] loss0.013-|Sample:0.14|
# EPOCH[673/1000] loss0.013-|Sample:0.14|
# EPOCH[674/1000] loss0.013-|Sample:0.14|
# EPOCH[675/1000] loss0.013-|Sample:0.14|
# EPOCH[676/1000] loss0.013-|Sample:0.14|
# EPOCH[677/1000] loss0.013-|Sample:0.14|
# EPOCH[678/1000] loss0.013-|Sample:0.13|
# EPOCH[679/1000] loss0.013-|Sample:0.14|
# EPOCH[680/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05843325]), 'recall': array([0.18981692]), 'ndcg': array([0.16139462])}
# EPOCH[681/1000] loss0.013-|Sample:0.13|
# EPOCH[682/1000] loss0.013-|Sample:0.14|
# EPOCH[683/1000] loss0.013-|Sample:0.14|
# EPOCH[684/1000] loss0.013-|Sample:0.13|
# EPOCH[685/1000] loss0.013-|Sample:0.14|
# EPOCH[686/1000] loss0.013-|Sample:0.14|
# EPOCH[687/1000] loss0.013-|Sample:0.14|
# EPOCH[688/1000] loss0.013-|Sample:0.14|
# EPOCH[689/1000] loss0.013-|Sample:0.14|
# EPOCH[690/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05846004]), 'recall': array([0.1897898]), 'ndcg': array([0.16136717])}
# EPOCH[691/1000] loss0.013-|Sample:0.12|
# EPOCH[692/1000] loss0.013-|Sample:0.14|
# EPOCH[693/1000] loss0.013-|Sample:0.15|
# EPOCH[694/1000] loss0.013-|Sample:0.15|
# EPOCH[695/1000] loss0.013-|Sample:0.14|
# EPOCH[696/1000] loss0.013-|Sample:0.14|
# EPOCH[697/1000] loss0.013-|Sample:0.14|
# EPOCH[698/1000] loss0.013-|Sample:0.14|
# EPOCH[699/1000] loss0.013-|Sample:0.14|
# EPOCH[700/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05864927]), 'recall': array([0.19033471]), 'ndcg': array([0.16169586])}
# EPOCH[701/1000] loss0.013-|Sample:0.16|
# EPOCH[702/1000] loss0.013-|Sample:0.15|
# EPOCH[703/1000] loss0.013-|Sample:0.13|
# EPOCH[704/1000] loss0.013-|Sample:0.14|
# EPOCH[705/1000] loss0.013-|Sample:0.14|
# EPOCH[706/1000] loss0.013-|Sample:0.14|
# EPOCH[707/1000] loss0.013-|Sample:0.13|
# EPOCH[708/1000] loss0.013-|Sample:0.14|
# EPOCH[709/1000] loss0.013-|Sample:0.14|
# EPOCH[710/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05849354]), 'recall': array([0.18976277]), 'ndcg': array([0.16162897])}
# EPOCH[711/1000] loss0.013-|Sample:0.14|
# EPOCH[712/1000] loss0.013-|Sample:0.13|
# EPOCH[713/1000] loss0.013-|Sample:0.13|
# EPOCH[714/1000] loss0.013-|Sample:0.14|
# EPOCH[715/1000] loss0.013-|Sample:0.14|
# EPOCH[716/1000] loss0.013-|Sample:0.14|
# EPOCH[717/1000] loss0.013-|Sample:0.12|
# EPOCH[718/1000] loss0.013-|Sample:0.14|
# EPOCH[719/1000] loss0.013-|Sample:0.14|
# EPOCH[720/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05850358]), 'recall': array([0.18976103]), 'ndcg': array([0.1616535])}
# EPOCH[721/1000] loss0.013-|Sample:0.16|
# EPOCH[722/1000] loss0.013-|Sample:0.14|
# EPOCH[723/1000] loss0.013-|Sample:0.13|
# EPOCH[724/1000] loss0.013-|Sample:0.14|
# EPOCH[725/1000] loss0.013-|Sample:0.13|
# EPOCH[726/1000] loss0.013-|Sample:0.13|
# EPOCH[727/1000] loss0.013-|Sample:0.14|
# EPOCH[728/1000] loss0.013-|Sample:0.14|
# EPOCH[729/1000] loss0.013-|Sample:0.14|
# EPOCH[730/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05870956]), 'recall': array([0.19026764]), 'ndcg': array([0.16188792])}
# EPOCH[731/1000] loss0.013-|Sample:0.14|
# EPOCH[732/1000] loss0.013-|Sample:0.14|
# EPOCH[733/1000] loss0.013-|Sample:0.14|
# EPOCH[734/1000] loss0.013-|Sample:0.13|
# EPOCH[735/1000] loss0.013-|Sample:0.14|
# EPOCH[736/1000] loss0.013-|Sample:0.20|
# EPOCH[737/1000] loss0.013-|Sample:0.14|
# EPOCH[738/1000] loss0.013-|Sample:0.13|
# EPOCH[739/1000] loss0.013-|Sample:0.14|
# EPOCH[740/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05860573]), 'recall': array([0.19047822]), 'ndcg': array([0.16179008])}
# EPOCH[741/1000] loss0.013-|Sample:0.14|
# EPOCH[742/1000] loss0.013-|Sample:0.14|
# EPOCH[743/1000] loss0.013-|Sample:0.13|
# EPOCH[744/1000] loss0.013-|Sample:0.14|
# EPOCH[745/1000] loss0.013-|Sample:0.14|
# EPOCH[746/1000] loss0.013-|Sample:0.14|
# EPOCH[747/1000] loss0.013-|Sample:0.14|
# EPOCH[748/1000] loss0.013-|Sample:0.14|
# EPOCH[749/1000] loss0.013-|Sample:0.14|
# EPOCH[750/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05870956]), 'recall': array([0.1902984]), 'ndcg': array([0.16172866])}
# EPOCH[751/1000] loss0.013-|Sample:0.14|
# EPOCH[752/1000] loss0.013-|Sample:0.14|
# EPOCH[753/1000] loss0.013-|Sample:0.14|
# EPOCH[754/1000] loss0.013-|Sample:0.16|
# EPOCH[755/1000] loss0.013-|Sample:0.14|
# EPOCH[756/1000] loss0.013-|Sample:0.16|
# EPOCH[757/1000] loss0.013-|Sample:0.14|
# EPOCH[758/1000] loss0.013-|Sample:0.14|
# EPOCH[759/1000] loss0.013-|Sample:0.14|
# EPOCH[760/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05871123]), 'recall': array([0.19042665]), 'ndcg': array([0.16173214])}
# EPOCH[761/1000] loss0.013-|Sample:0.14|
# EPOCH[762/1000] loss0.013-|Sample:0.13|
# EPOCH[763/1000] loss0.013-|Sample:0.14|
# EPOCH[764/1000] loss0.013-|Sample:0.13|
# EPOCH[765/1000] loss0.013-|Sample:0.13|
# EPOCH[766/1000] loss0.013-|Sample:0.14|
# EPOCH[767/1000] loss0.013-|Sample:0.14|
# EPOCH[768/1000] loss0.013-|Sample:0.14|
# EPOCH[769/1000] loss0.013-|Sample:0.14|
# EPOCH[770/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05877487]), 'recall': array([0.1908759]), 'ndcg': array([0.16223843])}
# EPOCH[771/1000] loss0.013-|Sample:0.13|
# EPOCH[772/1000] loss0.013-|Sample:0.14|
# EPOCH[773/1000] loss0.013-|Sample:0.14|
# EPOCH[774/1000] loss0.013-|Sample:0.14|
# EPOCH[775/1000] loss0.013-|Sample:0.14|
# EPOCH[776/1000] loss0.013-|Sample:0.13|
# EPOCH[777/1000] loss0.013-|Sample:0.14|
# EPOCH[778/1000] loss0.013-|Sample:0.13|
# EPOCH[779/1000] loss0.013-|Sample:0.14|
# EPOCH[780/1000] loss0.013-|Sample:0.15|
# [TEST]
# {'precision': array([0.05872296]), 'recall': array([0.19087475]), 'ndcg': array([0.16227752])}
# EPOCH[781/1000] loss0.013-|Sample:0.15|
# EPOCH[782/1000] loss0.013-|Sample:0.14|
# EPOCH[783/1000] loss0.013-|Sample:0.14|
# EPOCH[784/1000] loss0.013-|Sample:0.14|
# EPOCH[785/1000] loss0.013-|Sample:0.14|
# EPOCH[786/1000] loss0.013-|Sample:0.14|
# EPOCH[787/1000] loss0.013-|Sample:0.14|
# EPOCH[788/1000] loss0.013-|Sample:0.14|
# EPOCH[789/1000] loss0.013-|Sample:0.14|
# EPOCH[790/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05862081]), 'recall': array([0.19019013]), 'ndcg': array([0.16190124])}
# EPOCH[791/1000] loss0.013-|Sample:0.13|
# EPOCH[792/1000] loss0.013-|Sample:0.14|
# EPOCH[793/1000] loss0.013-|Sample:0.14|
# EPOCH[794/1000] loss0.013-|Sample:0.14|
# EPOCH[795/1000] loss0.013-|Sample:0.13|
# EPOCH[796/1000] loss0.013-|Sample:0.14|
# EPOCH[797/1000] loss0.013-|Sample:0.14|
# EPOCH[798/1000] loss0.013-|Sample:0.14|
# EPOCH[799/1000] loss0.013-|Sample:0.14|
# EPOCH[800/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05871793]), 'recall': array([0.19036125]), 'ndcg': array([0.1619181])}
# EPOCH[801/1000] loss0.013-|Sample:0.13|
# EPOCH[802/1000] loss0.013-|Sample:0.14|
# EPOCH[803/1000] loss0.013-|Sample:0.14|
# EPOCH[804/1000] loss0.013-|Sample:0.14|
# EPOCH[805/1000] loss0.013-|Sample:0.14|
# EPOCH[806/1000] loss0.013-|Sample:0.13|
# EPOCH[807/1000] loss0.013-|Sample:0.14|
# EPOCH[808/1000] loss0.013-|Sample:0.13|
# EPOCH[809/1000] loss0.013-|Sample:0.14|
# EPOCH[810/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.0584567]), 'recall': array([0.18987278]), 'ndcg': array([0.16165616])}
# EPOCH[811/1000] loss0.013-|Sample:0.16|
# EPOCH[812/1000] loss0.013-|Sample:0.14|
# EPOCH[813/1000] loss0.013-|Sample:0.13|
# EPOCH[814/1000] loss0.013-|Sample:0.14|
# EPOCH[815/1000] loss0.013-|Sample:0.13|
# EPOCH[816/1000] loss0.013-|Sample:0.14|
# EPOCH[817/1000] loss0.013-|Sample:0.14|
# EPOCH[818/1000] loss0.013-|Sample:0.13|
# EPOCH[819/1000] loss0.013-|Sample:0.14|
# EPOCH[820/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05872798]), 'recall': array([0.19089618]), 'ndcg': array([0.16199155])}
# EPOCH[821/1000] loss0.013-|Sample:0.14|
# EPOCH[822/1000] loss0.013-|Sample:0.14|
# EPOCH[823/1000] loss0.013-|Sample:0.14|
# EPOCH[824/1000] loss0.013-|Sample:0.14|
# EPOCH[825/1000] loss0.013-|Sample:0.14|
# EPOCH[826/1000] loss0.013-|Sample:0.14|
# EPOCH[827/1000] loss0.013-|Sample:0.15|
# EPOCH[828/1000] loss0.013-|Sample:0.14|
# EPOCH[829/1000] loss0.013-|Sample:0.14|
# EPOCH[830/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.0588385]), 'recall': array([0.19076633]), 'ndcg': array([0.16199304])}
# EPOCH[831/1000] loss0.013-|Sample:0.14|
# EPOCH[832/1000] loss0.013-|Sample:0.13|
# EPOCH[833/1000] loss0.013-|Sample:0.13|
# EPOCH[834/1000] loss0.013-|Sample:0.14|
# EPOCH[835/1000] loss0.013-|Sample:0.14|
# EPOCH[836/1000] loss0.013-|Sample:0.14|
# EPOCH[837/1000] loss0.013-|Sample:0.13|
# EPOCH[838/1000] loss0.013-|Sample:0.13|
# EPOCH[839/1000] loss0.013-|Sample:0.14|
# EPOCH[840/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05867607]), 'recall': array([0.19037736]), 'ndcg': array([0.16177833])}
# EPOCH[841/1000] loss0.013-|Sample:0.13|
# EPOCH[842/1000] loss0.013-|Sample:0.14|
# EPOCH[843/1000] loss0.013-|Sample:0.14|
# EPOCH[844/1000] loss0.013-|Sample:0.14|
# EPOCH[845/1000] loss0.013-|Sample:0.14|
# EPOCH[846/1000] loss0.013-|Sample:0.15|
# EPOCH[847/1000] loss0.013-|Sample:0.14|
# EPOCH[848/1000] loss0.013-|Sample:0.14|
# EPOCH[849/1000] loss0.013-|Sample:0.14|
# EPOCH[850/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05868611]), 'recall': array([0.19024548]), 'ndcg': array([0.16184543])}
# EPOCH[851/1000] loss0.013-|Sample:0.15|
# EPOCH[852/1000] loss0.013-|Sample:0.14|
# EPOCH[853/1000] loss0.013-|Sample:0.14|
# EPOCH[854/1000] loss0.013-|Sample:0.14|
# EPOCH[855/1000] loss0.013-|Sample:0.13|
# EPOCH[856/1000] loss0.013-|Sample:0.14|
# EPOCH[857/1000] loss0.013-|Sample:0.14|
# EPOCH[858/1000] loss0.013-|Sample:0.14|
# EPOCH[859/1000] loss0.013-|Sample:0.14|
# EPOCH[860/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05867104]), 'recall': array([0.19026811]), 'ndcg': array([0.16190937])}
# EPOCH[861/1000] loss0.013-|Sample:0.13|
# EPOCH[862/1000] loss0.013-|Sample:0.14|
# EPOCH[863/1000] loss0.013-|Sample:0.14|
# EPOCH[864/1000] loss0.013-|Sample:0.13|
# EPOCH[865/1000] loss0.013-|Sample:0.14|
# EPOCH[866/1000] loss0.013-|Sample:0.14|
# EPOCH[867/1000] loss0.013-|Sample:0.14|
# EPOCH[868/1000] loss0.013-|Sample:0.14|
# EPOCH[869/1000] loss0.013-|Sample:0.14|
# EPOCH[870/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05858564]), 'recall': array([0.19000844]), 'ndcg': array([0.1617901])}
# EPOCH[871/1000] loss0.013-|Sample:0.12|
# EPOCH[872/1000] loss0.013-|Sample:0.13|
# EPOCH[873/1000] loss0.013-|Sample:0.14|
# EPOCH[874/1000] loss0.013-|Sample:0.14|
# EPOCH[875/1000] loss0.013-|Sample:0.14|
# EPOCH[876/1000] loss0.013-|Sample:0.14|
# EPOCH[877/1000] loss0.013-|Sample:0.15|
# EPOCH[878/1000] loss0.013-|Sample:0.14|
# EPOCH[879/1000] loss0.013-|Sample:0.14|
# EPOCH[880/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05859736]), 'recall': array([0.1898512]), 'ndcg': array([0.16170784])}
# EPOCH[881/1000] loss0.013-|Sample:0.13|
# EPOCH[882/1000] loss0.013-|Sample:0.14|
# EPOCH[883/1000] loss0.013-|Sample:0.14|
# EPOCH[884/1000] loss0.013-|Sample:0.14|
# EPOCH[885/1000] loss0.013-|Sample:0.14|
# EPOCH[886/1000] loss0.013-|Sample:0.14|
# EPOCH[887/1000] loss0.013-|Sample:0.14|
# EPOCH[888/1000] loss0.013-|Sample:0.14|
# EPOCH[889/1000] loss0.013-|Sample:0.14|
# EPOCH[890/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05859569]), 'recall': array([0.1898129]), 'ndcg': array([0.1620717])}
# EPOCH[891/1000] loss0.013-|Sample:0.16|
# EPOCH[892/1000] loss0.013-|Sample:0.13|
# EPOCH[893/1000] loss0.013-|Sample:0.13|
# EPOCH[894/1000] loss0.013-|Sample:0.14|
# EPOCH[895/1000] loss0.013-|Sample:0.14|
# EPOCH[896/1000] loss0.013-|Sample:0.14|
# EPOCH[897/1000] loss0.013-|Sample:0.14|
# EPOCH[898/1000] loss0.013-|Sample:0.13|
# EPOCH[899/1000] loss0.013-|Sample:0.14|
# EPOCH[900/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05860071]), 'recall': array([0.19011648]), 'ndcg': array([0.16189003])}
# EPOCH[901/1000] loss0.013-|Sample:0.15|
# EPOCH[902/1000] loss0.013-|Sample:0.13|
# EPOCH[903/1000] loss0.013-|Sample:0.14|
# EPOCH[904/1000] loss0.013-|Sample:0.13|
# EPOCH[905/1000] loss0.013-|Sample:0.14|
# EPOCH[906/1000] loss0.013-|Sample:0.14|
# EPOCH[907/1000] loss0.013-|Sample:0.14|
# EPOCH[908/1000] loss0.013-|Sample:0.13|
# EPOCH[909/1000] loss0.013-|Sample:0.14|
# EPOCH[910/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05850526]), 'recall': array([0.18954006]), 'ndcg': array([0.16160322])}
# EPOCH[911/1000] loss0.013-|Sample:0.14|
# EPOCH[912/1000] loss0.013-|Sample:0.18|
# EPOCH[913/1000] loss0.013-|Sample:0.14|
# EPOCH[914/1000] loss0.013-|Sample:0.13|
# EPOCH[915/1000] loss0.013-|Sample:0.14|
# EPOCH[916/1000] loss0.013-|Sample:0.13|
# EPOCH[917/1000] loss0.013-|Sample:0.14|
# EPOCH[918/1000] loss0.013-|Sample:0.13|
# EPOCH[919/1000] loss0.013-|Sample:0.14|
# EPOCH[920/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05849019]), 'recall': array([0.1894003]), 'ndcg': array([0.16151616])}
# EPOCH[921/1000] loss0.013-|Sample:0.15|
# EPOCH[922/1000] loss0.013-|Sample:0.14|
# EPOCH[923/1000] loss0.013-|Sample:0.14|
# EPOCH[924/1000] loss0.013-|Sample:0.14|
# EPOCH[925/1000] loss0.013-|Sample:0.14|
# EPOCH[926/1000] loss0.013-|Sample:0.14|
# EPOCH[927/1000] loss0.013-|Sample:0.13|
# EPOCH[928/1000] loss0.013-|Sample:0.13|
# EPOCH[929/1000] loss0.013-|Sample:0.14|
# EPOCH[930/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05868444]), 'recall': array([0.19005034]), 'ndcg': array([0.16189534])}
# EPOCH[931/1000] loss0.013-|Sample:0.13|
# EPOCH[932/1000] loss0.013-|Sample:0.13|
# EPOCH[933/1000] loss0.013-|Sample:0.13|
# EPOCH[934/1000] loss0.013-|Sample:0.14|
# EPOCH[935/1000] loss0.013-|Sample:0.14|
# EPOCH[936/1000] loss0.013-|Sample:0.14|
# EPOCH[937/1000] loss0.013-|Sample:0.14|
# EPOCH[938/1000] loss0.013-|Sample:0.14|
# EPOCH[939/1000] loss0.013-|Sample:0.14|
# EPOCH[940/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05853205]), 'recall': array([0.18989068]), 'ndcg': array([0.16180128])}
# EPOCH[941/1000] loss0.013-|Sample:0.13|
# EPOCH[942/1000] loss0.013-|Sample:0.14|
# EPOCH[943/1000] loss0.013-|Sample:0.14|
# EPOCH[944/1000] loss0.013-|Sample:0.13|
# EPOCH[945/1000] loss0.013-|Sample:0.13|
# EPOCH[946/1000] loss0.013-|Sample:0.14|
# EPOCH[947/1000] loss0.013-|Sample:0.14|
# EPOCH[948/1000] loss0.013-|Sample:0.13|
# EPOCH[949/1000] loss0.013-|Sample:0.13|
# EPOCH[950/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05863923]), 'recall': array([0.19010561]), 'ndcg': array([0.16182424])}
# EPOCH[951/1000] loss0.013-|Sample:0.13|
# EPOCH[952/1000] loss0.013-|Sample:0.13|
# EPOCH[953/1000] loss0.013-|Sample:0.14|
# EPOCH[954/1000] loss0.013-|Sample:0.13|
# EPOCH[955/1000] loss0.013-|Sample:0.14|
# EPOCH[956/1000] loss0.013-|Sample:0.14|
# EPOCH[957/1000] loss0.013-|Sample:0.13|
# EPOCH[958/1000] loss0.013-|Sample:0.20|
# EPOCH[959/1000] loss0.013-|Sample:0.14|
# EPOCH[960/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05876649]), 'recall': array([0.19057656]), 'ndcg': array([0.16196109])}
# EPOCH[961/1000] loss0.013-|Sample:0.12|
# EPOCH[962/1000] loss0.013-|Sample:0.13|
# EPOCH[963/1000] loss0.013-|Sample:0.13|
# EPOCH[964/1000] loss0.013-|Sample:0.13|
# EPOCH[965/1000] loss0.013-|Sample:0.14|
# EPOCH[966/1000] loss0.013-|Sample:0.13|
# EPOCH[967/1000] loss0.013-|Sample:0.14|
# EPOCH[968/1000] loss0.013-|Sample:0.13|
# EPOCH[969/1000] loss0.013-|Sample:0.14|
# EPOCH[970/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.0587397]), 'recall': array([0.19056109]), 'ndcg': array([0.16197766])}
# EPOCH[971/1000] loss0.013-|Sample:0.13|
# EPOCH[972/1000] loss0.013-|Sample:0.14|
# EPOCH[973/1000] loss0.013-|Sample:0.14|
# EPOCH[974/1000] loss0.013-|Sample:0.13|
# EPOCH[975/1000] loss0.013-|Sample:0.14|
# EPOCH[976/1000] loss0.013-|Sample:0.14|
# EPOCH[977/1000] loss0.013-|Sample:0.14|
# EPOCH[978/1000] loss0.013-|Sample:0.14|
# EPOCH[979/1000] loss0.013-|Sample:0.14|
# EPOCH[980/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05864927]), 'recall': array([0.19028359]), 'ndcg': array([0.1619609])}
# EPOCH[981/1000] loss0.013-|Sample:0.14|
# EPOCH[982/1000] loss0.013-|Sample:0.14|
# EPOCH[983/1000] loss0.013-|Sample:0.14|
# EPOCH[984/1000] loss0.013-|Sample:0.14|
# EPOCH[985/1000] loss0.013-|Sample:0.13|
# EPOCH[986/1000] loss0.013-|Sample:0.14|
# EPOCH[987/1000] loss0.013-|Sample:0.14|
# EPOCH[988/1000] loss0.013-|Sample:0.14|
# EPOCH[989/1000] loss0.013-|Sample:0.14|
# EPOCH[990/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05865932]), 'recall': array([0.19018981]), 'ndcg': array([0.16190291])}
# EPOCH[991/1000] loss0.013-|Sample:0.13|
# EPOCH[992/1000] loss0.013-|Sample:0.14|
# EPOCH[993/1000] loss0.013-|Sample:0.14|
# EPOCH[994/1000] loss0.013-|Sample:0.14|
# EPOCH[995/1000] loss0.013-|Sample:0.14|
# EPOCH[996/1000] loss0.013-|Sample:0.14|
# EPOCH[997/1000] loss0.013-|Sample:0.13|
# EPOCH[998/1000] loss0.013-|Sample:0.14|
# EPOCH[999/1000] loss0.013-|Sample:0.14|
# EPOCH[1000/1000] loss0.013-|Sample:0.13|
