# %%
# %load main.py
import world
import utils
from world import cprint
import torch
import numpy as np
from tensorboardX import SummaryWriter
import time
import Procedure
from os.path import join
# ==============================
utils.set_seed(world.seed)
print(">>SEED:", world.seed)
# ==============================
import register
from register import dataset

Recmodel = register.MODELS[world.model_name](world.config, dataset)
Recmodel = Recmodel.to(world.device)
bpr = utils.BPRLoss(Recmodel, world.config)

weight_file = utils.getFileName()
print(f"load and save to {weight_file}")
if world.LOAD:
    try:
        Recmodel.load_state_dict(torch.load(weight_file,map_location=torch.device('cpu')))
        world.cprint(f"loaded model weights from {weight_file}")
    except FileNotFoundError:
        print(f"{weight_file} not exists, start from beginning")
Neg_k = 1

# init tensorboard
if world.tensorboard:
    w : SummaryWriter = SummaryWriter(
                                    join(world.BOARD_PATH, time.strftime("%m-%d-%Hh%Mm%Ss-") + "-" + world.comment)
                                    )
else:
    w = None
    world.cprint("not enable tensorflowboard")

try:
    for epoch in range(world.TRAIN_epochs):
        start = time.time()
        if epoch %10 == 0:
            cprint("[TEST]")
            Procedure.Test(dataset, Recmodel, epoch, w, world.config['multicore'])
        output_information = Procedure.BPR_train_original(dataset, Recmodel, bpr, epoch, neg_k=Neg_k,w=w)
        print(f'EPOCH[{epoch+1}/{world.TRAIN_epochs}] {output_information}')
        torch.save(Recmodel.state_dict(), weight_file)
finally:
    if world.tensorboard:
        w.close()
# Out:
# >>SEED: 2020
# loading [../data/gowalla]
# 810128 interactions for training
# 217242 interactions for testing
# gowalla Sparsity : 0.0008396216228570436
# gowalla is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'multicore': 1,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 24
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded heterogeneous graph ...
# don't split the matrix
# loading adjacency matrix
# successfully loaded homogeneous graph ...
# don't split the matrix
# loading degree weight
# successfully loaded heterogeneous degree weight ...
# lgn is already to go(dropout:0)
# load and save to /home/user1/Larry/FGCF/runs/code/checkpoints/lgn-gowalla-3-64.pth.tar
# [TEST]
# {'precision': array([0.00029138]), 'recall': array([0.00094856]), 'ndcg': array([0.00065288])}
# EPOCH[1/1000] loss0.546-|Sample:0.15|
# EPOCH[2/1000] loss0.235-|Sample:0.13|
# EPOCH[3/1000] loss0.154-|Sample:0.13|
# EPOCH[4/1000] loss0.121-|Sample:0.13|
# EPOCH[5/1000] loss0.105-|Sample:0.13|
# EPOCH[6/1000] loss0.093-|Sample:0.13|
# EPOCH[7/1000] loss0.085-|Sample:0.13|
# EPOCH[8/1000] loss0.079-|Sample:0.13|
# EPOCH[9/1000] loss0.075-|Sample:0.14|
# EPOCH[10/1000] loss0.071-|Sample:0.13|
# [TEST]
# {'precision': array([0.03836158]), 'recall': array([0.12449386]), 'ndcg': array([0.1062236])}
# EPOCH[11/1000] loss0.067-|Sample:0.13|
# EPOCH[12/1000] loss0.064-|Sample:0.13|
# EPOCH[13/1000] loss0.061-|Sample:0.13|
# EPOCH[14/1000] loss0.059-|Sample:0.13|
# EPOCH[15/1000] loss0.057-|Sample:0.13|
# EPOCH[16/1000] loss0.055-|Sample:0.13|
# EPOCH[17/1000] loss0.052-|Sample:0.13|
# EPOCH[18/1000] loss0.052-|Sample:0.13|
# EPOCH[19/1000] loss0.051-|Sample:0.13|
# EPOCH[20/1000] loss0.049-|Sample:0.13|
# [TEST]
# {'precision': array([0.04171579]), 'recall': array([0.13693936]), 'ndcg': array([0.11644798])}
# EPOCH[21/1000] loss0.048-|Sample:0.13|
# EPOCH[22/1000] loss0.046-|Sample:0.13|
# EPOCH[23/1000] loss0.045-|Sample:0.13|
# EPOCH[24/1000] loss0.044-|Sample:0.13|
# EPOCH[25/1000] loss0.043-|Sample:0.14|
# EPOCH[26/1000] loss0.042-|Sample:0.14|
# EPOCH[27/1000] loss0.041-|Sample:0.14|
# EPOCH[28/1000] loss0.041-|Sample:0.14|
# EPOCH[29/1000] loss0.040-|Sample:0.14|
# EPOCH[30/1000] loss0.040-|Sample:0.14|
# [TEST]
# {'precision': array([0.04389778]), 'recall': array([0.14440752]), 'ndcg': array([0.12298651])}
# EPOCH[31/1000] loss0.038-|Sample:0.15|
# EPOCH[32/1000] loss0.038-|Sample:0.14|
# EPOCH[33/1000] loss0.037-|Sample:0.13|
# EPOCH[34/1000] loss0.037-|Sample:0.13|
# EPOCH[35/1000] loss0.036-|Sample:0.13|
# EPOCH[36/1000] loss0.035-|Sample:0.13|
# EPOCH[37/1000] loss0.035-|Sample:0.14|
# EPOCH[38/1000] loss0.034-|Sample:0.13|
# EPOCH[39/1000] loss0.033-|Sample:0.13|
# EPOCH[40/1000] loss0.033-|Sample:0.14|
# [TEST]
# {'precision': array([0.04564438]), 'recall': array([0.15051056]), 'ndcg': array([0.12809307])}
# EPOCH[41/1000] loss0.032-|Sample:0.13|
# EPOCH[42/1000] loss0.032-|Sample:0.13|
# EPOCH[43/1000] loss0.032-|Sample:0.13|
# EPOCH[44/1000] loss0.031-|Sample:0.13|
# EPOCH[45/1000] loss0.031-|Sample:0.13|
# EPOCH[46/1000] loss0.030-|Sample:0.14|
# EPOCH[47/1000] loss0.030-|Sample:0.13|
# EPOCH[48/1000] loss0.030-|Sample:0.13|
# EPOCH[49/1000] loss0.030-|Sample:0.14|
# EPOCH[50/1000] loss0.029-|Sample:0.14|
# [TEST]
# {'precision': array([0.04724027]), 'recall': array([0.15616839]), 'ndcg': array([0.13272714])}
# EPOCH[51/1000] loss0.029-|Sample:0.17|
# EPOCH[52/1000] loss0.028-|Sample:0.13|
# EPOCH[53/1000] loss0.028-|Sample:0.13|
# EPOCH[54/1000] loss0.028-|Sample:0.13|
# EPOCH[55/1000] loss0.027-|Sample:0.14|
# EPOCH[56/1000] loss0.027-|Sample:0.13|
# EPOCH[57/1000] loss0.027-|Sample:0.14|
# EPOCH[58/1000] loss0.027-|Sample:0.14|
# EPOCH[59/1000] loss0.026-|Sample:0.13|
# EPOCH[60/1000] loss0.026-|Sample:0.14|
# [TEST]
# {'precision': array([0.0485565]), 'recall': array([0.16060767]), 'ndcg': array([0.136374])}
# EPOCH[61/1000] loss0.026-|Sample:0.15|
# EPOCH[62/1000] loss0.025-|Sample:0.13|
# EPOCH[63/1000] loss0.025-|Sample:0.14|
# EPOCH[64/1000] loss0.025-|Sample:0.14|
# EPOCH[65/1000] loss0.025-|Sample:0.13|
# EPOCH[66/1000] loss0.024-|Sample:0.13|
# EPOCH[67/1000] loss0.024-|Sample:0.14|
# EPOCH[68/1000] loss0.024-|Sample:0.13|
# EPOCH[69/1000] loss0.024-|Sample:0.14|
# EPOCH[70/1000] loss0.024-|Sample:0.13|
# [TEST]
# {'precision': array([0.04976053]), 'recall': array([0.16471596]), 'ndcg': array([0.13979648])}
# EPOCH[71/1000] loss0.023-|Sample:0.13|
# EPOCH[72/1000] loss0.023-|Sample:0.13|
# EPOCH[73/1000] loss0.023-|Sample:0.14|
# EPOCH[74/1000] loss0.023-|Sample:0.13|
# EPOCH[75/1000] loss0.023-|Sample:0.13|
# EPOCH[76/1000] loss0.022-|Sample:0.13|
# EPOCH[77/1000] loss0.022-|Sample:0.14|
# EPOCH[78/1000] loss0.022-|Sample:0.13|
# EPOCH[79/1000] loss0.022-|Sample:0.14|
# EPOCH[80/1000] loss0.022-|Sample:0.13|
# [TEST]
# {'precision': array([0.05074017]), 'recall': array([0.16797204]), 'ndcg': array([0.14227933])}
# EPOCH[81/1000] loss0.021-|Sample:0.14|
# EPOCH[82/1000] loss0.021-|Sample:0.13|
# EPOCH[83/1000] loss0.021-|Sample:0.14|
# EPOCH[84/1000] loss0.021-|Sample:0.13|
# EPOCH[85/1000] loss0.021-|Sample:0.13|
# EPOCH[86/1000] loss0.021-|Sample:0.13|
# EPOCH[87/1000] loss0.020-|Sample:0.13|
# EPOCH[88/1000] loss0.020-|Sample:0.13|
# EPOCH[89/1000] loss0.020-|Sample:0.13|
# EPOCH[90/1000] loss0.020-|Sample:0.13|
# [TEST]
# {'precision': array([0.05158082]), 'recall': array([0.17098596]), 'ndcg': array([0.14473417])}
# EPOCH[91/1000] loss0.020-|Sample:0.13|
# EPOCH[92/1000] loss0.020-|Sample:0.14|
# EPOCH[93/1000] loss0.020-|Sample:0.13|
# EPOCH[94/1000] loss0.020-|Sample:0.16|
# EPOCH[95/1000] loss0.020-|Sample:0.13|
# EPOCH[96/1000] loss0.019-|Sample:0.13|
# EPOCH[97/1000] loss0.019-|Sample:0.14|
# EPOCH[98/1000] loss0.019-|Sample:0.13|
# EPOCH[99/1000] loss0.019-|Sample:0.14|
# EPOCH[100/1000] loss0.019-|Sample:0.13|
# [TEST]
# {'precision': array([0.05215018]), 'recall': array([0.17218603]), 'ndcg': array([0.14649695])}
# EPOCH[101/1000] loss0.019-|Sample:0.13|
# EPOCH[102/1000] loss0.019-|Sample:0.14|
# EPOCH[103/1000] loss0.019-|Sample:0.13|
# EPOCH[104/1000] loss0.019-|Sample:0.13|
# EPOCH[105/1000] loss0.019-|Sample:0.14|
# EPOCH[106/1000] loss0.018-|Sample:0.14|
# EPOCH[107/1000] loss0.018-|Sample:0.14|
# EPOCH[108/1000] loss0.018-|Sample:0.15|
# EPOCH[109/1000] loss0.018-|Sample:0.13|
# EPOCH[110/1000] loss0.018-|Sample:0.14|
# [TEST]
# {'precision': array([0.05292551]), 'recall': array([0.17482062]), 'ndcg': array([0.14860625])}
# EPOCH[111/1000] loss0.018-|Sample:0.14|
# EPOCH[112/1000] loss0.018-|Sample:0.13|
# EPOCH[113/1000] loss0.018-|Sample:0.13|
# EPOCH[114/1000] loss0.018-|Sample:0.13|
# EPOCH[115/1000] loss0.017-|Sample:0.14|
# EPOCH[116/1000] loss0.017-|Sample:0.14|
# EPOCH[117/1000] loss0.017-|Sample:0.14|
# EPOCH[118/1000] loss0.017-|Sample:0.14|
# EPOCH[119/1000] loss0.017-|Sample:0.14|
# EPOCH[120/1000] loss0.017-|Sample:0.13|
# [TEST]
# {'precision': array([0.05348818]), 'recall': array([0.17641573]), 'ndcg': array([0.14995658])}
# EPOCH[121/1000] loss0.017-|Sample:0.15|
# EPOCH[122/1000] loss0.017-|Sample:0.13|
# EPOCH[123/1000] loss0.016-|Sample:0.13|
# EPOCH[124/1000] loss0.017-|Sample:0.13|
# EPOCH[125/1000] loss0.017-|Sample:0.14|
# EPOCH[126/1000] loss0.016-|Sample:0.13|
# EPOCH[127/1000] loss0.017-|Sample:0.13|
# EPOCH[128/1000] loss0.017-|Sample:0.13|
# EPOCH[129/1000] loss0.016-|Sample:0.13|
# EPOCH[130/1000] loss0.016-|Sample:0.13|
# [TEST]
# {'precision': array([0.05384989]), 'recall': array([0.17771986]), 'ndcg': array([0.15128354])}
# EPOCH[131/1000] loss0.016-|Sample:0.13|
# EPOCH[132/1000] loss0.016-|Sample:0.13|
# EPOCH[133/1000] loss0.016-|Sample:0.13|
# EPOCH[134/1000] loss0.016-|Sample:0.13|
# EPOCH[135/1000] loss0.016-|Sample:0.13|
# EPOCH[136/1000] loss0.016-|Sample:0.13|
# EPOCH[137/1000] loss0.016-|Sample:0.13|
# EPOCH[138/1000] loss0.016-|Sample:0.13|
# EPOCH[139/1000] loss0.016-|Sample:0.14|
# EPOCH[140/1000] loss0.016-|Sample:0.13|
# [TEST]
# {'precision': array([0.05422667]), 'recall': array([0.17887875]), 'ndcg': array([0.15222049])}
# EPOCH[141/1000] loss0.016-|Sample:0.13|
# EPOCH[142/1000] loss0.016-|Sample:0.13|
# EPOCH[143/1000] loss0.016-|Sample:0.13|
# EPOCH[144/1000] loss0.016-|Sample:0.13|
# EPOCH[145/1000] loss0.015-|Sample:0.13|
# EPOCH[146/1000] loss0.015-|Sample:0.13|
# EPOCH[147/1000] loss0.015-|Sample:0.13|
# EPOCH[148/1000] loss0.015-|Sample:0.13|
# EPOCH[149/1000] loss0.015-|Sample:0.13|
# EPOCH[150/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.05469556]), 'recall': array([0.18036362]), 'ndcg': array([0.153434])}
# EPOCH[151/1000] loss0.015-|Sample:0.14|
# EPOCH[152/1000] loss0.015-|Sample:0.13|
# EPOCH[153/1000] loss0.015-|Sample:0.13|
# EPOCH[154/1000] loss0.015-|Sample:0.13|
# EPOCH[155/1000] loss0.015-|Sample:0.13|
# EPOCH[156/1000] loss0.015-|Sample:0.13|
# EPOCH[157/1000] loss0.015-|Sample:0.13|
# EPOCH[158/1000] loss0.015-|Sample:0.13|
# EPOCH[159/1000] loss0.015-|Sample:0.13|
# EPOCH[160/1000] loss0.015-|Sample:0.13|
# [TEST]
# {'precision': array([0.05490488]), 'recall': array([0.1807188]), 'ndcg': array([0.15411551])}
# EPOCH[161/1000] loss0.015-|Sample:0.13|
# EPOCH[162/1000] loss0.015-|Sample:0.13|
# EPOCH[163/1000] loss0.014-|Sample:0.13|
# EPOCH[164/1000] loss0.015-|Sample:0.13|
# EPOCH[165/1000] loss0.014-|Sample:0.18|
# EPOCH[166/1000] loss0.015-|Sample:0.13|
# EPOCH[167/1000] loss0.015-|Sample:0.13|
# EPOCH[168/1000] loss0.014-|Sample:0.14|
# EPOCH[169/1000] loss0.014-|Sample:0.13|
# EPOCH[170/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.05529506]), 'recall': array([0.18180367]), 'ndcg': array([0.15514231])}
# EPOCH[171/1000] loss0.014-|Sample:0.15|
# EPOCH[172/1000] loss0.014-|Sample:0.13|
# EPOCH[173/1000] loss0.014-|Sample:0.13|
# EPOCH[174/1000] loss0.014-|Sample:0.13|
# EPOCH[175/1000] loss0.014-|Sample:0.13|
# EPOCH[176/1000] loss0.014-|Sample:0.13|
# EPOCH[177/1000] loss0.014-|Sample:0.14|
# EPOCH[178/1000] loss0.014-|Sample:0.13|
# EPOCH[179/1000] loss0.014-|Sample:0.14|
# EPOCH[180/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05561324]), 'recall': array([0.18274103]), 'ndcg': array([0.15588])}
# EPOCH[181/1000] loss0.014-|Sample:0.13|
# EPOCH[182/1000] loss0.014-|Sample:0.14|
# EPOCH[183/1000] loss0.014-|Sample:0.13|
# EPOCH[184/1000] loss0.014-|Sample:0.14|
# EPOCH[185/1000] loss0.014-|Sample:0.13|
# EPOCH[186/1000] loss0.014-|Sample:0.13|
# EPOCH[187/1000] loss0.014-|Sample:0.13|
# EPOCH[188/1000] loss0.014-|Sample:0.13|
# EPOCH[189/1000] loss0.014-|Sample:0.14|
# EPOCH[190/1000] loss0.014-|Sample:0.13|
# [TEST]
# {'precision': array([0.0558527]), 'recall': array([0.18338494]), 'ndcg': array([0.15658016])}
# EPOCH[191/1000] loss0.014-|Sample:0.15|
# EPOCH[192/1000] loss0.014-|Sample:0.13|
# EPOCH[193/1000] loss0.014-|Sample:0.13|
# EPOCH[194/1000] loss0.014-|Sample:0.13|
# EPOCH[195/1000] loss0.014-|Sample:0.14|
# EPOCH[196/1000] loss0.013-|Sample:0.14|
# EPOCH[197/1000] loss0.014-|Sample:0.13|
# EPOCH[198/1000] loss0.013-|Sample:0.14|
# EPOCH[199/1000] loss0.013-|Sample:0.13|
# EPOCH[200/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05591801]), 'recall': array([0.18338725]), 'ndcg': array([0.15709661])}
# EPOCH[201/1000] loss0.013-|Sample:0.13|
# EPOCH[202/1000] loss0.013-|Sample:0.13|
# EPOCH[203/1000] loss0.013-|Sample:0.13|
# EPOCH[204/1000] loss0.013-|Sample:0.13|
# EPOCH[205/1000] loss0.013-|Sample:0.14|
# EPOCH[206/1000] loss0.013-|Sample:0.13|
# EPOCH[207/1000] loss0.013-|Sample:0.14|
# EPOCH[208/1000] loss0.013-|Sample:0.14|
# EPOCH[209/1000] loss0.013-|Sample:0.13|
# EPOCH[210/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05630484]), 'recall': array([0.18468256]), 'ndcg': array([0.15765928])}
# EPOCH[211/1000] loss0.013-|Sample:0.13|
# EPOCH[212/1000] loss0.013-|Sample:0.13|
# EPOCH[213/1000] loss0.013-|Sample:0.13|
# EPOCH[214/1000] loss0.013-|Sample:0.13|
# EPOCH[215/1000] loss0.013-|Sample:0.13|
# EPOCH[216/1000] loss0.013-|Sample:0.13|
# EPOCH[217/1000] loss0.013-|Sample:0.13|
# EPOCH[218/1000] loss0.013-|Sample:0.13|
# EPOCH[219/1000] loss0.013-|Sample:0.13|
# EPOCH[220/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05633499]), 'recall': array([0.18513087]), 'ndcg': array([0.15817666])}
# EPOCH[221/1000] loss0.013-|Sample:0.13|
# EPOCH[222/1000] loss0.013-|Sample:0.13|
# EPOCH[223/1000] loss0.013-|Sample:0.13|
# EPOCH[224/1000] loss0.013-|Sample:0.13|
# EPOCH[225/1000] loss0.013-|Sample:0.13|
# EPOCH[226/1000] loss0.013-|Sample:0.13|
# EPOCH[227/1000] loss0.013-|Sample:0.13|
# EPOCH[228/1000] loss0.013-|Sample:0.13|
# EPOCH[229/1000] loss0.013-|Sample:0.14|
# EPOCH[230/1000] loss0.013-|Sample:0.14|
# [TEST]
# {'precision': array([0.05644551]), 'recall': array([0.18530756]), 'ndcg': array([0.15848485])}
# EPOCH[231/1000] loss0.013-|Sample:0.15|
# EPOCH[232/1000] loss0.013-|Sample:0.13|
# EPOCH[233/1000] loss0.013-|Sample:0.13|
# EPOCH[234/1000] loss0.012-|Sample:0.13|
# EPOCH[235/1000] loss0.013-|Sample:0.12|
# EPOCH[236/1000] loss0.013-|Sample:0.13|
# EPOCH[237/1000] loss0.013-|Sample:0.13|
# EPOCH[238/1000] loss0.013-|Sample:0.14|
# EPOCH[239/1000] loss0.012-|Sample:0.13|
# EPOCH[240/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05664479]), 'recall': array([0.1861169]), 'ndcg': array([0.15893406])}
# EPOCH[241/1000] loss0.013-|Sample:0.13|
# EPOCH[242/1000] loss0.012-|Sample:0.13|
# EPOCH[243/1000] loss0.012-|Sample:0.13|
# EPOCH[244/1000] loss0.012-|Sample:0.13|
# EPOCH[245/1000] loss0.012-|Sample:0.13|
# EPOCH[246/1000] loss0.012-|Sample:0.13|
# EPOCH[247/1000] loss0.013-|Sample:0.13|
# EPOCH[248/1000] loss0.012-|Sample:0.13|
# EPOCH[249/1000] loss0.012-|Sample:0.13|
# EPOCH[250/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05673354]), 'recall': array([0.18619596]), 'ndcg': array([0.15908557])}
# EPOCH[251/1000] loss0.012-|Sample:0.13|
# EPOCH[252/1000] loss0.012-|Sample:0.14|
# EPOCH[253/1000] loss0.012-|Sample:0.13|
# EPOCH[254/1000] loss0.012-|Sample:0.14|
# EPOCH[255/1000] loss0.012-|Sample:0.13|
# EPOCH[256/1000] loss0.012-|Sample:0.13|
# EPOCH[257/1000] loss0.012-|Sample:0.14|
# EPOCH[258/1000] loss0.012-|Sample:0.13|
# EPOCH[259/1000] loss0.012-|Sample:0.13|
# EPOCH[260/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05697468]), 'recall': array([0.18633717]), 'ndcg': array([0.15939979])}
# EPOCH[261/1000] loss0.012-|Sample:0.13|
# EPOCH[262/1000] loss0.012-|Sample:0.13|
# EPOCH[263/1000] loss0.012-|Sample:0.13|
# EPOCH[264/1000] loss0.012-|Sample:0.13|
# EPOCH[265/1000] loss0.012-|Sample:0.14|
# EPOCH[266/1000] loss0.012-|Sample:0.14|
# EPOCH[267/1000] loss0.012-|Sample:0.13|
# EPOCH[268/1000] loss0.012-|Sample:0.13|
# EPOCH[269/1000] loss0.012-|Sample:0.13|
# EPOCH[270/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05703162]), 'recall': array([0.1866653]), 'ndcg': array([0.15957118])}
# EPOCH[271/1000] loss0.012-|Sample:0.16|
# EPOCH[272/1000] loss0.012-|Sample:0.14|
# EPOCH[273/1000] loss0.012-|Sample:0.13|
# EPOCH[274/1000] loss0.012-|Sample:0.13|
# EPOCH[275/1000] loss0.012-|Sample:0.14|
# EPOCH[276/1000] loss0.012-|Sample:0.13|
# EPOCH[277/1000] loss0.012-|Sample:0.14|
# EPOCH[278/1000] loss0.012-|Sample:0.14|
# EPOCH[279/1000] loss0.012-|Sample:0.14|
# EPOCH[280/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05707516]), 'recall': array([0.18656482]), 'ndcg': array([0.1596318])}
# EPOCH[281/1000] loss0.012-|Sample:0.13|
# EPOCH[282/1000] loss0.012-|Sample:0.13|
# EPOCH[283/1000] loss0.012-|Sample:0.13|
# EPOCH[284/1000] loss0.012-|Sample:0.13|
# EPOCH[285/1000] loss0.012-|Sample:0.13|
# EPOCH[286/1000] loss0.012-|Sample:0.13|
# EPOCH[287/1000] loss0.012-|Sample:0.13|
# EPOCH[288/1000] loss0.012-|Sample:0.13|
# EPOCH[289/1000] loss0.012-|Sample:0.13|
# EPOCH[290/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05706678]), 'recall': array([0.18663672]), 'ndcg': array([0.15992285])}
# EPOCH[291/1000] loss0.012-|Sample:0.14|
# EPOCH[292/1000] loss0.012-|Sample:0.13|
# EPOCH[293/1000] loss0.012-|Sample:0.13|
# EPOCH[294/1000] loss0.012-|Sample:0.13|
# EPOCH[295/1000] loss0.012-|Sample:0.14|
# EPOCH[296/1000] loss0.012-|Sample:0.13|
# EPOCH[297/1000] loss0.012-|Sample:0.14|
# EPOCH[298/1000] loss0.012-|Sample:0.14|
# EPOCH[299/1000] loss0.012-|Sample:0.14|
# EPOCH[300/1000] loss0.012-|Sample:0.15|
# [TEST]
# {'precision': array([0.05718568]), 'recall': array([0.18697568]), 'ndcg': array([0.15995682])}
# EPOCH[301/1000] loss0.012-|Sample:0.15|
# EPOCH[302/1000] loss0.012-|Sample:0.13|
# EPOCH[303/1000] loss0.012-|Sample:0.13|
# EPOCH[304/1000] loss0.012-|Sample:0.13|
# EPOCH[305/1000] loss0.012-|Sample:0.13|
# EPOCH[306/1000] loss0.012-|Sample:0.13|
# EPOCH[307/1000] loss0.012-|Sample:0.13|
# EPOCH[308/1000] loss0.012-|Sample:0.13|
# EPOCH[309/1000] loss0.012-|Sample:0.13|
# EPOCH[310/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05730625]), 'recall': array([0.18759858]), 'ndcg': array([0.16035107])}
# EPOCH[311/1000] loss0.012-|Sample:0.13|
# EPOCH[312/1000] loss0.011-|Sample:0.13|
# EPOCH[313/1000] loss0.011-|Sample:0.14|
# EPOCH[314/1000] loss0.011-|Sample:0.13|
# EPOCH[315/1000] loss0.011-|Sample:0.13|
# EPOCH[316/1000] loss0.011-|Sample:0.13|
# EPOCH[317/1000] loss0.012-|Sample:0.13|
# EPOCH[318/1000] loss0.011-|Sample:0.13|
# EPOCH[319/1000] loss0.012-|Sample:0.14|
# EPOCH[320/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05737156]), 'recall': array([0.18744345]), 'ndcg': array([0.16034592])}
# EPOCH[321/1000] loss0.011-|Sample:0.13|
# EPOCH[322/1000] loss0.012-|Sample:0.13|
# EPOCH[323/1000] loss0.011-|Sample:0.13|
# EPOCH[324/1000] loss0.012-|Sample:0.13|
# EPOCH[325/1000] loss0.012-|Sample:0.13|
# EPOCH[326/1000] loss0.012-|Sample:0.13|
# EPOCH[327/1000] loss0.011-|Sample:0.13|
# EPOCH[328/1000] loss0.011-|Sample:0.14|
# EPOCH[329/1000] loss0.011-|Sample:0.14|
# EPOCH[330/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.05747371]), 'recall': array([0.18772478]), 'ndcg': array([0.16065227])}
# EPOCH[331/1000] loss0.011-|Sample:0.15|
# EPOCH[332/1000] loss0.011-|Sample:0.13|
# EPOCH[333/1000] loss0.011-|Sample:0.13|
# EPOCH[334/1000] loss0.011-|Sample:0.13|
# EPOCH[335/1000] loss0.011-|Sample:0.14|
# EPOCH[336/1000] loss0.011-|Sample:0.13|
# EPOCH[337/1000] loss0.011-|Sample:0.14|
# EPOCH[338/1000] loss0.012-|Sample:0.13|
# EPOCH[339/1000] loss0.011-|Sample:0.13|
# EPOCH[340/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05743519]), 'recall': array([0.1876032]), 'ndcg': array([0.16062901])}
# EPOCH[341/1000] loss0.011-|Sample:0.16|
# EPOCH[342/1000] loss0.011-|Sample:0.13|
# EPOCH[343/1000] loss0.011-|Sample:0.13|
# EPOCH[344/1000] loss0.011-|Sample:0.14|
# EPOCH[345/1000] loss0.011-|Sample:0.13|
# EPOCH[346/1000] loss0.011-|Sample:0.13|
# EPOCH[347/1000] loss0.011-|Sample:0.14|
# EPOCH[348/1000] loss0.011-|Sample:0.13|
# EPOCH[349/1000] loss0.011-|Sample:0.13|
# EPOCH[350/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05752897]), 'recall': array([0.18783628]), 'ndcg': array([0.16054394])}
# EPOCH[351/1000] loss0.011-|Sample:0.14|
# EPOCH[352/1000] loss0.011-|Sample:0.13|
# EPOCH[353/1000] loss0.011-|Sample:0.13|
# EPOCH[354/1000] loss0.011-|Sample:0.13|
# EPOCH[355/1000] loss0.011-|Sample:0.13|
# EPOCH[356/1000] loss0.011-|Sample:0.13|
# EPOCH[357/1000] loss0.011-|Sample:0.14|
# EPOCH[358/1000] loss0.011-|Sample:0.14|
# EPOCH[359/1000] loss0.011-|Sample:0.14|
# EPOCH[360/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05765791]), 'recall': array([0.18882488]), 'ndcg': array([0.16102051])}
# EPOCH[361/1000] loss0.011-|Sample:0.13|
# EPOCH[362/1000] loss0.011-|Sample:0.13|
# EPOCH[363/1000] loss0.011-|Sample:0.14|
# EPOCH[364/1000] loss0.011-|Sample:0.13|
# EPOCH[365/1000] loss0.011-|Sample:0.13|
# EPOCH[366/1000] loss0.011-|Sample:0.14|
# EPOCH[367/1000] loss0.011-|Sample:0.13|
# EPOCH[368/1000] loss0.011-|Sample:0.14|
# EPOCH[369/1000] loss0.011-|Sample:0.13|
# EPOCH[370/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05751055]), 'recall': array([0.18758872]), 'ndcg': array([0.16054731])}
# EPOCH[371/1000] loss0.011-|Sample:0.13|
# EPOCH[372/1000] loss0.011-|Sample:0.13|
# EPOCH[373/1000] loss0.011-|Sample:0.14|
# EPOCH[374/1000] loss0.011-|Sample:0.14|
# EPOCH[375/1000] loss0.011-|Sample:0.13|
# EPOCH[376/1000] loss0.011-|Sample:0.14|
# EPOCH[377/1000] loss0.011-|Sample:0.13|
# EPOCH[378/1000] loss0.011-|Sample:0.13|
# EPOCH[379/1000] loss0.011-|Sample:0.13|
# EPOCH[380/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05756581]), 'recall': array([0.18793631]), 'ndcg': array([0.16084056])}
# EPOCH[381/1000] loss0.011-|Sample:0.14|
# EPOCH[382/1000] loss0.011-|Sample:0.13|
# EPOCH[383/1000] loss0.011-|Sample:0.20|
# EPOCH[384/1000] loss0.011-|Sample:0.13|
# EPOCH[385/1000] loss0.011-|Sample:0.14|
# EPOCH[386/1000] loss0.011-|Sample:0.13|
# EPOCH[387/1000] loss0.011-|Sample:0.14|
# EPOCH[388/1000] loss0.011-|Sample:0.13|
# EPOCH[389/1000] loss0.011-|Sample:0.14|
# EPOCH[390/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.0578103]), 'recall': array([0.18880196]), 'ndcg': array([0.16142408])}
# EPOCH[391/1000] loss0.011-|Sample:0.13|
# EPOCH[392/1000] loss0.011-|Sample:0.13|
# EPOCH[393/1000] loss0.011-|Sample:0.13|
# EPOCH[394/1000] loss0.011-|Sample:0.13|
# EPOCH[395/1000] loss0.011-|Sample:0.13|
# EPOCH[396/1000] loss0.011-|Sample:0.13|
# EPOCH[397/1000] loss0.011-|Sample:0.13|
# EPOCH[398/1000] loss0.011-|Sample:0.13|
# EPOCH[399/1000] loss0.011-|Sample:0.13|
# EPOCH[400/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05782872]), 'recall': array([0.18894175]), 'ndcg': array([0.16145376])}
# EPOCH[401/1000] loss0.011-|Sample:0.15|
# EPOCH[402/1000] loss0.011-|Sample:0.13|
# EPOCH[403/1000] loss0.011-|Sample:0.13|
# EPOCH[404/1000] loss0.011-|Sample:0.14|
# EPOCH[405/1000] loss0.011-|Sample:0.13|
# EPOCH[406/1000] loss0.011-|Sample:0.14|
# EPOCH[407/1000] loss0.011-|Sample:0.13|
# EPOCH[408/1000] loss0.011-|Sample:0.13|
# EPOCH[409/1000] loss0.011-|Sample:0.14|
# EPOCH[410/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05794092]), 'recall': array([0.18901822]), 'ndcg': array([0.16144958])}
# EPOCH[411/1000] loss0.011-|Sample:0.15|
# EPOCH[412/1000] loss0.011-|Sample:0.14|
# EPOCH[413/1000] loss0.011-|Sample:0.14|
# EPOCH[414/1000] loss0.011-|Sample:0.13|
# EPOCH[415/1000] loss0.011-|Sample:0.13|
# EPOCH[416/1000] loss0.011-|Sample:0.13|
# EPOCH[417/1000] loss0.011-|Sample:0.13|
# EPOCH[418/1000] loss0.011-|Sample:0.14|
# EPOCH[419/1000] loss0.011-|Sample:0.13|
# EPOCH[420/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05803135]), 'recall': array([0.18943421]), 'ndcg': array([0.16146611])}
# EPOCH[421/1000] loss0.011-|Sample:0.14|
# EPOCH[422/1000] loss0.011-|Sample:0.16|
# EPOCH[423/1000] loss0.011-|Sample:0.13|
# EPOCH[424/1000] loss0.011-|Sample:0.13|
# EPOCH[425/1000] loss0.011-|Sample:0.13|
# EPOCH[426/1000] loss0.011-|Sample:0.13|
# EPOCH[427/1000] loss0.011-|Sample:0.13|
# EPOCH[428/1000] loss0.011-|Sample:0.13|
# EPOCH[429/1000] loss0.011-|Sample:0.14|
# EPOCH[430/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05790575]), 'recall': array([0.18894986]), 'ndcg': array([0.16150643])}
# EPOCH[431/1000] loss0.011-|Sample:0.13|
# EPOCH[432/1000] loss0.011-|Sample:0.13|
# EPOCH[433/1000] loss0.011-|Sample:0.13|
# EPOCH[434/1000] loss0.011-|Sample:0.20|
# EPOCH[435/1000] loss0.011-|Sample:0.13|
# EPOCH[436/1000] loss0.011-|Sample:0.14|
# EPOCH[437/1000] loss0.011-|Sample:0.14|
# EPOCH[438/1000] loss0.011-|Sample:0.14|
# EPOCH[439/1000] loss0.011-|Sample:0.13|
# EPOCH[440/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05797609]), 'recall': array([0.18922292]), 'ndcg': array([0.16123499])}
# EPOCH[441/1000] loss0.011-|Sample:0.13|
# EPOCH[442/1000] loss0.011-|Sample:0.13|
# EPOCH[443/1000] loss0.011-|Sample:0.13|
# EPOCH[444/1000] loss0.011-|Sample:0.13|
# EPOCH[445/1000] loss0.011-|Sample:0.13|
# EPOCH[446/1000] loss0.011-|Sample:0.13|
# EPOCH[447/1000] loss0.011-|Sample:0.14|
# EPOCH[448/1000] loss0.011-|Sample:0.14|
# EPOCH[449/1000] loss0.011-|Sample:0.13|
# EPOCH[450/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05803637]), 'recall': array([0.18938266]), 'ndcg': array([0.16152761])}
# EPOCH[451/1000] loss0.011-|Sample:0.15|
# EPOCH[452/1000] loss0.011-|Sample:0.13|
# EPOCH[453/1000] loss0.011-|Sample:0.13|
# EPOCH[454/1000] loss0.011-|Sample:0.13|
# EPOCH[455/1000] loss0.011-|Sample:0.13|
# EPOCH[456/1000] loss0.011-|Sample:0.13|
# EPOCH[457/1000] loss0.011-|Sample:0.13|
# EPOCH[458/1000] loss0.011-|Sample:0.13|
# EPOCH[459/1000] loss0.011-|Sample:0.13|
# EPOCH[460/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05805144]), 'recall': array([0.18882479]), 'ndcg': array([0.16115002])}
# EPOCH[461/1000] loss0.011-|Sample:0.13|
# EPOCH[462/1000] loss0.011-|Sample:0.13|
# EPOCH[463/1000] loss0.011-|Sample:0.14|
# EPOCH[464/1000] loss0.011-|Sample:0.14|
# EPOCH[465/1000] loss0.011-|Sample:0.13|
# EPOCH[466/1000] loss0.011-|Sample:0.13|
# EPOCH[467/1000] loss0.011-|Sample:0.13|
# EPOCH[468/1000] loss0.011-|Sample:0.13|
# EPOCH[469/1000] loss0.011-|Sample:0.13|
# EPOCH[470/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05822895]), 'recall': array([0.18988658]), 'ndcg': array([0.16175672])}
# EPOCH[471/1000] loss0.011-|Sample:0.13|
# EPOCH[472/1000] loss0.011-|Sample:0.13|
# EPOCH[473/1000] loss0.011-|Sample:0.14|
# EPOCH[474/1000] loss0.011-|Sample:0.13|
# EPOCH[475/1000] loss0.011-|Sample:0.13|
# EPOCH[476/1000] loss0.011-|Sample:0.13|
# EPOCH[477/1000] loss0.011-|Sample:0.13|
# EPOCH[478/1000] loss0.011-|Sample:0.14|
# EPOCH[479/1000] loss0.011-|Sample:0.14|
# EPOCH[480/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05837631]), 'recall': array([0.19005758]), 'ndcg': array([0.16223367])}
# EPOCH[481/1000] loss0.011-|Sample:0.13|
# EPOCH[482/1000] loss0.011-|Sample:0.13|
# EPOCH[483/1000] loss0.011-|Sample:0.13|
# EPOCH[484/1000] loss0.011-|Sample:0.13|
# EPOCH[485/1000] loss0.010-|Sample:0.14|
# EPOCH[486/1000] loss0.011-|Sample:0.13|
# EPOCH[487/1000] loss0.011-|Sample:0.13|
# EPOCH[488/1000] loss0.011-|Sample:0.13|
# EPOCH[489/1000] loss0.011-|Sample:0.13|
# EPOCH[490/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05835622]), 'recall': array([0.18996182]), 'ndcg': array([0.16198088])}
# EPOCH[491/1000] loss0.011-|Sample:0.15|
# EPOCH[492/1000] loss0.011-|Sample:0.14|
# EPOCH[493/1000] loss0.011-|Sample:0.14|
# EPOCH[494/1000] loss0.011-|Sample:0.13|
# EPOCH[495/1000] loss0.011-|Sample:0.14|
# EPOCH[496/1000] loss0.011-|Sample:0.13|
# EPOCH[497/1000] loss0.011-|Sample:0.14|
# EPOCH[498/1000] loss0.010-|Sample:0.13|
# EPOCH[499/1000] loss0.011-|Sample:0.14|
# EPOCH[500/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05842488]), 'recall': array([0.18999862]), 'ndcg': array([0.16247373])}
# EPOCH[501/1000] loss0.011-|Sample:0.15|
# EPOCH[502/1000] loss0.011-|Sample:0.13|
# EPOCH[503/1000] loss0.011-|Sample:0.13|
# EPOCH[504/1000] loss0.011-|Sample:0.13|
# EPOCH[505/1000] loss0.010-|Sample:0.13|
# EPOCH[506/1000] loss0.011-|Sample:0.13|
# EPOCH[507/1000] loss0.011-|Sample:0.14|
# EPOCH[508/1000] loss0.011-|Sample:0.14|
# EPOCH[509/1000] loss0.011-|Sample:0.14|
# EPOCH[510/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05824235]), 'recall': array([0.18957021]), 'ndcg': array([0.16206013])}
# EPOCH[511/1000] loss0.011-|Sample:0.13|
# EPOCH[512/1000] loss0.011-|Sample:0.14|
# EPOCH[513/1000] loss0.010-|Sample:0.14|
# EPOCH[514/1000] loss0.011-|Sample:0.14|
# EPOCH[515/1000] loss0.010-|Sample:0.14|
# EPOCH[516/1000] loss0.011-|Sample:0.13|
# EPOCH[517/1000] loss0.011-|Sample:0.13|
# EPOCH[518/1000] loss0.011-|Sample:0.14|
# EPOCH[519/1000] loss0.011-|Sample:0.14|
# EPOCH[520/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05833612]), 'recall': array([0.18946079]), 'ndcg': array([0.16217919])}
# EPOCH[521/1000] loss0.011-|Sample:0.13|
# EPOCH[522/1000] loss0.011-|Sample:0.13|
# EPOCH[523/1000] loss0.010-|Sample:0.14|
# EPOCH[524/1000] loss0.011-|Sample:0.13|
# EPOCH[525/1000] loss0.011-|Sample:0.14|
# EPOCH[526/1000] loss0.011-|Sample:0.13|
# EPOCH[527/1000] loss0.011-|Sample:0.14|
# EPOCH[528/1000] loss0.011-|Sample:0.13|
# EPOCH[529/1000] loss0.011-|Sample:0.13|
# EPOCH[530/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05826579]), 'recall': array([0.18956842]), 'ndcg': array([0.16203283])}
# EPOCH[531/1000] loss0.011-|Sample:0.15|
# EPOCH[532/1000] loss0.011-|Sample:0.13|
# EPOCH[533/1000] loss0.011-|Sample:0.13|
# EPOCH[534/1000] loss0.010-|Sample:0.13|
# EPOCH[535/1000] loss0.010-|Sample:0.13|
# EPOCH[536/1000] loss0.010-|Sample:0.13|
# EPOCH[537/1000] loss0.011-|Sample:0.13|
# EPOCH[538/1000] loss0.011-|Sample:0.13|
# EPOCH[539/1000] loss0.010-|Sample:0.13|
# EPOCH[540/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05831938]), 'recall': array([0.18924112]), 'ndcg': array([0.16202542])}
# EPOCH[541/1000] loss0.010-|Sample:0.18|
# EPOCH[542/1000] loss0.011-|Sample:0.13|
# EPOCH[543/1000] loss0.011-|Sample:0.13|
# EPOCH[544/1000] loss0.011-|Sample:0.14|
# EPOCH[545/1000] loss0.011-|Sample:0.13|
# EPOCH[546/1000] loss0.011-|Sample:0.13|
# EPOCH[547/1000] loss0.011-|Sample:0.13|
# EPOCH[548/1000] loss0.011-|Sample:0.13|
# EPOCH[549/1000] loss0.010-|Sample:0.13|
# EPOCH[550/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05840311]), 'recall': array([0.18948472]), 'ndcg': array([0.16238694])}
# EPOCH[551/1000] loss0.011-|Sample:0.14|
# EPOCH[552/1000] loss0.010-|Sample:0.13|
# EPOCH[553/1000] loss0.011-|Sample:0.13|
# EPOCH[554/1000] loss0.011-|Sample:0.13|
# EPOCH[555/1000] loss0.010-|Sample:0.14|
# EPOCH[556/1000] loss0.010-|Sample:0.13|
# EPOCH[557/1000] loss0.010-|Sample:0.13|
# EPOCH[558/1000] loss0.011-|Sample:0.14|
# EPOCH[559/1000] loss0.011-|Sample:0.14|
# EPOCH[560/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05856219]), 'recall': array([0.19026009]), 'ndcg': array([0.16277004])}
# EPOCH[561/1000] loss0.010-|Sample:0.13|
# EPOCH[562/1000] loss0.010-|Sample:0.13|
# EPOCH[563/1000] loss0.011-|Sample:0.13|
# EPOCH[564/1000] loss0.010-|Sample:0.13|
# EPOCH[565/1000] loss0.010-|Sample:0.14|
# EPOCH[566/1000] loss0.010-|Sample:0.13|
# EPOCH[567/1000] loss0.011-|Sample:0.13|
# EPOCH[568/1000] loss0.011-|Sample:0.13|
# EPOCH[569/1000] loss0.010-|Sample:0.14|
# EPOCH[570/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05856219]), 'recall': array([0.19083506]), 'ndcg': array([0.16286465])}
# EPOCH[571/1000] loss0.010-|Sample:0.13|
# EPOCH[572/1000] loss0.010-|Sample:0.13|
# EPOCH[573/1000] loss0.010-|Sample:0.13|
# EPOCH[574/1000] loss0.010-|Sample:0.13|
# EPOCH[575/1000] loss0.010-|Sample:0.14|
# EPOCH[576/1000] loss0.010-|Sample:0.13|
# EPOCH[577/1000] loss0.010-|Sample:0.13|
# EPOCH[578/1000] loss0.010-|Sample:0.13|
# EPOCH[579/1000] loss0.010-|Sample:0.13|
# EPOCH[580/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.0586476]), 'recall': array([0.19042937]), 'ndcg': array([0.16291383])}
# EPOCH[581/1000] loss0.010-|Sample:0.12|
# EPOCH[582/1000] loss0.010-|Sample:0.13|
# EPOCH[583/1000] loss0.010-|Sample:0.13|
# EPOCH[584/1000] loss0.010-|Sample:0.13|
# EPOCH[585/1000] loss0.010-|Sample:0.13|
# EPOCH[586/1000] loss0.010-|Sample:0.13|
# EPOCH[587/1000] loss0.010-|Sample:0.13|
# EPOCH[588/1000] loss0.011-|Sample:0.13|
# EPOCH[589/1000] loss0.010-|Sample:0.13|
# EPOCH[590/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05856219]), 'recall': array([0.19012404]), 'ndcg': array([0.16248471])}
# EPOCH[591/1000] loss0.010-|Sample:0.14|
# EPOCH[592/1000] loss0.010-|Sample:0.13|
# EPOCH[593/1000] loss0.010-|Sample:0.14|
# EPOCH[594/1000] loss0.010-|Sample:0.13|
# EPOCH[595/1000] loss0.010-|Sample:0.14|
# EPOCH[596/1000] loss0.010-|Sample:0.13|
# EPOCH[597/1000] loss0.010-|Sample:0.14|
# EPOCH[598/1000] loss0.010-|Sample:0.14|
# EPOCH[599/1000] loss0.010-|Sample:0.13|
# EPOCH[600/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.0584567]), 'recall': array([0.18987249]), 'ndcg': array([0.1622809])}
# EPOCH[601/1000] loss0.011-|Sample:0.15|
# EPOCH[602/1000] loss0.010-|Sample:0.13|
# EPOCH[603/1000] loss0.010-|Sample:0.13|
# EPOCH[604/1000] loss0.010-|Sample:0.13|
# EPOCH[605/1000] loss0.010-|Sample:0.13|
# EPOCH[606/1000] loss0.010-|Sample:0.13|
# EPOCH[607/1000] loss0.010-|Sample:0.13|
# EPOCH[608/1000] loss0.010-|Sample:0.13|
# EPOCH[609/1000] loss0.010-|Sample:0.13|
# EPOCH[610/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05841985]), 'recall': array([0.18995432]), 'ndcg': array([0.16213748])}
# EPOCH[611/1000] loss0.011-|Sample:0.14|
# EPOCH[612/1000] loss0.010-|Sample:0.13|
# EPOCH[613/1000] loss0.010-|Sample:0.14|
# EPOCH[614/1000] loss0.010-|Sample:0.14|
# EPOCH[615/1000] loss0.010-|Sample:0.13|
# EPOCH[616/1000] loss0.010-|Sample:0.13|
# EPOCH[617/1000] loss0.010-|Sample:0.13|
# EPOCH[618/1000] loss0.010-|Sample:0.13|
# EPOCH[619/1000] loss0.010-|Sample:0.13|
# EPOCH[620/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05850861]), 'recall': array([0.19012872]), 'ndcg': array([0.16279521])}
# EPOCH[621/1000] loss0.010-|Sample:0.13|
# EPOCH[622/1000] loss0.010-|Sample:0.13|
# EPOCH[623/1000] loss0.010-|Sample:0.14|
# EPOCH[624/1000] loss0.010-|Sample:0.13|
# EPOCH[625/1000] loss0.010-|Sample:0.18|
# EPOCH[626/1000] loss0.010-|Sample:0.13|
# EPOCH[627/1000] loss0.010-|Sample:0.13|
# EPOCH[628/1000] loss0.010-|Sample:0.13|
# EPOCH[629/1000] loss0.010-|Sample:0.13|
# EPOCH[630/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05865262]), 'recall': array([0.19068678]), 'ndcg': array([0.16305492])}
# EPOCH[631/1000] loss0.010-|Sample:0.13|
# EPOCH[632/1000] loss0.010-|Sample:0.13|
# EPOCH[633/1000] loss0.010-|Sample:0.13|
# EPOCH[634/1000] loss0.010-|Sample:0.14|
# EPOCH[635/1000] loss0.010-|Sample:0.14|
# EPOCH[636/1000] loss0.010-|Sample:0.13|
# EPOCH[637/1000] loss0.010-|Sample:0.13|
# EPOCH[638/1000] loss0.010-|Sample:0.13|
# EPOCH[639/1000] loss0.010-|Sample:0.14|
# EPOCH[640/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05866602]), 'recall': array([0.1904138]), 'ndcg': array([0.16309044])}
# EPOCH[641/1000] loss0.010-|Sample:0.13|
# EPOCH[642/1000] loss0.010-|Sample:0.14|
# EPOCH[643/1000] loss0.010-|Sample:0.14|
# EPOCH[644/1000] loss0.010-|Sample:0.14|
# EPOCH[645/1000] loss0.010-|Sample:0.13|
# EPOCH[646/1000] loss0.010-|Sample:0.13|
# EPOCH[647/1000] loss0.010-|Sample:0.13|
# EPOCH[648/1000] loss0.010-|Sample:0.14|
# EPOCH[649/1000] loss0.010-|Sample:0.13|
# EPOCH[650/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05846507]), 'recall': array([0.19022508]), 'ndcg': array([0.16272754])}
# EPOCH[651/1000] loss0.010-|Sample:0.15|
# EPOCH[652/1000] loss0.010-|Sample:0.13|
# EPOCH[653/1000] loss0.010-|Sample:0.13|
# EPOCH[654/1000] loss0.010-|Sample:0.13|
# EPOCH[655/1000] loss0.010-|Sample:0.13|
# EPOCH[656/1000] loss0.010-|Sample:0.13|
# EPOCH[657/1000] loss0.010-|Sample:0.13|
# EPOCH[658/1000] loss0.010-|Sample:0.14|
# EPOCH[659/1000] loss0.010-|Sample:0.14|
# EPOCH[660/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05849019]), 'recall': array([0.18974074]), 'ndcg': array([0.16287799])}
# EPOCH[661/1000] loss0.010-|Sample:0.14|
# EPOCH[662/1000] loss0.010-|Sample:0.13|
# EPOCH[663/1000] loss0.010-|Sample:0.14|
# EPOCH[664/1000] loss0.010-|Sample:0.13|
# EPOCH[665/1000] loss0.010-|Sample:0.13|
# EPOCH[666/1000] loss0.010-|Sample:0.14|
# EPOCH[667/1000] loss0.010-|Sample:0.14|
# EPOCH[668/1000] loss0.010-|Sample:0.13|
# EPOCH[669/1000] loss0.010-|Sample:0.14|
# EPOCH[670/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05839641]), 'recall': array([0.18953198]), 'ndcg': array([0.16238649])}
# EPOCH[671/1000] loss0.010-|Sample:0.14|
# EPOCH[672/1000] loss0.010-|Sample:0.13|
# EPOCH[673/1000] loss0.010-|Sample:0.14|
# EPOCH[674/1000] loss0.010-|Sample:0.13|
# EPOCH[675/1000] loss0.010-|Sample:0.13|
# EPOCH[676/1000] loss0.010-|Sample:0.14|
# EPOCH[677/1000] loss0.010-|Sample:0.14|
# EPOCH[678/1000] loss0.010-|Sample:0.14|
# EPOCH[679/1000] loss0.010-|Sample:0.13|
# EPOCH[680/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05846674]), 'recall': array([0.19004916]), 'ndcg': array([0.16252037])}
# EPOCH[681/1000] loss0.010-|Sample:0.15|
# EPOCH[682/1000] loss0.010-|Sample:0.14|
# EPOCH[683/1000] loss0.010-|Sample:0.13|
# EPOCH[684/1000] loss0.010-|Sample:0.13|
# EPOCH[685/1000] loss0.010-|Sample:0.13|
# EPOCH[686/1000] loss0.010-|Sample:0.14|
# EPOCH[687/1000] loss0.010-|Sample:0.14|
# EPOCH[688/1000] loss0.010-|Sample:0.14|
# EPOCH[689/1000] loss0.010-|Sample:0.14|
# EPOCH[690/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.0585488]), 'recall': array([0.19037164]), 'ndcg': array([0.16283762])}
# EPOCH[691/1000] loss0.010-|Sample:0.15|
# EPOCH[692/1000] loss0.010-|Sample:0.13|
# EPOCH[693/1000] loss0.010-|Sample:0.14|
# EPOCH[694/1000] loss0.010-|Sample:0.14|
# EPOCH[695/1000] loss0.010-|Sample:0.14|
# EPOCH[696/1000] loss0.010-|Sample:0.14|
# EPOCH[697/1000] loss0.010-|Sample:0.14|
# EPOCH[698/1000] loss0.010-|Sample:0.19|
# EPOCH[699/1000] loss0.010-|Sample:0.14|
# EPOCH[700/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05868277]), 'recall': array([0.19081554]), 'ndcg': array([0.16312332])}
# EPOCH[701/1000] loss0.010-|Sample:0.14|
# EPOCH[702/1000] loss0.010-|Sample:0.14|
# EPOCH[703/1000] loss0.010-|Sample:0.16|
# EPOCH[704/1000] loss0.010-|Sample:0.14|
# EPOCH[705/1000] loss0.010-|Sample:0.14|
# EPOCH[706/1000] loss0.010-|Sample:0.14|
# EPOCH[707/1000] loss0.010-|Sample:0.14|
# EPOCH[708/1000] loss0.010-|Sample:0.14|
# EPOCH[709/1000] loss0.010-|Sample:0.14|
# EPOCH[710/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05859401]), 'recall': array([0.1905486]), 'ndcg': array([0.16312584])}
# EPOCH[711/1000] loss0.010-|Sample:0.13|
# EPOCH[712/1000] loss0.010-|Sample:0.14|
# EPOCH[713/1000] loss0.010-|Sample:0.14|
# EPOCH[714/1000] loss0.010-|Sample:0.14|
# EPOCH[715/1000] loss0.010-|Sample:0.13|
# EPOCH[716/1000] loss0.010-|Sample:0.14|
# EPOCH[717/1000] loss0.010-|Sample:0.14|
# EPOCH[718/1000] loss0.010-|Sample:0.13|
# EPOCH[719/1000] loss0.010-|Sample:0.13|
# EPOCH[720/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05856554]), 'recall': array([0.18995876]), 'ndcg': array([0.16292712])}
# EPOCH[721/1000] loss0.010-|Sample:0.13|
# EPOCH[722/1000] loss0.010-|Sample:0.14|
# EPOCH[723/1000] loss0.010-|Sample:0.14|
# EPOCH[724/1000] loss0.010-|Sample:0.14|
# EPOCH[725/1000] loss0.010-|Sample:0.14|
# EPOCH[726/1000] loss0.010-|Sample:0.14|
# EPOCH[727/1000] loss0.010-|Sample:0.14|
# EPOCH[728/1000] loss0.010-|Sample:0.14|
# EPOCH[729/1000] loss0.010-|Sample:0.13|
# EPOCH[730/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05867104]), 'recall': array([0.19037087]), 'ndcg': array([0.16314205])}
# EPOCH[731/1000] loss0.010-|Sample:0.13|
# EPOCH[732/1000] loss0.010-|Sample:0.19|
# EPOCH[733/1000] loss0.010-|Sample:0.14|
# EPOCH[734/1000] loss0.010-|Sample:0.18|
# EPOCH[735/1000] loss0.010-|Sample:0.14|
# EPOCH[736/1000] loss0.010-|Sample:0.15|
# EPOCH[737/1000] loss0.010-|Sample:0.13|
# EPOCH[738/1000] loss0.010-|Sample:0.14|
# EPOCH[739/1000] loss0.010-|Sample:0.14|
# EPOCH[740/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05869951]), 'recall': array([0.19077225]), 'ndcg': array([0.16315065])}
# EPOCH[741/1000] loss0.010-|Sample:0.13|
# EPOCH[742/1000] loss0.010-|Sample:0.14|
# EPOCH[743/1000] loss0.010-|Sample:0.15|
# EPOCH[744/1000] loss0.010-|Sample:0.14|
# EPOCH[745/1000] loss0.010-|Sample:0.14|
# EPOCH[746/1000] loss0.010-|Sample:0.19|
# EPOCH[747/1000] loss0.010-|Sample:0.24|
# EPOCH[748/1000] loss0.010-|Sample:0.14|
# EPOCH[749/1000] loss0.010-|Sample:0.16|
# EPOCH[750/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05886362]), 'recall': array([0.1912047]), 'ndcg': array([0.16320946])}
# EPOCH[751/1000] loss0.010-|Sample:0.15|
# EPOCH[752/1000] loss0.010-|Sample:0.14|
# EPOCH[753/1000] loss0.010-|Sample:0.14|
# EPOCH[754/1000] loss0.010-|Sample:0.14|
# EPOCH[755/1000] loss0.010-|Sample:0.14|
# EPOCH[756/1000] loss0.010-|Sample:0.14|
# EPOCH[757/1000] loss0.010-|Sample:0.14|
# EPOCH[758/1000] loss0.010-|Sample:0.15|
# EPOCH[759/1000] loss0.010-|Sample:0.14|
# EPOCH[760/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05884353]), 'recall': array([0.19109116]), 'ndcg': array([0.1632989])}
# EPOCH[761/1000] loss0.010-|Sample:0.14|
# EPOCH[762/1000] loss0.010-|Sample:0.14|
# EPOCH[763/1000] loss0.010-|Sample:0.14|
# EPOCH[764/1000] loss0.010-|Sample:0.14|
# EPOCH[765/1000] loss0.010-|Sample:0.14|
# EPOCH[766/1000] loss0.010-|Sample:0.14|
# EPOCH[767/1000] loss0.010-|Sample:0.14|
# EPOCH[768/1000] loss0.010-|Sample:0.14|
# EPOCH[769/1000] loss0.010-|Sample:0.14|
# EPOCH[770/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05888874]), 'recall': array([0.19144149]), 'ndcg': array([0.16375128])}
# EPOCH[771/1000] loss0.010-|Sample:0.13|
# EPOCH[772/1000] loss0.010-|Sample:0.14|
# EPOCH[773/1000] loss0.010-|Sample:0.14|
# EPOCH[774/1000] loss0.010-|Sample:0.14|
# EPOCH[775/1000] loss0.010-|Sample:0.14|
# EPOCH[776/1000] loss0.010-|Sample:0.14|
# EPOCH[777/1000] loss0.010-|Sample:0.14|
# EPOCH[778/1000] loss0.010-|Sample:0.14|
# EPOCH[779/1000] loss0.010-|Sample:0.14|
# EPOCH[780/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05884855]), 'recall': array([0.19126875]), 'ndcg': array([0.16360727])}
# EPOCH[781/1000] loss0.010-|Sample:0.13|
# EPOCH[782/1000] loss0.010-|Sample:0.14|
# EPOCH[783/1000] loss0.010-|Sample:0.14|
# EPOCH[784/1000] loss0.010-|Sample:0.14|
# EPOCH[785/1000] loss0.010-|Sample:0.13|
# EPOCH[786/1000] loss0.010-|Sample:0.14|
# EPOCH[787/1000] loss0.010-|Sample:0.14|
# EPOCH[788/1000] loss0.010-|Sample:0.14|
# EPOCH[789/1000] loss0.010-|Sample:0.15|
# EPOCH[790/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05879496]), 'recall': array([0.19100268]), 'ndcg': array([0.16345805])}
# EPOCH[791/1000] loss0.010-|Sample:0.14|
# EPOCH[792/1000] loss0.010-|Sample:0.14|
# EPOCH[793/1000] loss0.010-|Sample:0.14|
# EPOCH[794/1000] loss0.010-|Sample:0.14|
# EPOCH[795/1000] loss0.010-|Sample:0.14|
# EPOCH[796/1000] loss0.010-|Sample:0.14|
# EPOCH[797/1000] loss0.010-|Sample:0.14|
# EPOCH[798/1000] loss0.010-|Sample:0.14|
# EPOCH[799/1000] loss0.010-|Sample:0.13|
# EPOCH[800/1000] loss0.010-|Sample:0.12|
# [TEST]
# {'precision': array([0.0587598]), 'recall': array([0.19068525]), 'ndcg': array([0.16317838])}
# EPOCH[801/1000] loss0.010-|Sample:0.14|
# EPOCH[802/1000] loss0.010-|Sample:0.14|
# EPOCH[803/1000] loss0.010-|Sample:0.13|
# EPOCH[804/1000] loss0.010-|Sample:0.13|
# EPOCH[805/1000] loss0.010-|Sample:0.14|
# EPOCH[806/1000] loss0.010-|Sample:0.14|
# EPOCH[807/1000] loss0.010-|Sample:0.14|
# EPOCH[808/1000] loss0.010-|Sample:0.14|
# EPOCH[809/1000] loss0.010-|Sample:0.14|
# EPOCH[810/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05860238]), 'recall': array([0.19025695]), 'ndcg': array([0.16305097])}
# EPOCH[811/1000] loss0.010-|Sample:0.13|
# EPOCH[812/1000] loss0.010-|Sample:0.14|
# EPOCH[813/1000] loss0.010-|Sample:0.14|
# EPOCH[814/1000] loss0.010-|Sample:0.14|
# EPOCH[815/1000] loss0.010-|Sample:0.17|
# EPOCH[816/1000] loss0.010-|Sample:0.15|
# EPOCH[817/1000] loss0.010-|Sample:0.14|
# EPOCH[818/1000] loss0.010-|Sample:0.13|
# EPOCH[819/1000] loss0.010-|Sample:0.14|
# EPOCH[820/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.058733]), 'recall': array([0.19100143]), 'ndcg': array([0.16345214])}
# EPOCH[821/1000] loss0.010-|Sample:0.13|
# EPOCH[822/1000] loss0.010-|Sample:0.14|
# EPOCH[823/1000] loss0.010-|Sample:0.14|
# EPOCH[824/1000] loss0.010-|Sample:0.14|
# EPOCH[825/1000] loss0.010-|Sample:0.15|
# EPOCH[826/1000] loss0.010-|Sample:0.13|
# EPOCH[827/1000] loss0.010-|Sample:0.14|
# EPOCH[828/1000] loss0.010-|Sample:0.14|
# EPOCH[829/1000] loss0.010-|Sample:0.14|
# EPOCH[830/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05878492]), 'recall': array([0.19072729]), 'ndcg': array([0.16311314])}
# EPOCH[831/1000] loss0.010-|Sample:0.16|
# EPOCH[832/1000] loss0.010-|Sample:0.13|
# EPOCH[833/1000] loss0.010-|Sample:0.14|
# EPOCH[834/1000] loss0.010-|Sample:0.20|
# EPOCH[835/1000] loss0.010-|Sample:0.14|
# EPOCH[836/1000] loss0.010-|Sample:0.14|
# EPOCH[837/1000] loss0.010-|Sample:0.14|
# EPOCH[838/1000] loss0.010-|Sample:0.14|
# EPOCH[839/1000] loss0.010-|Sample:0.14|
# EPOCH[840/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05871626]), 'recall': array([0.19045635]), 'ndcg': array([0.16308506])}
# EPOCH[841/1000] loss0.010-|Sample:0.13|
# EPOCH[842/1000] loss0.010-|Sample:0.14|
# EPOCH[843/1000] loss0.010-|Sample:0.14|
# EPOCH[844/1000] loss0.010-|Sample:0.19|
# EPOCH[845/1000] loss0.010-|Sample:0.14|
# EPOCH[846/1000] loss0.010-|Sample:0.14|
# EPOCH[847/1000] loss0.010-|Sample:0.14|
# EPOCH[848/1000] loss0.010-|Sample:0.14|
# EPOCH[849/1000] loss0.010-|Sample:0.14|
# EPOCH[850/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05870286]), 'recall': array([0.19002074]), 'ndcg': array([0.16298619])}
# EPOCH[851/1000] loss0.010-|Sample:0.14|
# EPOCH[852/1000] loss0.010-|Sample:0.14|
# EPOCH[853/1000] loss0.010-|Sample:0.14|
# EPOCH[854/1000] loss0.010-|Sample:0.14|
# EPOCH[855/1000] loss0.010-|Sample:0.15|
# EPOCH[856/1000] loss0.010-|Sample:0.14|
# EPOCH[857/1000] loss0.010-|Sample:0.14|
# EPOCH[858/1000] loss0.010-|Sample:0.14|
# EPOCH[859/1000] loss0.010-|Sample:0.19|
# EPOCH[860/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05869449]), 'recall': array([0.19010334]), 'ndcg': array([0.16296032])}
# EPOCH[861/1000] loss0.010-|Sample:0.14|
# EPOCH[862/1000] loss0.010-|Sample:0.13|
# EPOCH[863/1000] loss0.010-|Sample:0.14|
# EPOCH[864/1000] loss0.010-|Sample:0.14|
# EPOCH[865/1000] loss0.010-|Sample:0.14|
# EPOCH[866/1000] loss0.010-|Sample:0.13|
# EPOCH[867/1000] loss0.010-|Sample:0.14|
# EPOCH[868/1000] loss0.010-|Sample:0.14|
# EPOCH[869/1000] loss0.010-|Sample:0.14|
# EPOCH[870/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.0586476]), 'recall': array([0.19018004]), 'ndcg': array([0.16299725])}
# EPOCH[871/1000] loss0.010-|Sample:0.14|
# EPOCH[872/1000] loss0.010-|Sample:0.14|
# EPOCH[873/1000] loss0.010-|Sample:0.13|
# EPOCH[874/1000] loss0.010-|Sample:0.14|
# EPOCH[875/1000] loss0.010-|Sample:0.14|
# EPOCH[876/1000] loss0.010-|Sample:0.13|
# EPOCH[877/1000] loss0.010-|Sample:0.14|
# EPOCH[878/1000] loss0.010-|Sample:0.14|
# EPOCH[879/1000] loss0.010-|Sample:0.14|
# EPOCH[880/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05864257]), 'recall': array([0.19007065]), 'ndcg': array([0.16292352])}
# EPOCH[881/1000] loss0.010-|Sample:0.14|
# EPOCH[882/1000] loss0.010-|Sample:0.14|
# EPOCH[883/1000] loss0.010-|Sample:0.14|
# EPOCH[884/1000] loss0.010-|Sample:0.14|
# EPOCH[885/1000] loss0.010-|Sample:0.14|
# EPOCH[886/1000] loss0.010-|Sample:0.14|
# EPOCH[887/1000] loss0.010-|Sample:0.14|
# EPOCH[888/1000] loss0.010-|Sample:0.14|
# EPOCH[889/1000] loss0.010-|Sample:0.14|
# EPOCH[890/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05859401]), 'recall': array([0.18988774]), 'ndcg': array([0.1630581])}
# EPOCH[891/1000] loss0.010-|Sample:0.13|
# EPOCH[892/1000] loss0.010-|Sample:0.14|
# EPOCH[893/1000] loss0.010-|Sample:0.14|
# EPOCH[894/1000] loss0.010-|Sample:0.14|
# EPOCH[895/1000] loss0.010-|Sample:0.14|
# EPOCH[896/1000] loss0.010-|Sample:0.13|
# EPOCH[897/1000] loss0.010-|Sample:0.14|
# EPOCH[898/1000] loss0.010-|Sample:0.14|
# EPOCH[899/1000] loss0.010-|Sample:0.14|
# EPOCH[900/1000] loss0.010-|Sample:0.15|
# [TEST]
# {'precision': array([0.0585354]), 'recall': array([0.19003354]), 'ndcg': array([0.16271458])}
# EPOCH[901/1000] loss0.010-|Sample:0.14|
# EPOCH[902/1000] loss0.010-|Sample:0.14|
# EPOCH[903/1000] loss0.010-|Sample:0.14|
# EPOCH[904/1000] loss0.010-|Sample:0.14|
# EPOCH[905/1000] loss0.010-|Sample:0.13|
# EPOCH[906/1000] loss0.010-|Sample:0.14|
# EPOCH[907/1000] loss0.010-|Sample:0.14|
# EPOCH[908/1000] loss0.010-|Sample:0.14|
# EPOCH[909/1000] loss0.010-|Sample:0.14|
# EPOCH[910/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05836459]), 'recall': array([0.1892267]), 'ndcg': array([0.16242723])}
# EPOCH[911/1000] loss0.010-|Sample:0.14|
# EPOCH[912/1000] loss0.010-|Sample:0.13|
# EPOCH[913/1000] loss0.010-|Sample:0.14|
# EPOCH[914/1000] loss0.010-|Sample:0.13|
# EPOCH[915/1000] loss0.010-|Sample:0.14|
# EPOCH[916/1000] loss0.010-|Sample:0.14|
# EPOCH[917/1000] loss0.010-|Sample:0.14|
# EPOCH[918/1000] loss0.010-|Sample:0.14|
# EPOCH[919/1000] loss0.010-|Sample:0.14|
# EPOCH[920/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05839306]), 'recall': array([0.18947704]), 'ndcg': array([0.1623585])}
# EPOCH[921/1000] loss0.010-|Sample:0.19|
# EPOCH[922/1000] loss0.010-|Sample:0.14|
# EPOCH[923/1000] loss0.010-|Sample:0.14|
# EPOCH[924/1000] loss0.010-|Sample:0.14|
# EPOCH[925/1000] loss0.010-|Sample:0.14|
# EPOCH[926/1000] loss0.010-|Sample:0.14|
# EPOCH[927/1000] loss0.010-|Sample:0.14|
# EPOCH[928/1000] loss0.010-|Sample:0.14|
# EPOCH[929/1000] loss0.010-|Sample:0.14|
# EPOCH[930/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05851698]), 'recall': array([0.18952289]), 'ndcg': array([0.16252457])}
# EPOCH[931/1000] loss0.010-|Sample:0.13|
# EPOCH[932/1000] loss0.010-|Sample:0.13|
# EPOCH[933/1000] loss0.010-|Sample:0.14|
# EPOCH[934/1000] loss0.010-|Sample:0.13|
# EPOCH[935/1000] loss0.010-|Sample:0.13|
# EPOCH[936/1000] loss0.010-|Sample:0.14|
# EPOCH[937/1000] loss0.010-|Sample:0.14|
# EPOCH[938/1000] loss0.010-|Sample:0.14|
# EPOCH[939/1000] loss0.010-|Sample:0.14|
# EPOCH[940/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.0584366]), 'recall': array([0.19007851]), 'ndcg': array([0.16276497])}
# EPOCH[941/1000] loss0.010-|Sample:0.13|
# EPOCH[942/1000] loss0.010-|Sample:0.14|
# EPOCH[943/1000] loss0.010-|Sample:0.13|
# EPOCH[944/1000] loss0.010-|Sample:0.14|
# EPOCH[945/1000] loss0.010-|Sample:0.17|
# EPOCH[946/1000] loss0.010-|Sample:0.14|
# EPOCH[947/1000] loss0.010-|Sample:0.14|
# EPOCH[948/1000] loss0.010-|Sample:0.13|
# EPOCH[949/1000] loss0.010-|Sample:0.13|
# EPOCH[950/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.0587464]), 'recall': array([0.19075714]), 'ndcg': array([0.16301369])}
# EPOCH[951/1000] loss0.010-|Sample:0.14|
# EPOCH[952/1000] loss0.010-|Sample:0.13|
# EPOCH[953/1000] loss0.010-|Sample:0.14|
# EPOCH[954/1000] loss0.010-|Sample:0.15|
# EPOCH[955/1000] loss0.010-|Sample:0.14|
# EPOCH[956/1000] loss0.010-|Sample:0.13|
# EPOCH[957/1000] loss0.010-|Sample:0.14|
# EPOCH[958/1000] loss0.010-|Sample:0.14|
# EPOCH[959/1000] loss0.010-|Sample:0.13|
# EPOCH[960/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05877654]), 'recall': array([0.19071599]), 'ndcg': array([0.16303385])}
# EPOCH[961/1000] loss0.010-|Sample:0.13|
# EPOCH[962/1000] loss0.010-|Sample:0.13|
# EPOCH[963/1000] loss0.010-|Sample:0.13|
# EPOCH[964/1000] loss0.010-|Sample:0.14|
# EPOCH[965/1000] loss0.010-|Sample:0.14|
# EPOCH[966/1000] loss0.010-|Sample:0.14|
# EPOCH[967/1000] loss0.010-|Sample:0.14|
# EPOCH[968/1000] loss0.010-|Sample:0.14|
# EPOCH[969/1000] loss0.010-|Sample:0.14|
# EPOCH[970/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05866434]), 'recall': array([0.19013658]), 'ndcg': array([0.16289877])}
# EPOCH[971/1000] loss0.010-|Sample:0.15|
# EPOCH[972/1000] loss0.010-|Sample:0.14|
# EPOCH[973/1000] loss0.010-|Sample:0.14|
# EPOCH[974/1000] loss0.010-|Sample:0.13|
# EPOCH[975/1000] loss0.010-|Sample:0.14|
# EPOCH[976/1000] loss0.010-|Sample:0.14|
# EPOCH[977/1000] loss0.010-|Sample:0.14|
# EPOCH[978/1000] loss0.010-|Sample:0.17|
# EPOCH[979/1000] loss0.010-|Sample:0.14|
# EPOCH[980/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05870956]), 'recall': array([0.190457]), 'ndcg': array([0.16298026])}
# EPOCH[981/1000] loss0.010-|Sample:0.13|
# EPOCH[982/1000] loss0.010-|Sample:0.14|
# EPOCH[983/1000] loss0.010-|Sample:0.14|
# EPOCH[984/1000] loss0.010-|Sample:0.14|
# EPOCH[985/1000] loss0.010-|Sample:0.14|
# EPOCH[986/1000] loss0.010-|Sample:0.14|
# EPOCH[987/1000] loss0.010-|Sample:0.13|
# EPOCH[988/1000] loss0.010-|Sample:0.14|
# EPOCH[989/1000] loss0.010-|Sample:0.14|
# EPOCH[990/1000] loss0.010-|Sample:0.17|
# [TEST]
# {'precision': array([0.05869784]), 'recall': array([0.19025649]), 'ndcg': array([0.16290204])}
# EPOCH[991/1000] loss0.010-|Sample:0.13|
# EPOCH[992/1000] loss0.010-|Sample:0.16|
# EPOCH[993/1000] loss0.010-|Sample:0.14|
# EPOCH[994/1000] loss0.010-|Sample:0.14|
# EPOCH[995/1000] loss0.010-|Sample:0.14|
# EPOCH[996/1000] loss0.010-|Sample:0.14|
# EPOCH[997/1000] loss0.010-|Sample:0.14|
# EPOCH[998/1000] loss0.010-|Sample:0.14|
# EPOCH[999/1000] loss0.010-|Sample:0.14|
# EPOCH[1000/1000] loss0.010-|Sample:0.14|
