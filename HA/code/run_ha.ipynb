# %%
# %load main.py
import world
import utils
from world import cprint
import torch
import numpy as np
from tensorboardX import SummaryWriter
import time
import Procedure
from os.path import join
# ==============================
utils.set_seed(world.seed)
print(">>SEED:", world.seed)
# ==============================
import register
from register import dataset

Recmodel = register.MODELS[world.model_name](world.config, dataset)
Recmodel = Recmodel.to(world.device)
bpr = utils.BPRLoss(Recmodel, world.config)

weight_file = utils.getFileName()
print(f"load and save to {weight_file}")
if world.LOAD:
    try:
        Recmodel.load_state_dict(torch.load(weight_file,map_location=torch.device('cpu')))
        world.cprint(f"loaded model weights from {weight_file}")
    except FileNotFoundError:
        print(f"{weight_file} not exists, start from beginning")
Neg_k = 1

# init tensorboard
if world.tensorboard:
    w : SummaryWriter = SummaryWriter(
                                    join(world.BOARD_PATH, time.strftime("%m-%d-%Hh%Mm%Ss-") + "-" + world.comment)
                                    )
else:
    w = None
    world.cprint("not enable tensorflowboard")

try:
    for epoch in range(world.TRAIN_epochs):
        start = time.time()
        if epoch %10 == 0:
            cprint("[TEST]")
            Procedure.Test(dataset, Recmodel, epoch, w, world.config['multicore'])
        output_information = Procedure.BPR_train_original(dataset, Recmodel, bpr, epoch, neg_k=Neg_k,w=w)
        print(f'EPOCH[{epoch+1}/{world.TRAIN_epochs}] {output_information}')
        torch.save(Recmodel.state_dict(), weight_file)
finally:
    if world.tensorboard:
        w.close()
# Out:
# >>SEED: 2020
# loading [../data/gowalla]
# 810128 interactions for training
# 217242 interactions for testing
# gowalla Sparsity : 0.0008396216228570436
# gowalla is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'multicore': 1,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 24
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded heterogeneous graph ...
# don't split the matrix
# loading adjacency matrix
# successfully loaded homogeneous graph ...
# don't split the matrix
# loading degree weight
# successfully loaded heterogeneous degree weight ...
# lgn is already to go(dropout:0)
# load and save to /home/user1/Larry/FGCF/HA/runs/code/checkpoints/lgn-gowalla-3-64.pth.tar
# [TEST]
# {'precision': array([0.00199611]), 'recall': array([0.00718575]), 'ndcg': array([0.00488124])}
# EPOCH[1/1000] loss0.277-|Sample:0.13|
# EPOCH[2/1000] loss0.127-|Sample:0.12|
# EPOCH[3/1000] loss0.103-|Sample:0.14|
# EPOCH[4/1000] loss0.091-|Sample:0.14|
# EPOCH[5/1000] loss0.084-|Sample:0.15|
# EPOCH[6/1000] loss0.077-|Sample:0.13|
# EPOCH[7/1000] loss0.072-|Sample:0.15|
# EPOCH[8/1000] loss0.068-|Sample:0.14|
# EPOCH[9/1000] loss0.065-|Sample:0.14|
# EPOCH[10/1000] loss0.062-|Sample:0.14|
# [TEST]
# {'precision': array([0.03668699]), 'recall': array([0.12662231]), 'ndcg': array([0.09798313])}
# EPOCH[11/1000] loss0.059-|Sample:0.13|
# EPOCH[12/1000] loss0.057-|Sample:0.14|
# EPOCH[13/1000] loss0.054-|Sample:0.13|
# EPOCH[14/1000] loss0.053-|Sample:0.14|
# EPOCH[15/1000] loss0.051-|Sample:0.14|
# EPOCH[16/1000] loss0.050-|Sample:0.14|
# EPOCH[17/1000] loss0.047-|Sample:0.14|
# EPOCH[18/1000] loss0.047-|Sample:0.14|
# EPOCH[19/1000] loss0.046-|Sample:0.14|
# EPOCH[20/1000] loss0.044-|Sample:0.14|
# [TEST]
# {'precision': array([0.04067419]), 'recall': array([0.13912775]), 'ndcg': array([0.10847743])}
# EPOCH[21/1000] loss0.043-|Sample:0.13|
# EPOCH[22/1000] loss0.042-|Sample:0.14|
# EPOCH[23/1000] loss0.041-|Sample:0.14|
# EPOCH[24/1000] loss0.040-|Sample:0.15|
# EPOCH[25/1000] loss0.040-|Sample:0.15|
# EPOCH[26/1000] loss0.039-|Sample:0.14|
# EPOCH[27/1000] loss0.038-|Sample:0.15|
# EPOCH[28/1000] loss0.037-|Sample:0.14|
# EPOCH[29/1000] loss0.037-|Sample:0.14|
# EPOCH[30/1000] loss0.036-|Sample:0.14|
# [TEST]
# {'precision': array([0.04336861]), 'recall': array([0.14855883]), 'ndcg': array([0.11636658])}
# EPOCH[31/1000] loss0.035-|Sample:0.13|
# EPOCH[32/1000] loss0.035-|Sample:0.14|
# EPOCH[33/1000] loss0.034-|Sample:0.14|
# EPOCH[34/1000] loss0.033-|Sample:0.14|
# EPOCH[35/1000] loss0.032-|Sample:0.14|
# EPOCH[36/1000] loss0.032-|Sample:0.14|
# EPOCH[37/1000] loss0.032-|Sample:0.13|
# EPOCH[38/1000] loss0.031-|Sample:0.14|
# EPOCH[39/1000] loss0.030-|Sample:0.14|
# EPOCH[40/1000] loss0.030-|Sample:0.14|
# [TEST]
# {'precision': array([0.04557238]), 'recall': array([0.15564868]), 'ndcg': array([0.12237945])}
# EPOCH[41/1000] loss0.029-|Sample:0.14|
# EPOCH[42/1000] loss0.029-|Sample:0.14|
# EPOCH[43/1000] loss0.029-|Sample:0.14|
# EPOCH[44/1000] loss0.028-|Sample:0.14|
# EPOCH[45/1000] loss0.028-|Sample:0.14|
# EPOCH[46/1000] loss0.027-|Sample:0.14|
# EPOCH[47/1000] loss0.027-|Sample:0.16|
# EPOCH[48/1000] loss0.027-|Sample:0.14|
# EPOCH[49/1000] loss0.027-|Sample:0.14|
# EPOCH[50/1000] loss0.026-|Sample:0.13|
# [TEST]
# {'precision': array([0.04722185]), 'recall': array([0.161061]), 'ndcg': array([0.12716772])}
# EPOCH[51/1000] loss0.026-|Sample:0.14|
# EPOCH[52/1000] loss0.025-|Sample:0.14|
# EPOCH[53/1000] loss0.026-|Sample:0.15|
# EPOCH[54/1000] loss0.025-|Sample:0.14|
# EPOCH[55/1000] loss0.024-|Sample:0.14|
# EPOCH[56/1000] loss0.024-|Sample:0.14|
# EPOCH[57/1000] loss0.024-|Sample:0.14|
# EPOCH[58/1000] loss0.024-|Sample:0.14|
# EPOCH[59/1000] loss0.024-|Sample:0.14|
# EPOCH[60/1000] loss0.023-|Sample:0.14|
# [TEST]
# {'precision': array([0.04872061]), 'recall': array([0.16550247]), 'ndcg': array([0.1313829])}
# EPOCH[61/1000] loss0.023-|Sample:0.14|
# EPOCH[62/1000] loss0.023-|Sample:0.14|
# EPOCH[63/1000] loss0.023-|Sample:0.14|
# EPOCH[64/1000] loss0.022-|Sample:0.18|
# EPOCH[65/1000] loss0.022-|Sample:0.14|
# EPOCH[66/1000] loss0.021-|Sample:0.14|
# EPOCH[67/1000] loss0.022-|Sample:0.14|
# EPOCH[68/1000] loss0.021-|Sample:0.14|
# EPOCH[69/1000] loss0.021-|Sample:0.19|
# EPOCH[70/1000] loss0.022-|Sample:0.15|
# [TEST]
# {'precision': array([0.04962154]), 'recall': array([0.16818523]), 'ndcg': array([0.13486019])}
# EPOCH[71/1000] loss0.021-|Sample:0.16|
# EPOCH[72/1000] loss0.020-|Sample:0.14|
# EPOCH[73/1000] loss0.020-|Sample:0.14|
# EPOCH[74/1000] loss0.020-|Sample:0.14|
# EPOCH[75/1000] loss0.021-|Sample:0.14|
# EPOCH[76/1000] loss0.020-|Sample:0.14|
# EPOCH[77/1000] loss0.020-|Sample:0.14|
# EPOCH[78/1000] loss0.020-|Sample:0.14|
# EPOCH[79/1000] loss0.019-|Sample:0.14|
# EPOCH[80/1000] loss0.020-|Sample:0.14|
# [TEST]
# {'precision': array([0.05057606]), 'recall': array([0.17095852]), 'ndcg': array([0.13719017])}
# EPOCH[81/1000] loss0.019-|Sample:0.14|
# EPOCH[82/1000] loss0.019-|Sample:0.13|
# EPOCH[83/1000] loss0.019-|Sample:0.14|
# EPOCH[84/1000] loss0.018-|Sample:0.14|
# EPOCH[85/1000] loss0.018-|Sample:0.14|
# EPOCH[86/1000] loss0.018-|Sample:0.14|
# EPOCH[87/1000] loss0.018-|Sample:0.13|
# EPOCH[88/1000] loss0.018-|Sample:0.14|
# EPOCH[89/1000] loss0.018-|Sample:0.15|
# EPOCH[90/1000] loss0.018-|Sample:0.14|
# [TEST]
# {'precision': array([0.05141671]), 'recall': array([0.17369455]), 'ndcg': array([0.14007236])}
# EPOCH[91/1000] loss0.018-|Sample:0.14|
# EPOCH[92/1000] loss0.018-|Sample:0.14|
# EPOCH[93/1000] loss0.018-|Sample:0.14|
# EPOCH[94/1000] loss0.018-|Sample:0.14|
# EPOCH[95/1000] loss0.018-|Sample:0.14|
# EPOCH[96/1000] loss0.017-|Sample:0.14|
# EPOCH[97/1000] loss0.017-|Sample:0.14|
# EPOCH[98/1000] loss0.017-|Sample:0.14|
# EPOCH[99/1000] loss0.017-|Sample:0.14|
# EPOCH[100/1000] loss0.017-|Sample:0.14|
# [TEST]
# {'precision': array([0.05207984]), 'recall': array([0.17571563]), 'ndcg': array([0.14229798])}
# EPOCH[101/1000] loss0.017-|Sample:0.13|
# EPOCH[102/1000] loss0.016-|Sample:0.13|
# EPOCH[103/1000] loss0.017-|Sample:0.14|
# EPOCH[104/1000] loss0.017-|Sample:0.14|
# EPOCH[105/1000] loss0.017-|Sample:0.15|
# EPOCH[106/1000] loss0.016-|Sample:0.14|
# EPOCH[107/1000] loss0.016-|Sample:0.14|
# EPOCH[108/1000] loss0.016-|Sample:0.14|
# EPOCH[109/1000] loss0.016-|Sample:0.14|
# EPOCH[110/1000] loss0.016-|Sample:0.14|
# [TEST]
# {'precision': array([0.05262576]), 'recall': array([0.17773461]), 'ndcg': array([0.14442208])}
# EPOCH[111/1000] loss0.016-|Sample:0.14|
# EPOCH[112/1000] loss0.016-|Sample:0.14|
# EPOCH[113/1000] loss0.016-|Sample:0.13|
# EPOCH[114/1000] loss0.016-|Sample:0.14|
# EPOCH[115/1000] loss0.015-|Sample:0.14|
# EPOCH[116/1000] loss0.015-|Sample:0.13|
# EPOCH[117/1000] loss0.016-|Sample:0.13|
# EPOCH[118/1000] loss0.015-|Sample:0.14|
# EPOCH[119/1000] loss0.015-|Sample:0.14|
# EPOCH[120/1000] loss0.015-|Sample:0.14|
# [TEST]
# {'precision': array([0.05297575]), 'recall': array([0.1785022]), 'ndcg': array([0.14556671])}
# EPOCH[121/1000] loss0.015-|Sample:0.15|
# EPOCH[122/1000] loss0.015-|Sample:0.14|
# EPOCH[123/1000] loss0.015-|Sample:0.14|
# EPOCH[124/1000] loss0.015-|Sample:0.13|
# EPOCH[125/1000] loss0.015-|Sample:0.14|
# EPOCH[126/1000] loss0.014-|Sample:0.13|
# EPOCH[127/1000] loss0.015-|Sample:0.13|
# EPOCH[128/1000] loss0.015-|Sample:0.14|
# EPOCH[129/1000] loss0.014-|Sample:0.13|
# EPOCH[130/1000] loss0.015-|Sample:0.14|
# [TEST]
# {'precision': array([0.05333411]), 'recall': array([0.17960141]), 'ndcg': array([0.14677411])}
# EPOCH[131/1000] loss0.015-|Sample:0.16|
# EPOCH[132/1000] loss0.014-|Sample:0.13|
# EPOCH[133/1000] loss0.014-|Sample:0.15|
# EPOCH[134/1000] loss0.014-|Sample:0.14|
# EPOCH[135/1000] loss0.014-|Sample:0.14|
# EPOCH[136/1000] loss0.014-|Sample:0.13|
# EPOCH[137/1000] loss0.014-|Sample:0.13|
# EPOCH[138/1000] loss0.014-|Sample:0.14|
# EPOCH[139/1000] loss0.014-|Sample:0.14|
# EPOCH[140/1000] loss0.014-|Sample:0.14|
# [TEST]
# {'precision': array([0.05356521]), 'recall': array([0.18058181]), 'ndcg': array([0.14758132])}
# EPOCH[141/1000] loss0.014-|Sample:0.13|
# EPOCH[142/1000] loss0.014-|Sample:0.13|
# EPOCH[143/1000] loss0.014-|Sample:0.14|
# EPOCH[144/1000] loss0.014-|Sample:0.15|
# EPOCH[145/1000] loss0.014-|Sample:0.15|
# EPOCH[146/1000] loss0.014-|Sample:0.14|
# EPOCH[147/1000] loss0.013-|Sample:0.14|
# EPOCH[148/1000] loss0.014-|Sample:0.14|
# EPOCH[149/1000] loss0.013-|Sample:0.14|
# EPOCH[150/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05382645]), 'recall': array([0.18159337]), 'ndcg': array([0.14883106])}
# EPOCH[151/1000] loss0.014-|Sample:0.13|
# EPOCH[152/1000] loss0.013-|Sample:0.13|
# EPOCH[153/1000] loss0.014-|Sample:0.14|
# EPOCH[154/1000] loss0.013-|Sample:0.14|
# EPOCH[155/1000] loss0.013-|Sample:0.14|
# EPOCH[156/1000] loss0.014-|Sample:0.14|
# EPOCH[157/1000] loss0.013-|Sample:0.14|
# EPOCH[158/1000] loss0.013-|Sample:0.14|
# EPOCH[159/1000] loss0.013-|Sample:0.18|
# EPOCH[160/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05419151]), 'recall': array([0.18250076]), 'ndcg': array([0.1498564])}
# EPOCH[161/1000] loss0.013-|Sample:0.13|
# EPOCH[162/1000] loss0.013-|Sample:0.13|
# EPOCH[163/1000] loss0.013-|Sample:0.13|
# EPOCH[164/1000] loss0.013-|Sample:0.13|
# EPOCH[165/1000] loss0.013-|Sample:0.14|
# EPOCH[166/1000] loss0.013-|Sample:0.14|
# EPOCH[167/1000] loss0.013-|Sample:0.13|
# EPOCH[168/1000] loss0.013-|Sample:0.14|
# EPOCH[169/1000] loss0.013-|Sample:0.14|
# EPOCH[170/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05447284]), 'recall': array([0.18331303]), 'ndcg': array([0.15050191])}
# EPOCH[171/1000] loss0.013-|Sample:0.13|
# EPOCH[172/1000] loss0.012-|Sample:0.14|
# EPOCH[173/1000] loss0.013-|Sample:0.14|
# EPOCH[174/1000] loss0.012-|Sample:0.13|
# EPOCH[175/1000] loss0.012-|Sample:0.13|
# EPOCH[176/1000] loss0.012-|Sample:0.13|
# EPOCH[177/1000] loss0.012-|Sample:0.13|
# EPOCH[178/1000] loss0.013-|Sample:0.13|
# EPOCH[179/1000] loss0.012-|Sample:0.14|
# EPOCH[180/1000] loss0.013-|Sample:0.13|
# [TEST]
# {'precision': array([0.05473575]), 'recall': array([0.18424258]), 'ndcg': array([0.1515481])}
# EPOCH[181/1000] loss0.012-|Sample:0.13|
# EPOCH[182/1000] loss0.012-|Sample:0.13|
# EPOCH[183/1000] loss0.012-|Sample:0.14|
# EPOCH[184/1000] loss0.012-|Sample:0.14|
# EPOCH[185/1000] loss0.012-|Sample:0.14|
# EPOCH[186/1000] loss0.012-|Sample:0.13|
# EPOCH[187/1000] loss0.012-|Sample:0.14|
# EPOCH[188/1000] loss0.012-|Sample:0.14|
# EPOCH[189/1000] loss0.012-|Sample:0.14|
# EPOCH[190/1000] loss0.012-|Sample:0.13|
# [TEST]
# {'precision': array([0.0548245]), 'recall': array([0.18431056]), 'ndcg': array([0.15230273])}
# EPOCH[191/1000] loss0.012-|Sample:0.13|
# EPOCH[192/1000] loss0.012-|Sample:0.13|
# EPOCH[193/1000] loss0.012-|Sample:0.13|
# EPOCH[194/1000] loss0.012-|Sample:0.13|
# EPOCH[195/1000] loss0.012-|Sample:0.14|
# EPOCH[196/1000] loss0.012-|Sample:0.14|
# EPOCH[197/1000] loss0.012-|Sample:0.13|
# EPOCH[198/1000] loss0.012-|Sample:0.14|
# EPOCH[199/1000] loss0.012-|Sample:0.14|
# EPOCH[200/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05517784]), 'recall': array([0.18492289]), 'ndcg': array([0.15320084])}
# EPOCH[201/1000] loss0.012-|Sample:0.15|
# EPOCH[202/1000] loss0.012-|Sample:0.13|
# EPOCH[203/1000] loss0.011-|Sample:0.14|
# EPOCH[204/1000] loss0.012-|Sample:0.13|
# EPOCH[205/1000] loss0.012-|Sample:0.14|
# EPOCH[206/1000] loss0.012-|Sample:0.14|
# EPOCH[207/1000] loss0.012-|Sample:0.14|
# EPOCH[208/1000] loss0.011-|Sample:0.13|
# EPOCH[209/1000] loss0.011-|Sample:0.13|
# EPOCH[210/1000] loss0.012-|Sample:0.14|
# [TEST]
# {'precision': array([0.05525487]), 'recall': array([0.18556764]), 'ndcg': array([0.15341284])}
# EPOCH[211/1000] loss0.012-|Sample:0.13|
# EPOCH[212/1000] loss0.011-|Sample:0.13|
# EPOCH[213/1000] loss0.011-|Sample:0.14|
# EPOCH[214/1000] loss0.011-|Sample:0.13|
# EPOCH[215/1000] loss0.012-|Sample:0.14|
# EPOCH[216/1000] loss0.011-|Sample:0.13|
# EPOCH[217/1000] loss0.011-|Sample:0.14|
# EPOCH[218/1000] loss0.011-|Sample:0.14|
# EPOCH[219/1000] loss0.011-|Sample:0.14|
# EPOCH[220/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05548764]), 'recall': array([0.18608377]), 'ndcg': array([0.15354482])}
# EPOCH[221/1000] loss0.011-|Sample:0.15|
# EPOCH[222/1000] loss0.011-|Sample:0.13|
# EPOCH[223/1000] loss0.011-|Sample:0.13|
# EPOCH[224/1000] loss0.011-|Sample:0.14|
# EPOCH[225/1000] loss0.011-|Sample:0.13|
# EPOCH[226/1000] loss0.011-|Sample:0.13|
# EPOCH[227/1000] loss0.011-|Sample:0.14|
# EPOCH[228/1000] loss0.011-|Sample:0.13|
# EPOCH[229/1000] loss0.011-|Sample:0.13|
# EPOCH[230/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.0555697]), 'recall': array([0.18637672]), 'ndcg': array([0.1545783])}
# EPOCH[231/1000] loss0.011-|Sample:0.13|
# EPOCH[232/1000] loss0.011-|Sample:0.13|
# EPOCH[233/1000] loss0.011-|Sample:0.13|
# EPOCH[234/1000] loss0.011-|Sample:0.14|
# EPOCH[235/1000] loss0.011-|Sample:0.14|
# EPOCH[236/1000] loss0.011-|Sample:0.14|
# EPOCH[237/1000] loss0.011-|Sample:0.13|
# EPOCH[238/1000] loss0.011-|Sample:0.13|
# EPOCH[239/1000] loss0.011-|Sample:0.14|
# EPOCH[240/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.05575725]), 'recall': array([0.18692355]), 'ndcg': array([0.15494658])}
# EPOCH[241/1000] loss0.011-|Sample:0.12|
# EPOCH[242/1000] loss0.011-|Sample:0.13|
# EPOCH[243/1000] loss0.011-|Sample:0.13|
# EPOCH[244/1000] loss0.011-|Sample:0.14|
# EPOCH[245/1000] loss0.011-|Sample:0.14|
# EPOCH[246/1000] loss0.011-|Sample:0.13|
# EPOCH[247/1000] loss0.011-|Sample:0.13|
# EPOCH[248/1000] loss0.011-|Sample:0.14|
# EPOCH[249/1000] loss0.011-|Sample:0.14|
# EPOCH[250/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05565343]), 'recall': array([0.18662081]), 'ndcg': array([0.15494463])}
# EPOCH[251/1000] loss0.011-|Sample:0.13|
# EPOCH[252/1000] loss0.011-|Sample:0.13|
# EPOCH[253/1000] loss0.011-|Sample:0.14|
# EPOCH[254/1000] loss0.011-|Sample:0.13|
# EPOCH[255/1000] loss0.011-|Sample:0.13|
# EPOCH[256/1000] loss0.011-|Sample:0.13|
# EPOCH[257/1000] loss0.011-|Sample:0.13|
# EPOCH[258/1000] loss0.011-|Sample:0.13|
# EPOCH[259/1000] loss0.011-|Sample:0.13|
# EPOCH[260/1000] loss0.011-|Sample:0.14|
# [TEST]
# {'precision': array([0.05579409]), 'recall': array([0.18702147]), 'ndcg': array([0.1552248])}
# EPOCH[261/1000] loss0.011-|Sample:0.13|
# EPOCH[262/1000] loss0.011-|Sample:0.13|
# EPOCH[263/1000] loss0.011-|Sample:0.14|
# EPOCH[264/1000] loss0.011-|Sample:0.13|
# EPOCH[265/1000] loss0.011-|Sample:0.13|
# EPOCH[266/1000] loss0.011-|Sample:0.13|
# EPOCH[267/1000] loss0.011-|Sample:0.13|
# EPOCH[268/1000] loss0.011-|Sample:0.14|
# EPOCH[269/1000] loss0.010-|Sample:0.14|
# EPOCH[270/1000] loss0.011-|Sample:0.13|
# [TEST]
# {'precision': array([0.0558728]), 'recall': array([0.18699163]), 'ndcg': array([0.15548897])}
# EPOCH[271/1000] loss0.010-|Sample:0.13|
# EPOCH[272/1000] loss0.011-|Sample:0.13|
# EPOCH[273/1000] loss0.010-|Sample:0.14|
# EPOCH[274/1000] loss0.010-|Sample:0.13|
# EPOCH[275/1000] loss0.010-|Sample:0.14|
# EPOCH[276/1000] loss0.011-|Sample:0.13|
# EPOCH[277/1000] loss0.010-|Sample:0.13|
# EPOCH[278/1000] loss0.010-|Sample:0.14|
# EPOCH[279/1000] loss0.011-|Sample:0.14|
# EPOCH[280/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05602184]), 'recall': array([0.18745271]), 'ndcg': array([0.15585475])}
# EPOCH[281/1000] loss0.010-|Sample:0.14|
# EPOCH[282/1000] loss0.011-|Sample:0.14|
# EPOCH[283/1000] loss0.011-|Sample:0.14|
# EPOCH[284/1000] loss0.010-|Sample:0.13|
# EPOCH[285/1000] loss0.011-|Sample:0.14|
# EPOCH[286/1000] loss0.011-|Sample:0.14|
# EPOCH[287/1000] loss0.010-|Sample:0.13|
# EPOCH[288/1000] loss0.011-|Sample:0.14|
# EPOCH[289/1000] loss0.010-|Sample:0.14|
# EPOCH[290/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05589122]), 'recall': array([0.18725309]), 'ndcg': array([0.15562318])}
# EPOCH[291/1000] loss0.010-|Sample:0.15|
# EPOCH[292/1000] loss0.010-|Sample:0.14|
# EPOCH[293/1000] loss0.010-|Sample:0.13|
# EPOCH[294/1000] loss0.010-|Sample:0.14|
# EPOCH[295/1000] loss0.010-|Sample:0.14|
# EPOCH[296/1000] loss0.010-|Sample:0.14|
# EPOCH[297/1000] loss0.010-|Sample:0.14|
# EPOCH[298/1000] loss0.010-|Sample:0.14|
# EPOCH[299/1000] loss0.010-|Sample:0.14|
# EPOCH[300/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05624623]), 'recall': array([0.188452]), 'ndcg': array([0.15639216])}
# EPOCH[301/1000] loss0.010-|Sample:0.13|
# EPOCH[302/1000] loss0.010-|Sample:0.13|
# EPOCH[303/1000] loss0.010-|Sample:0.14|
# EPOCH[304/1000] loss0.010-|Sample:0.14|
# EPOCH[305/1000] loss0.010-|Sample:0.14|
# EPOCH[306/1000] loss0.010-|Sample:0.14|
# EPOCH[307/1000] loss0.010-|Sample:0.14|
# EPOCH[308/1000] loss0.010-|Sample:0.14|
# EPOCH[309/1000] loss0.010-|Sample:0.15|
# EPOCH[310/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05608547]), 'recall': array([0.18795365]), 'ndcg': array([0.15609196])}
# EPOCH[311/1000] loss0.010-|Sample:0.13|
# EPOCH[312/1000] loss0.010-|Sample:0.14|
# EPOCH[313/1000] loss0.010-|Sample:0.14|
# EPOCH[314/1000] loss0.010-|Sample:0.14|
# EPOCH[315/1000] loss0.010-|Sample:0.14|
# EPOCH[316/1000] loss0.010-|Sample:0.14|
# EPOCH[317/1000] loss0.010-|Sample:0.14|
# EPOCH[318/1000] loss0.010-|Sample:0.13|
# EPOCH[319/1000] loss0.010-|Sample:0.13|
# EPOCH[320/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.0563735]), 'recall': array([0.18840869]), 'ndcg': array([0.15664044])}
# EPOCH[321/1000] loss0.010-|Sample:0.13|
# EPOCH[322/1000] loss0.010-|Sample:0.14|
# EPOCH[323/1000] loss0.010-|Sample:0.13|
# EPOCH[324/1000] loss0.010-|Sample:0.13|
# EPOCH[325/1000] loss0.010-|Sample:0.14|
# EPOCH[326/1000] loss0.010-|Sample:0.14|
# EPOCH[327/1000] loss0.010-|Sample:0.14|
# EPOCH[328/1000] loss0.010-|Sample:0.15|
# EPOCH[329/1000] loss0.010-|Sample:0.15|
# EPOCH[330/1000] loss0.010-|Sample:0.15|
# [TEST]
# {'precision': array([0.05632996]), 'recall': array([0.18883092]), 'ndcg': array([0.15677166])}
# EPOCH[331/1000] loss0.010-|Sample:0.14|
# EPOCH[332/1000] loss0.010-|Sample:0.14|
# EPOCH[333/1000] loss0.010-|Sample:0.13|
# EPOCH[334/1000] loss0.010-|Sample:0.14|
# EPOCH[335/1000] loss0.010-|Sample:0.14|
# EPOCH[336/1000] loss0.010-|Sample:0.14|
# EPOCH[337/1000] loss0.010-|Sample:0.14|
# EPOCH[338/1000] loss0.010-|Sample:0.14|
# EPOCH[339/1000] loss0.010-|Sample:0.14|
# EPOCH[340/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05634168]), 'recall': array([0.18859674]), 'ndcg': array([0.15659933])}
# EPOCH[341/1000] loss0.010-|Sample:0.13|
# EPOCH[342/1000] loss0.010-|Sample:0.14|
# EPOCH[343/1000] loss0.010-|Sample:0.14|
# EPOCH[344/1000] loss0.010-|Sample:0.14|
# EPOCH[345/1000] loss0.010-|Sample:0.14|
# EPOCH[346/1000] loss0.010-|Sample:0.18|
# EPOCH[347/1000] loss0.010-|Sample:0.14|
# EPOCH[348/1000] loss0.010-|Sample:0.14|
# EPOCH[349/1000] loss0.010-|Sample:0.14|
# EPOCH[350/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05631991]), 'recall': array([0.18835438]), 'ndcg': array([0.15698667])}
# EPOCH[351/1000] loss0.010-|Sample:0.13|
# EPOCH[352/1000] loss0.010-|Sample:0.14|
# EPOCH[353/1000] loss0.010-|Sample:0.14|
# EPOCH[354/1000] loss0.010-|Sample:0.14|
# EPOCH[355/1000] loss0.010-|Sample:0.14|
# EPOCH[356/1000] loss0.010-|Sample:0.14|
# EPOCH[357/1000] loss0.010-|Sample:0.14|
# EPOCH[358/1000] loss0.010-|Sample:0.14|
# EPOCH[359/1000] loss0.010-|Sample:0.14|
# EPOCH[360/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05626465]), 'recall': array([0.18860857]), 'ndcg': array([0.15674681])}
# EPOCH[361/1000] loss0.010-|Sample:0.13|
# EPOCH[362/1000] loss0.010-|Sample:0.14|
# EPOCH[363/1000] loss0.010-|Sample:0.14|
# EPOCH[364/1000] loss0.010-|Sample:0.14|
# EPOCH[365/1000] loss0.010-|Sample:0.14|
# EPOCH[366/1000] loss0.010-|Sample:0.14|
# EPOCH[367/1000] loss0.010-|Sample:0.14|
# EPOCH[368/1000] loss0.010-|Sample:0.14|
# EPOCH[369/1000] loss0.010-|Sample:0.14|
# EPOCH[370/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05645891]), 'recall': array([0.18855519]), 'ndcg': array([0.15698287])}
# EPOCH[371/1000] loss0.010-|Sample:0.19|
# EPOCH[372/1000] loss0.010-|Sample:0.14|
# EPOCH[373/1000] loss0.010-|Sample:0.14|
# EPOCH[374/1000] loss0.010-|Sample:0.14|
# EPOCH[375/1000] loss0.010-|Sample:0.13|
# EPOCH[376/1000] loss0.010-|Sample:0.13|
# EPOCH[377/1000] loss0.010-|Sample:0.14|
# EPOCH[378/1000] loss0.010-|Sample:0.14|
# EPOCH[379/1000] loss0.010-|Sample:0.14|
# EPOCH[380/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05654431]), 'recall': array([0.1888294]), 'ndcg': array([0.15734364])}
# EPOCH[381/1000] loss0.010-|Sample:0.15|
# EPOCH[382/1000] loss0.010-|Sample:0.14|
# EPOCH[383/1000] loss0.010-|Sample:0.14|
# EPOCH[384/1000] loss0.010-|Sample:0.14|
# EPOCH[385/1000] loss0.010-|Sample:0.13|
# EPOCH[386/1000] loss0.010-|Sample:0.13|
# EPOCH[387/1000] loss0.010-|Sample:0.14|
# EPOCH[388/1000] loss0.010-|Sample:0.14|
# EPOCH[389/1000] loss0.010-|Sample:0.14|
# EPOCH[390/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.05666823]), 'recall': array([0.1893079]), 'ndcg': array([0.15779567])}
# EPOCH[391/1000] loss0.010-|Sample:0.13|
# EPOCH[392/1000] loss0.010-|Sample:0.14|
# EPOCH[393/1000] loss0.010-|Sample:0.18|
# EPOCH[394/1000] loss0.010-|Sample:0.14|
# EPOCH[395/1000] loss0.009-|Sample:0.14|
# EPOCH[396/1000] loss0.009-|Sample:0.14|
# EPOCH[397/1000] loss0.009-|Sample:0.14|
# EPOCH[398/1000] loss0.010-|Sample:0.14|
# EPOCH[399/1000] loss0.010-|Sample:0.14|
# EPOCH[400/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05663306]), 'recall': array([0.18925427]), 'ndcg': array([0.15780711])}
# EPOCH[401/1000] loss0.010-|Sample:0.14|
# EPOCH[402/1000] loss0.010-|Sample:0.13|
# EPOCH[403/1000] loss0.009-|Sample:0.15|
# EPOCH[404/1000] loss0.010-|Sample:0.14|
# EPOCH[405/1000] loss0.010-|Sample:0.14|
# EPOCH[406/1000] loss0.010-|Sample:0.14|
# EPOCH[407/1000] loss0.010-|Sample:0.14|
# EPOCH[408/1000] loss0.010-|Sample:0.14|
# EPOCH[409/1000] loss0.010-|Sample:0.14|
# EPOCH[410/1000] loss0.010-|Sample:0.14|
# [TEST]
# {'precision': array([0.0566967]), 'recall': array([0.18927392]), 'ndcg': array([0.15776058])}
# EPOCH[411/1000] loss0.009-|Sample:0.13|
# EPOCH[412/1000] loss0.009-|Sample:0.14|
# EPOCH[413/1000] loss0.010-|Sample:0.14|
# EPOCH[414/1000] loss0.009-|Sample:0.14|
# EPOCH[415/1000] loss0.010-|Sample:0.14|
# EPOCH[416/1000] loss0.009-|Sample:0.15|
# EPOCH[417/1000] loss0.010-|Sample:0.14|
# EPOCH[418/1000] loss0.010-|Sample:0.15|
# EPOCH[419/1000] loss0.010-|Sample:0.18|
# EPOCH[420/1000] loss0.010-|Sample:0.20|
# [TEST]
# {'precision': array([0.05678713]), 'recall': array([0.18935243]), 'ndcg': array([0.15765224])}
# EPOCH[421/1000] loss0.010-|Sample:0.12|
# EPOCH[422/1000] loss0.009-|Sample:0.14|
# EPOCH[423/1000] loss0.010-|Sample:0.15|
# EPOCH[424/1000] loss0.009-|Sample:0.13|
# EPOCH[425/1000] loss0.009-|Sample:0.14|
# EPOCH[426/1000] loss0.009-|Sample:0.13|
# EPOCH[427/1000] loss0.009-|Sample:0.14|
# EPOCH[428/1000] loss0.009-|Sample:0.14|
# EPOCH[429/1000] loss0.009-|Sample:0.13|
# EPOCH[430/1000] loss0.010-|Sample:0.20|
# [TEST]
# {'precision': array([0.05644383]), 'recall': array([0.18897756]), 'ndcg': array([0.15746498])}
# EPOCH[431/1000] loss0.010-|Sample:0.18|
# EPOCH[432/1000] loss0.010-|Sample:0.14|
# EPOCH[433/1000] loss0.009-|Sample:0.14|
# EPOCH[434/1000] loss0.010-|Sample:0.14|
# EPOCH[435/1000] loss0.010-|Sample:0.14|
# EPOCH[436/1000] loss0.009-|Sample:0.19|
# EPOCH[437/1000] loss0.010-|Sample:0.14|
# EPOCH[438/1000] loss0.010-|Sample:0.14|
# EPOCH[439/1000] loss0.010-|Sample:0.15|
# EPOCH[440/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05680555]), 'recall': array([0.18944264]), 'ndcg': array([0.15773396])}
# EPOCH[441/1000] loss0.009-|Sample:0.15|
# EPOCH[442/1000] loss0.009-|Sample:0.13|
# EPOCH[443/1000] loss0.009-|Sample:0.14|
# EPOCH[444/1000] loss0.009-|Sample:0.13|
# EPOCH[445/1000] loss0.009-|Sample:0.14|
# EPOCH[446/1000] loss0.009-|Sample:0.14|
# EPOCH[447/1000] loss0.009-|Sample:0.14|
# EPOCH[448/1000] loss0.009-|Sample:0.13|
# EPOCH[449/1000] loss0.010-|Sample:0.13|
# EPOCH[450/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05674024]), 'recall': array([0.18916956]), 'ndcg': array([0.15794144])}
# EPOCH[451/1000] loss0.009-|Sample:0.14|
# EPOCH[452/1000] loss0.009-|Sample:0.14|
# EPOCH[453/1000] loss0.009-|Sample:0.14|
# EPOCH[454/1000] loss0.009-|Sample:0.14|
# EPOCH[455/1000] loss0.009-|Sample:0.14|
# EPOCH[456/1000] loss0.009-|Sample:0.14|
# EPOCH[457/1000] loss0.009-|Sample:0.14|
# EPOCH[458/1000] loss0.009-|Sample:0.13|
# EPOCH[459/1000] loss0.009-|Sample:0.14|
# EPOCH[460/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05677038]), 'recall': array([0.18913872]), 'ndcg': array([0.1577366])}
# EPOCH[461/1000] loss0.009-|Sample:0.15|
# EPOCH[462/1000] loss0.009-|Sample:0.14|
# EPOCH[463/1000] loss0.009-|Sample:0.13|
# EPOCH[464/1000] loss0.009-|Sample:0.14|
# EPOCH[465/1000] loss0.009-|Sample:0.14|
# EPOCH[466/1000] loss0.009-|Sample:0.14|
# EPOCH[467/1000] loss0.009-|Sample:0.14|
# EPOCH[468/1000] loss0.009-|Sample:0.13|
# EPOCH[469/1000] loss0.009-|Sample:0.14|
# EPOCH[470/1000] loss0.010-|Sample:0.13|
# [TEST]
# {'precision': array([0.05675531]), 'recall': array([0.18909615]), 'ndcg': array([0.15761291])}
# EPOCH[471/1000] loss0.009-|Sample:0.13|
# EPOCH[472/1000] loss0.009-|Sample:0.14|
# EPOCH[473/1000] loss0.009-|Sample:0.14|
# EPOCH[474/1000] loss0.009-|Sample:0.13|
# EPOCH[475/1000] loss0.009-|Sample:0.14|
# EPOCH[476/1000] loss0.009-|Sample:0.14|
# EPOCH[477/1000] loss0.009-|Sample:0.14|
# EPOCH[478/1000] loss0.009-|Sample:0.14|
# EPOCH[479/1000] loss0.009-|Sample:0.14|
# EPOCH[480/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05668498]), 'recall': array([0.18892194]), 'ndcg': array([0.15811163])}
# EPOCH[481/1000] loss0.009-|Sample:0.15|
# EPOCH[482/1000] loss0.009-|Sample:0.14|
# EPOCH[483/1000] loss0.009-|Sample:0.14|
# EPOCH[484/1000] loss0.009-|Sample:0.14|
# EPOCH[485/1000] loss0.009-|Sample:0.14|
# EPOCH[486/1000] loss0.009-|Sample:0.13|
# EPOCH[487/1000] loss0.009-|Sample:0.14|
# EPOCH[488/1000] loss0.009-|Sample:0.14|
# EPOCH[489/1000] loss0.009-|Sample:0.14|
# EPOCH[490/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.0566766]), 'recall': array([0.1886829]), 'ndcg': array([0.15731937])}
# EPOCH[491/1000] loss0.009-|Sample:0.12|
# EPOCH[492/1000] loss0.009-|Sample:0.14|
# EPOCH[493/1000] loss0.009-|Sample:0.14|
# EPOCH[494/1000] loss0.009-|Sample:0.13|
# EPOCH[495/1000] loss0.009-|Sample:0.14|
# EPOCH[496/1000] loss0.009-|Sample:0.14|
# EPOCH[497/1000] loss0.009-|Sample:0.15|
# EPOCH[498/1000] loss0.009-|Sample:0.14|
# EPOCH[499/1000] loss0.009-|Sample:0.15|
# EPOCH[500/1000] loss0.009-|Sample:0.15|
# [TEST]
# {'precision': array([0.05701487]), 'recall': array([0.18967363]), 'ndcg': array([0.15822357])}
# EPOCH[501/1000] loss0.009-|Sample:0.12|
# EPOCH[502/1000] loss0.009-|Sample:0.14|
# EPOCH[503/1000] loss0.009-|Sample:0.14|
# EPOCH[504/1000] loss0.010-|Sample:0.14|
# EPOCH[505/1000] loss0.009-|Sample:0.14|
# EPOCH[506/1000] loss0.009-|Sample:0.14|
# EPOCH[507/1000] loss0.009-|Sample:0.14|
# EPOCH[508/1000] loss0.009-|Sample:0.14|
# EPOCH[509/1000] loss0.009-|Sample:0.14|
# EPOCH[510/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05692277]), 'recall': array([0.18966618]), 'ndcg': array([0.15831378])}
# EPOCH[511/1000] loss0.009-|Sample:0.13|
# EPOCH[512/1000] loss0.009-|Sample:0.14|
# EPOCH[513/1000] loss0.009-|Sample:0.14|
# EPOCH[514/1000] loss0.009-|Sample:0.14|
# EPOCH[515/1000] loss0.009-|Sample:0.14|
# EPOCH[516/1000] loss0.009-|Sample:0.14|
# EPOCH[517/1000] loss0.009-|Sample:0.13|
# EPOCH[518/1000] loss0.009-|Sample:0.14|
# EPOCH[519/1000] loss0.009-|Sample:0.14|
# EPOCH[520/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05681559]), 'recall': array([0.18929873]), 'ndcg': array([0.15824779])}
# EPOCH[521/1000] loss0.009-|Sample:0.14|
# EPOCH[522/1000] loss0.009-|Sample:0.14|
# EPOCH[523/1000] loss0.009-|Sample:0.14|
# EPOCH[524/1000] loss0.009-|Sample:0.14|
# EPOCH[525/1000] loss0.009-|Sample:0.14|
# EPOCH[526/1000] loss0.009-|Sample:0.14|
# EPOCH[527/1000] loss0.009-|Sample:0.18|
# EPOCH[528/1000] loss0.009-|Sample:0.20|
# EPOCH[529/1000] loss0.009-|Sample:0.14|
# EPOCH[530/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05703162]), 'recall': array([0.19000119]), 'ndcg': array([0.15871106])}
# EPOCH[531/1000] loss0.009-|Sample:0.14|
# EPOCH[532/1000] loss0.009-|Sample:0.13|
# EPOCH[533/1000] loss0.009-|Sample:0.13|
# EPOCH[534/1000] loss0.009-|Sample:0.14|
# EPOCH[535/1000] loss0.009-|Sample:0.14|
# EPOCH[536/1000] loss0.009-|Sample:0.13|
# EPOCH[537/1000] loss0.009-|Sample:0.15|
# EPOCH[538/1000] loss0.009-|Sample:0.14|
# EPOCH[539/1000] loss0.009-|Sample:0.14|
# EPOCH[540/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05691272]), 'recall': array([0.18945384]), 'ndcg': array([0.15819861])}
# EPOCH[541/1000] loss0.009-|Sample:0.14|
# EPOCH[542/1000] loss0.009-|Sample:0.14|
# EPOCH[543/1000] loss0.009-|Sample:0.14|
# EPOCH[544/1000] loss0.009-|Sample:0.14|
# EPOCH[545/1000] loss0.009-|Sample:0.14|
# EPOCH[546/1000] loss0.009-|Sample:0.14|
# EPOCH[547/1000] loss0.009-|Sample:0.14|
# EPOCH[548/1000] loss0.009-|Sample:0.14|
# EPOCH[549/1000] loss0.009-|Sample:0.14|
# EPOCH[550/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05688425]), 'recall': array([0.18994366]), 'ndcg': array([0.15820673])}
# EPOCH[551/1000] loss0.009-|Sample:0.15|
# EPOCH[552/1000] loss0.009-|Sample:0.14|
# EPOCH[553/1000] loss0.009-|Sample:0.14|
# EPOCH[554/1000] loss0.009-|Sample:0.13|
# EPOCH[555/1000] loss0.009-|Sample:0.14|
# EPOCH[556/1000] loss0.009-|Sample:0.14|
# EPOCH[557/1000] loss0.009-|Sample:0.14|
# EPOCH[558/1000] loss0.009-|Sample:0.13|
# EPOCH[559/1000] loss0.009-|Sample:0.14|
# EPOCH[560/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05692947]), 'recall': array([0.18960363]), 'ndcg': array([0.1584732])}
# EPOCH[561/1000] loss0.009-|Sample:0.15|
# EPOCH[562/1000] loss0.009-|Sample:0.14|
# EPOCH[563/1000] loss0.009-|Sample:0.19|
# EPOCH[564/1000] loss0.009-|Sample:0.14|
# EPOCH[565/1000] loss0.009-|Sample:0.14|
# EPOCH[566/1000] loss0.009-|Sample:0.14|
# EPOCH[567/1000] loss0.009-|Sample:0.14|
# EPOCH[568/1000] loss0.009-|Sample:0.17|
# EPOCH[569/1000] loss0.009-|Sample:0.14|
# EPOCH[570/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05700482]), 'recall': array([0.18981353]), 'ndcg': array([0.15900615])}
# EPOCH[571/1000] loss0.009-|Sample:0.13|
# EPOCH[572/1000] loss0.009-|Sample:0.14|
# EPOCH[573/1000] loss0.009-|Sample:0.14|
# EPOCH[574/1000] loss0.009-|Sample:0.14|
# EPOCH[575/1000] loss0.009-|Sample:0.14|
# EPOCH[576/1000] loss0.009-|Sample:0.13|
# EPOCH[577/1000] loss0.009-|Sample:0.14|
# EPOCH[578/1000] loss0.009-|Sample:0.14|
# EPOCH[579/1000] loss0.009-|Sample:0.14|
# EPOCH[580/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05699143]), 'recall': array([0.18968662]), 'ndcg': array([0.15863418])}
# EPOCH[581/1000] loss0.009-|Sample:0.13|
# EPOCH[582/1000] loss0.009-|Sample:0.14|
# EPOCH[583/1000] loss0.009-|Sample:0.13|
# EPOCH[584/1000] loss0.009-|Sample:0.14|
# EPOCH[585/1000] loss0.009-|Sample:0.14|
# EPOCH[586/1000] loss0.009-|Sample:0.14|
# EPOCH[587/1000] loss0.009-|Sample:0.14|
# EPOCH[588/1000] loss0.009-|Sample:0.14|
# EPOCH[589/1000] loss0.009-|Sample:0.14|
# EPOCH[590/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05705674]), 'recall': array([0.18959941]), 'ndcg': array([0.15867106])}
# EPOCH[591/1000] loss0.009-|Sample:0.13|
# EPOCH[592/1000] loss0.009-|Sample:0.13|
# EPOCH[593/1000] loss0.009-|Sample:0.14|
# EPOCH[594/1000] loss0.009-|Sample:0.14|
# EPOCH[595/1000] loss0.009-|Sample:0.14|
# EPOCH[596/1000] loss0.009-|Sample:0.14|
# EPOCH[597/1000] loss0.009-|Sample:0.14|
# EPOCH[598/1000] loss0.009-|Sample:0.14|
# EPOCH[599/1000] loss0.009-|Sample:0.15|
# EPOCH[600/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05726104]), 'recall': array([0.19035686]), 'ndcg': array([0.15924197])}
# EPOCH[601/1000] loss0.009-|Sample:0.14|
# EPOCH[602/1000] loss0.009-|Sample:0.14|
# EPOCH[603/1000] loss0.009-|Sample:0.14|
# EPOCH[604/1000] loss0.009-|Sample:0.13|
# EPOCH[605/1000] loss0.009-|Sample:0.14|
# EPOCH[606/1000] loss0.009-|Sample:0.14|
# EPOCH[607/1000] loss0.009-|Sample:0.19|
# EPOCH[608/1000] loss0.009-|Sample:0.17|
# EPOCH[609/1000] loss0.009-|Sample:0.19|
# EPOCH[610/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05705506]), 'recall': array([0.18966006]), 'ndcg': array([0.1585316])}
# EPOCH[611/1000] loss0.009-|Sample:0.13|
# EPOCH[612/1000] loss0.009-|Sample:0.14|
# EPOCH[613/1000] loss0.009-|Sample:0.14|
# EPOCH[614/1000] loss0.009-|Sample:0.13|
# EPOCH[615/1000] loss0.009-|Sample:0.14|
# EPOCH[616/1000] loss0.009-|Sample:0.14|
# EPOCH[617/1000] loss0.009-|Sample:0.19|
# EPOCH[618/1000] loss0.009-|Sample:0.14|
# EPOCH[619/1000] loss0.009-|Sample:0.15|
# EPOCH[620/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05723592]), 'recall': array([0.1903123]), 'ndcg': array([0.15898748])}
# EPOCH[621/1000] loss0.009-|Sample:0.15|
# EPOCH[622/1000] loss0.009-|Sample:0.15|
# EPOCH[623/1000] loss0.009-|Sample:0.14|
# EPOCH[624/1000] loss0.009-|Sample:0.14|
# EPOCH[625/1000] loss0.009-|Sample:0.14|
# EPOCH[626/1000] loss0.009-|Sample:0.13|
# EPOCH[627/1000] loss0.009-|Sample:0.14|
# EPOCH[628/1000] loss0.009-|Sample:0.15|
# EPOCH[629/1000] loss0.009-|Sample:0.14|
# EPOCH[630/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05723592]), 'recall': array([0.19016331]), 'ndcg': array([0.15882938])}
# EPOCH[631/1000] loss0.009-|Sample:0.15|
# EPOCH[632/1000] loss0.009-|Sample:0.15|
# EPOCH[633/1000] loss0.009-|Sample:0.14|
# EPOCH[634/1000] loss0.009-|Sample:0.14|
# EPOCH[635/1000] loss0.009-|Sample:0.14|
# EPOCH[636/1000] loss0.009-|Sample:0.14|
# EPOCH[637/1000] loss0.009-|Sample:0.14|
# EPOCH[638/1000] loss0.009-|Sample:0.15|
# EPOCH[639/1000] loss0.009-|Sample:0.14|
# EPOCH[640/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05717228]), 'recall': array([0.18989482]), 'ndcg': array([0.15890131])}
# EPOCH[641/1000] loss0.009-|Sample:0.14|
# EPOCH[642/1000] loss0.009-|Sample:0.14|
# EPOCH[643/1000] loss0.009-|Sample:0.14|
# EPOCH[644/1000] loss0.009-|Sample:0.14|
# EPOCH[645/1000] loss0.009-|Sample:0.13|
# EPOCH[646/1000] loss0.009-|Sample:0.14|
# EPOCH[647/1000] loss0.009-|Sample:0.14|
# EPOCH[648/1000] loss0.009-|Sample:0.14|
# EPOCH[649/1000] loss0.009-|Sample:0.14|
# EPOCH[650/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05718903]), 'recall': array([0.19004616]), 'ndcg': array([0.1588832])}
# EPOCH[651/1000] loss0.009-|Sample:0.13|
# EPOCH[652/1000] loss0.009-|Sample:0.14|
# EPOCH[653/1000] loss0.009-|Sample:0.14|
# EPOCH[654/1000] loss0.009-|Sample:0.14|
# EPOCH[655/1000] loss0.009-|Sample:0.14|
# EPOCH[656/1000] loss0.009-|Sample:0.13|
# EPOCH[657/1000] loss0.009-|Sample:0.14|
# EPOCH[658/1000] loss0.009-|Sample:0.14|
# EPOCH[659/1000] loss0.009-|Sample:0.14|
# EPOCH[660/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.0570852]), 'recall': array([0.19017568]), 'ndcg': array([0.15908126])}
# EPOCH[661/1000] loss0.009-|Sample:0.16|
# EPOCH[662/1000] loss0.009-|Sample:0.14|
# EPOCH[663/1000] loss0.009-|Sample:0.14|
# EPOCH[664/1000] loss0.009-|Sample:0.14|
# EPOCH[665/1000] loss0.009-|Sample:0.14|
# EPOCH[666/1000] loss0.009-|Sample:0.14|
# EPOCH[667/1000] loss0.009-|Sample:0.14|
# EPOCH[668/1000] loss0.009-|Sample:0.13|
# EPOCH[669/1000] loss0.009-|Sample:0.14|
# EPOCH[670/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05695961]), 'recall': array([0.18965908]), 'ndcg': array([0.15835002])}
# EPOCH[671/1000] loss0.009-|Sample:0.15|
# EPOCH[672/1000] loss0.009-|Sample:0.15|
# EPOCH[673/1000] loss0.009-|Sample:0.14|
# EPOCH[674/1000] loss0.009-|Sample:0.15|
# EPOCH[675/1000] loss0.009-|Sample:0.15|
# EPOCH[676/1000] loss0.009-|Sample:0.15|
# EPOCH[677/1000] loss0.009-|Sample:0.14|
# EPOCH[678/1000] loss0.009-|Sample:0.16|
# EPOCH[679/1000] loss0.009-|Sample:0.15|
# EPOCH[680/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05685243]), 'recall': array([0.18919054]), 'ndcg': array([0.15819883])}
# EPOCH[681/1000] loss0.009-|Sample:0.13|
# EPOCH[682/1000] loss0.009-|Sample:0.14|
# EPOCH[683/1000] loss0.009-|Sample:0.14|
# EPOCH[684/1000] loss0.009-|Sample:0.14|
# EPOCH[685/1000] loss0.009-|Sample:0.14|
# EPOCH[686/1000] loss0.009-|Sample:0.14|
# EPOCH[687/1000] loss0.009-|Sample:0.14|
# EPOCH[688/1000] loss0.009-|Sample:0.13|
# EPOCH[689/1000] loss0.009-|Sample:0.13|
# EPOCH[690/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05700482]), 'recall': array([0.18986804]), 'ndcg': array([0.15858996])}
# EPOCH[691/1000] loss0.009-|Sample:0.14|
# EPOCH[692/1000] loss0.009-|Sample:0.14|
# EPOCH[693/1000] loss0.009-|Sample:0.15|
# EPOCH[694/1000] loss0.009-|Sample:0.14|
# EPOCH[695/1000] loss0.009-|Sample:0.14|
# EPOCH[696/1000] loss0.009-|Sample:0.14|
# EPOCH[697/1000] loss0.009-|Sample:0.14|
# EPOCH[698/1000] loss0.009-|Sample:0.14|
# EPOCH[699/1000] loss0.009-|Sample:0.14|
# EPOCH[700/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05695291]), 'recall': array([0.18972021]), 'ndcg': array([0.15847091])}
# EPOCH[701/1000] loss0.009-|Sample:0.12|
# EPOCH[702/1000] loss0.009-|Sample:0.14|
# EPOCH[703/1000] loss0.009-|Sample:0.14|
# EPOCH[704/1000] loss0.009-|Sample:0.14|
# EPOCH[705/1000] loss0.009-|Sample:0.14|
# EPOCH[706/1000] loss0.009-|Sample:0.14|
# EPOCH[707/1000] loss0.009-|Sample:0.14|
# EPOCH[708/1000] loss0.009-|Sample:0.14|
# EPOCH[709/1000] loss0.009-|Sample:0.14|
# EPOCH[710/1000] loss0.009-|Sample:0.15|
# [TEST]
# {'precision': array([0.05683904]), 'recall': array([0.18978447]), 'ndcg': array([0.15861202])}
# EPOCH[711/1000] loss0.009-|Sample:0.12|
# EPOCH[712/1000] loss0.009-|Sample:0.14|
# EPOCH[713/1000] loss0.009-|Sample:0.13|
# EPOCH[714/1000] loss0.009-|Sample:0.14|
# EPOCH[715/1000] loss0.009-|Sample:0.14|
# EPOCH[716/1000] loss0.009-|Sample:0.14|
# EPOCH[717/1000] loss0.009-|Sample:0.14|
# EPOCH[718/1000] loss0.009-|Sample:0.13|
# EPOCH[719/1000] loss0.009-|Sample:0.13|
# EPOCH[720/1000] loss0.009-|Sample:0.15|
# [TEST]
# {'precision': array([0.05685243]), 'recall': array([0.18988478]), 'ndcg': array([0.15852075])}
# EPOCH[721/1000] loss0.009-|Sample:0.13|
# EPOCH[722/1000] loss0.009-|Sample:0.13|
# EPOCH[723/1000] loss0.009-|Sample:0.14|
# EPOCH[724/1000] loss0.009-|Sample:0.14|
# EPOCH[725/1000] loss0.009-|Sample:0.14|
# EPOCH[726/1000] loss0.009-|Sample:0.15|
# EPOCH[727/1000] loss0.009-|Sample:0.14|
# EPOCH[728/1000] loss0.009-|Sample:0.14|
# EPOCH[729/1000] loss0.009-|Sample:0.15|
# EPOCH[730/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05700817]), 'recall': array([0.18998231]), 'ndcg': array([0.15898012])}
# EPOCH[731/1000] loss0.009-|Sample:0.13|
# EPOCH[732/1000] loss0.009-|Sample:0.14|
# EPOCH[733/1000] loss0.009-|Sample:0.13|
# EPOCH[734/1000] loss0.009-|Sample:0.14|
# EPOCH[735/1000] loss0.009-|Sample:0.13|
# EPOCH[736/1000] loss0.009-|Sample:0.13|
# EPOCH[737/1000] loss0.009-|Sample:0.14|
# EPOCH[738/1000] loss0.009-|Sample:0.14|
# EPOCH[739/1000] loss0.009-|Sample:0.13|
# EPOCH[740/1000] loss0.009-|Sample:0.13|
# [TEST]
# {'precision': array([0.05708353]), 'recall': array([0.1903598]), 'ndcg': array([0.15862934])}
# EPOCH[741/1000] loss0.009-|Sample:0.14|
# EPOCH[742/1000] loss0.009-|Sample:0.14|
# EPOCH[743/1000] loss0.009-|Sample:0.13|
# EPOCH[744/1000] loss0.009-|Sample:0.14|
# EPOCH[745/1000] loss0.009-|Sample:0.14|
# EPOCH[746/1000] loss0.009-|Sample:0.14|
# EPOCH[747/1000] loss0.009-|Sample:0.14|
# EPOCH[748/1000] loss0.009-|Sample:0.14|
# EPOCH[749/1000] loss0.009-|Sample:0.14|
# EPOCH[750/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05694454]), 'recall': array([0.18990901]), 'ndcg': array([0.15858309])}
# EPOCH[751/1000] loss0.009-|Sample:0.14|
# EPOCH[752/1000] loss0.009-|Sample:0.14|
# EPOCH[753/1000] loss0.009-|Sample:0.15|
# EPOCH[754/1000] loss0.009-|Sample:0.13|
# EPOCH[755/1000] loss0.009-|Sample:0.14|
# EPOCH[756/1000] loss0.009-|Sample:0.14|
# EPOCH[757/1000] loss0.009-|Sample:0.14|
# EPOCH[758/1000] loss0.009-|Sample:0.14|
# EPOCH[759/1000] loss0.009-|Sample:0.14|
# EPOCH[760/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05695961]), 'recall': array([0.18960778]), 'ndcg': array([0.15870111])}
# EPOCH[761/1000] loss0.009-|Sample:0.13|
# EPOCH[762/1000] loss0.009-|Sample:0.13|
# EPOCH[763/1000] loss0.009-|Sample:0.14|
# EPOCH[764/1000] loss0.009-|Sample:0.14|
# EPOCH[765/1000] loss0.009-|Sample:0.14|
# EPOCH[766/1000] loss0.009-|Sample:0.13|
# EPOCH[767/1000] loss0.009-|Sample:0.14|
# EPOCH[768/1000] loss0.009-|Sample:0.14|
# EPOCH[769/1000] loss0.009-|Sample:0.13|
# EPOCH[770/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05710697]), 'recall': array([0.19001031]), 'ndcg': array([0.15899839])}
# EPOCH[771/1000] loss0.009-|Sample:0.13|
# EPOCH[772/1000] loss0.009-|Sample:0.14|
# EPOCH[773/1000] loss0.009-|Sample:0.14|
# EPOCH[774/1000] loss0.009-|Sample:0.14|
# EPOCH[775/1000] loss0.009-|Sample:0.13|
# EPOCH[776/1000] loss0.009-|Sample:0.14|
# EPOCH[777/1000] loss0.009-|Sample:0.14|
# EPOCH[778/1000] loss0.009-|Sample:0.13|
# EPOCH[779/1000] loss0.009-|Sample:0.13|
# EPOCH[780/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.0568943]), 'recall': array([0.18992078]), 'ndcg': array([0.15887524])}
# EPOCH[781/1000] loss0.009-|Sample:0.15|
# EPOCH[782/1000] loss0.009-|Sample:0.13|
# EPOCH[783/1000] loss0.009-|Sample:0.14|
# EPOCH[784/1000] loss0.009-|Sample:0.14|
# EPOCH[785/1000] loss0.009-|Sample:0.14|
# EPOCH[786/1000] loss0.009-|Sample:0.14|
# EPOCH[787/1000] loss0.009-|Sample:0.14|
# EPOCH[788/1000] loss0.009-|Sample:0.14|
# EPOCH[789/1000] loss0.009-|Sample:0.14|
# EPOCH[790/1000] loss0.009-|Sample:0.17|
# [TEST]
# {'precision': array([0.0568022]), 'recall': array([0.18960625]), 'ndcg': array([0.15887471])}
# EPOCH[791/1000] loss0.009-|Sample:0.15|
# EPOCH[792/1000] loss0.009-|Sample:0.14|
# EPOCH[793/1000] loss0.009-|Sample:0.14|
# EPOCH[794/1000] loss0.009-|Sample:0.14|
# EPOCH[795/1000] loss0.009-|Sample:0.14|
# EPOCH[796/1000] loss0.009-|Sample:0.13|
# EPOCH[797/1000] loss0.009-|Sample:0.13|
# EPOCH[798/1000] loss0.009-|Sample:0.14|
# EPOCH[799/1000] loss0.009-|Sample:0.13|
# EPOCH[800/1000] loss0.009-|Sample:0.13|
# [TEST]
# {'precision': array([0.05692612]), 'recall': array([0.19006195]), 'ndcg': array([0.15900147])}
# EPOCH[801/1000] loss0.009-|Sample:0.15|
# EPOCH[802/1000] loss0.009-|Sample:0.14|
# EPOCH[803/1000] loss0.009-|Sample:0.13|
# EPOCH[804/1000] loss0.009-|Sample:0.14|
# EPOCH[805/1000] loss0.009-|Sample:0.13|
# EPOCH[806/1000] loss0.009-|Sample:0.14|
# EPOCH[807/1000] loss0.009-|Sample:0.13|
# EPOCH[808/1000] loss0.009-|Sample:0.14|
# EPOCH[809/1000] loss0.009-|Sample:0.14|
# EPOCH[810/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05697133]), 'recall': array([0.19001141]), 'ndcg': array([0.15870558])}
# EPOCH[811/1000] loss0.009-|Sample:0.15|
# EPOCH[812/1000] loss0.009-|Sample:0.14|
# EPOCH[813/1000] loss0.009-|Sample:0.14|
# EPOCH[814/1000] loss0.009-|Sample:0.14|
# EPOCH[815/1000] loss0.009-|Sample:0.14|
# EPOCH[816/1000] loss0.009-|Sample:0.14|
# EPOCH[817/1000] loss0.009-|Sample:0.14|
# EPOCH[818/1000] loss0.009-|Sample:0.13|
# EPOCH[819/1000] loss0.009-|Sample:0.14|
# EPOCH[820/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05689932]), 'recall': array([0.18942274]), 'ndcg': array([0.15858343])}
# EPOCH[821/1000] loss0.009-|Sample:0.14|
# EPOCH[822/1000] loss0.009-|Sample:0.14|
# EPOCH[823/1000] loss0.009-|Sample:0.14|
# EPOCH[824/1000] loss0.009-|Sample:0.14|
# EPOCH[825/1000] loss0.009-|Sample:0.14|
# EPOCH[826/1000] loss0.009-|Sample:0.13|
# EPOCH[827/1000] loss0.009-|Sample:0.14|
# EPOCH[828/1000] loss0.009-|Sample:0.13|
# EPOCH[829/1000] loss0.009-|Sample:0.13|
# EPOCH[830/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05713879]), 'recall': array([0.19060714]), 'ndcg': array([0.15945599])}
# EPOCH[831/1000] loss0.009-|Sample:0.13|
# EPOCH[832/1000] loss0.009-|Sample:0.14|
# EPOCH[833/1000] loss0.009-|Sample:0.14|
# EPOCH[834/1000] loss0.009-|Sample:0.14|
# EPOCH[835/1000] loss0.009-|Sample:0.14|
# EPOCH[836/1000] loss0.009-|Sample:0.14|
# EPOCH[837/1000] loss0.009-|Sample:0.14|
# EPOCH[838/1000] loss0.009-|Sample:0.14|
# EPOCH[839/1000] loss0.009-|Sample:0.14|
# EPOCH[840/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05685411]), 'recall': array([0.18979458]), 'ndcg': array([0.15874138])}
# EPOCH[841/1000] loss0.009-|Sample:0.13|
# EPOCH[842/1000] loss0.009-|Sample:0.14|
# EPOCH[843/1000] loss0.009-|Sample:0.14|
# EPOCH[844/1000] loss0.009-|Sample:0.14|
# EPOCH[845/1000] loss0.009-|Sample:0.14|
# EPOCH[846/1000] loss0.009-|Sample:0.14|
# EPOCH[847/1000] loss0.009-|Sample:0.14|
# EPOCH[848/1000] loss0.009-|Sample:0.13|
# EPOCH[849/1000] loss0.009-|Sample:0.14|
# EPOCH[850/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05682899]), 'recall': array([0.189341]), 'ndcg': array([0.15842617])}
# EPOCH[851/1000] loss0.009-|Sample:0.14|
# EPOCH[852/1000] loss0.009-|Sample:0.13|
# EPOCH[853/1000] loss0.009-|Sample:0.14|
# EPOCH[854/1000] loss0.009-|Sample:0.14|
# EPOCH[855/1000] loss0.009-|Sample:0.14|
# EPOCH[856/1000] loss0.009-|Sample:0.14|
# EPOCH[857/1000] loss0.009-|Sample:0.14|
# EPOCH[858/1000] loss0.009-|Sample:0.14|
# EPOCH[859/1000] loss0.009-|Sample:0.13|
# EPOCH[860/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05683904]), 'recall': array([0.18946925]), 'ndcg': array([0.15865111])}
# EPOCH[861/1000] loss0.009-|Sample:0.13|
# EPOCH[862/1000] loss0.009-|Sample:0.13|
# EPOCH[863/1000] loss0.009-|Sample:0.13|
# EPOCH[864/1000] loss0.009-|Sample:0.13|
# EPOCH[865/1000] loss0.009-|Sample:0.14|
# EPOCH[866/1000] loss0.009-|Sample:0.14|
# EPOCH[867/1000] loss0.009-|Sample:0.20|
# EPOCH[868/1000] loss0.009-|Sample:0.14|
# EPOCH[869/1000] loss0.009-|Sample:0.14|
# EPOCH[870/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05693282]), 'recall': array([0.18985111]), 'ndcg': array([0.15876693])}
# EPOCH[871/1000] loss0.009-|Sample:0.13|
# EPOCH[872/1000] loss0.009-|Sample:0.14|
# EPOCH[873/1000] loss0.009-|Sample:0.14|
# EPOCH[874/1000] loss0.009-|Sample:0.14|
# EPOCH[875/1000] loss0.009-|Sample:0.13|
# EPOCH[876/1000] loss0.009-|Sample:0.14|
# EPOCH[877/1000] loss0.009-|Sample:0.14|
# EPOCH[878/1000] loss0.009-|Sample:0.14|
# EPOCH[879/1000] loss0.009-|Sample:0.14|
# EPOCH[880/1000] loss0.009-|Sample:0.13|
# [TEST]
# {'precision': array([0.05691942]), 'recall': array([0.18977822]), 'ndcg': array([0.15880621])}
# EPOCH[881/1000] loss0.009-|Sample:0.13|
# EPOCH[882/1000] loss0.009-|Sample:0.13|
# EPOCH[883/1000] loss0.009-|Sample:0.13|
# EPOCH[884/1000] loss0.009-|Sample:0.13|
# EPOCH[885/1000] loss0.009-|Sample:0.14|
# EPOCH[886/1000] loss0.009-|Sample:0.13|
# EPOCH[887/1000] loss0.009-|Sample:0.13|
# EPOCH[888/1000] loss0.009-|Sample:0.14|
# EPOCH[889/1000] loss0.009-|Sample:0.14|
# EPOCH[890/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05695459]), 'recall': array([0.18938929]), 'ndcg': array([0.1584973])}
# EPOCH[891/1000] loss0.009-|Sample:0.13|
# EPOCH[892/1000] loss0.009-|Sample:0.13|
# EPOCH[893/1000] loss0.009-|Sample:0.15|
# EPOCH[894/1000] loss0.009-|Sample:0.14|
# EPOCH[895/1000] loss0.009-|Sample:0.13|
# EPOCH[896/1000] loss0.009-|Sample:0.13|
# EPOCH[897/1000] loss0.009-|Sample:0.14|
# EPOCH[898/1000] loss0.009-|Sample:0.14|
# EPOCH[899/1000] loss0.009-|Sample:0.14|
# EPOCH[900/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05672182]), 'recall': array([0.18901823]), 'ndcg': array([0.15801331])}
# EPOCH[901/1000] loss0.009-|Sample:0.12|
# EPOCH[902/1000] loss0.009-|Sample:0.13|
# EPOCH[903/1000] loss0.009-|Sample:0.13|
# EPOCH[904/1000] loss0.009-|Sample:0.14|
# EPOCH[905/1000] loss0.009-|Sample:0.14|
# EPOCH[906/1000] loss0.009-|Sample:0.14|
# EPOCH[907/1000] loss0.009-|Sample:0.14|
# EPOCH[908/1000] loss0.009-|Sample:0.14|
# EPOCH[909/1000] loss0.009-|Sample:0.14|
# EPOCH[910/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05667995]), 'recall': array([0.18905903]), 'ndcg': array([0.15827068])}
# EPOCH[911/1000] loss0.009-|Sample:0.14|
# EPOCH[912/1000] loss0.009-|Sample:0.13|
# EPOCH[913/1000] loss0.009-|Sample:0.13|
# EPOCH[914/1000] loss0.009-|Sample:0.13|
# EPOCH[915/1000] loss0.009-|Sample:0.14|
# EPOCH[916/1000] loss0.009-|Sample:0.14|
# EPOCH[917/1000] loss0.009-|Sample:0.13|
# EPOCH[918/1000] loss0.009-|Sample:0.13|
# EPOCH[919/1000] loss0.009-|Sample:0.13|
# EPOCH[920/1000] loss0.009-|Sample:0.13|
# [TEST]
# {'precision': array([0.05683234]), 'recall': array([0.18945659]), 'ndcg': array([0.1583795])}
# EPOCH[921/1000] loss0.009-|Sample:0.13|
# EPOCH[922/1000] loss0.009-|Sample:0.14|
# EPOCH[923/1000] loss0.009-|Sample:0.14|
# EPOCH[924/1000] loss0.009-|Sample:0.14|
# EPOCH[925/1000] loss0.009-|Sample:0.13|
# EPOCH[926/1000] loss0.009-|Sample:0.13|
# EPOCH[927/1000] loss0.009-|Sample:0.13|
# EPOCH[928/1000] loss0.009-|Sample:0.13|
# EPOCH[929/1000] loss0.009-|Sample:0.14|
# EPOCH[930/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05687923]), 'recall': array([0.18959699]), 'ndcg': array([0.15832741])}
# EPOCH[931/1000] loss0.009-|Sample:0.15|
# EPOCH[932/1000] loss0.009-|Sample:0.14|
# EPOCH[933/1000] loss0.009-|Sample:0.13|
# EPOCH[934/1000] loss0.009-|Sample:0.14|
# EPOCH[935/1000] loss0.009-|Sample:0.14|
# EPOCH[936/1000] loss0.009-|Sample:0.13|
# EPOCH[937/1000] loss0.009-|Sample:0.14|
# EPOCH[938/1000] loss0.009-|Sample:0.14|
# EPOCH[939/1000] loss0.009-|Sample:0.14|
# EPOCH[940/1000] loss0.009-|Sample:0.13|
# [TEST]
# {'precision': array([0.05665316]), 'recall': array([0.18891879]), 'ndcg': array([0.15743799])}
# EPOCH[941/1000] loss0.009-|Sample:0.15|
# EPOCH[942/1000] loss0.009-|Sample:0.14|
# EPOCH[943/1000] loss0.009-|Sample:0.14|
# EPOCH[944/1000] loss0.009-|Sample:0.13|
# EPOCH[945/1000] loss0.009-|Sample:0.14|
# EPOCH[946/1000] loss0.009-|Sample:0.14|
# EPOCH[947/1000] loss0.009-|Sample:0.14|
# EPOCH[948/1000] loss0.009-|Sample:0.14|
# EPOCH[949/1000] loss0.009-|Sample:0.14|
# EPOCH[950/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05702492]), 'recall': array([0.19005937]), 'ndcg': array([0.15887486])}
# EPOCH[951/1000] loss0.009-|Sample:0.13|
# EPOCH[952/1000] loss0.009-|Sample:0.14|
# EPOCH[953/1000] loss0.009-|Sample:0.14|
# EPOCH[954/1000] loss0.009-|Sample:0.14|
# EPOCH[955/1000] loss0.009-|Sample:0.14|
# EPOCH[956/1000] loss0.009-|Sample:0.13|
# EPOCH[957/1000] loss0.009-|Sample:0.14|
# EPOCH[958/1000] loss0.009-|Sample:0.13|
# EPOCH[959/1000] loss0.009-|Sample:0.13|
# EPOCH[960/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.057112]), 'recall': array([0.19002831]), 'ndcg': array([0.15885933])}
# EPOCH[961/1000] loss0.009-|Sample:0.14|
# EPOCH[962/1000] loss0.009-|Sample:0.13|
# EPOCH[963/1000] loss0.009-|Sample:0.13|
# EPOCH[964/1000] loss0.009-|Sample:0.14|
# EPOCH[965/1000] loss0.009-|Sample:0.13|
# EPOCH[966/1000] loss0.009-|Sample:0.13|
# EPOCH[967/1000] loss0.009-|Sample:0.14|
# EPOCH[968/1000] loss0.009-|Sample:0.14|
# EPOCH[969/1000] loss0.009-|Sample:0.14|
# EPOCH[970/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05675866]), 'recall': array([0.18911506]), 'ndcg': array([0.15824057])}
# EPOCH[971/1000] loss0.009-|Sample:0.12|
# EPOCH[972/1000] loss0.009-|Sample:0.14|
# EPOCH[973/1000] loss0.009-|Sample:0.14|
# EPOCH[974/1000] loss0.009-|Sample:0.14|
# EPOCH[975/1000] loss0.009-|Sample:0.13|
# EPOCH[976/1000] loss0.009-|Sample:0.14|
# EPOCH[977/1000] loss0.008-|Sample:0.14|
# EPOCH[978/1000] loss0.009-|Sample:0.14|
# EPOCH[979/1000] loss0.009-|Sample:0.15|
# EPOCH[980/1000] loss0.009-|Sample:0.13|
# [TEST]
# {'precision': array([0.05696966]), 'recall': array([0.18938652]), 'ndcg': array([0.15848934])}
# EPOCH[981/1000] loss0.009-|Sample:0.13|
# EPOCH[982/1000] loss0.009-|Sample:0.14|
# EPOCH[983/1000] loss0.009-|Sample:0.14|
# EPOCH[984/1000] loss0.009-|Sample:0.14|
# EPOCH[985/1000] loss0.009-|Sample:0.14|
# EPOCH[986/1000] loss0.009-|Sample:0.14|
# EPOCH[987/1000] loss0.009-|Sample:0.14|
# EPOCH[988/1000] loss0.009-|Sample:0.14|
# EPOCH[989/1000] loss0.009-|Sample:0.14|
# EPOCH[990/1000] loss0.009-|Sample:0.14|
# [TEST]
# {'precision': array([0.05699645]), 'recall': array([0.18946652]), 'ndcg': array([0.15854066])}
# EPOCH[991/1000] loss0.009-|Sample:0.14|
# EPOCH[992/1000] loss0.009-|Sample:0.14|
# EPOCH[993/1000] loss0.009-|Sample:0.14|
# EPOCH[994/1000] loss0.009-|Sample:0.14|
# EPOCH[995/1000] loss0.009-|Sample:0.14|
# EPOCH[996/1000] loss0.009-|Sample:0.14|
# EPOCH[997/1000] loss0.009-|Sample:0.14|
# EPOCH[998/1000] loss0.009-|Sample:0.14|
# EPOCH[999/1000] loss0.009-|Sample:0.14|
# EPOCH[1000/1000] loss0.009-|Sample:0.14|
